# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
result_df = pd.read_csv("continuallearningexperiments.csv")
#result_df = pd.read_csv("domainadaptationexperiments-withexperiencereplay.csv")
#result_df = pd.read_csv("domainadaptationexperiments-withoutexperiencereplay.csv")
result_df = result_df.dropna()
display(result_df)
# Out:
#     source_train_dataset target_train_dataset  \
# 0                  KITTI                 DDAD
# 1                  KITTI                 DDAD
# 2                  KITTI                 DDAD
# 3                  KITTI                 DDAD
# 4                  KITTI                 DDAD
# 5                  KITTI                 DDAD
# 6                  KITTI                 DDAD
# 7                  KITTI                 DDAD
# 8                  KITTI                 DDAD
# 9                  KITTI                 DDAD
# 10                 KITTI                 DDAD
# 11                 KITTI                 DDAD
# 12                 KITTI                 DDAD
# 13                 KITTI                 DDAD
# 14                 KITTI                 DDAD
# 15                 KITTI                 DDAD
# 16                 KITTI                 DDAD
# 17                 KITTI                 DDAD
# 18                 KITTI                 DDAD
# 19                 KITTI                 DDAD
# 20                 KITTI                 DDAD
# 21                 KITTI                 DDAD
# 22                 KITTI                 DDAD
# 23                 KITTI                 DDAD
# 24                 KITTI                 DDAD
# 25                 KITTI                 DDAD
# 26                 KITTI                 DDAD
# 27                 KITTI                 DDAD
# 28                 KITTI                 DDAD
# 29                 KITTI                 DDAD
# 30                 KITTI                 DDAD
# 31                 KITTI                 DDAD
# 32                 KITTI                 DDAD
# 33                 KITTI                 DDAD
# 34                 KITTI                 DDAD
# 35                 KITTI                 DDAD
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                  DDAD                KITTI
# 55                  DDAD                KITTI
# 56                  DDAD                KITTI
# 57                  DDAD                KITTI
# 58                  DDAD                KITTI
# 59                  DDAD                KITTI
# 60                  DDAD                KITTI
# 61                  DDAD                KITTI
# 62                  DDAD                KITTI
# 63                  DDAD                KITTI
# 64                  DDAD                KITTI
# 65                  DDAD                KITTI
# 66                  DDAD                KITTI
# 67                  DDAD                KITTI
# 68                  DDAD                KITTI
# 69                  DDAD                KITTI
# 70                  DDAD                KITTI
# 71                  DDAD                KITTI
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
# 108                KITTI                 DDAD
# 109                KITTI                 DDAD
# 110                KITTI                 DDAD
# 111                KITTI                 DDAD
# 112                KITTI                 DDAD
# 113                KITTI                 DDAD
# 114                KITTI                 DDAD
# 115                KITTI                 DDAD
# 116                KITTI                 DDAD
# 117                KITTI                 DDAD
# 118                KITTI                 DDAD
# 119                KITTI                 DDAD
# 120                 DDAD                KITTI
# 121                 DDAD                KITTI
# 122                 DDAD                KITTI
# 123                 DDAD                KITTI
# 124                 DDAD                KITTI
# 125                 DDAD                KITTI
# 126                 DDAD                KITTI
# 127                 DDAD                KITTI
# 128                 DDAD                KITTI
# 129                 DDAD                KITTI
# 130                 DDAD                KITTI
# 131                 DDAD                KITTI
# 132                 DDAD                KITTI
# 133                 DDAD                KITTI
# 134                 DDAD                KITTI
# 135                 DDAD                KITTI
# 136                 DDAD                KITTI
# 137                 DDAD                KITTI
# 138                 DDAD                KITTI
# 139                 DDAD                KITTI
# 140                 DDAD                KITTI
# 141                 DDAD                KITTI
# 142                 DDAD                KITTI
# 143                 DDAD                KITTI
# 144                 DDAD                KITTI
# 145                 DDAD                KITTI
# 146                 DDAD                KITTI
# 147                 DDAD                KITTI
# 148                 DDAD                KITTI
# 149                 DDAD                KITTI
# 150                 DDAD                KITTI
# 151                 DDAD                KITTI
# 152                 DDAD                KITTI
# 153                 DDAD                KITTI
# 154                 DDAD                KITTI
# 155                 DDAD                KITTI
# 156                 DDAD                KITTI
# 157                 DDAD                KITTI
# 158                 DDAD                KITTI
# 159                 DDAD                KITTI
# 160                 DDAD                KITTI
# 161                 DDAD                KITTI
# 162                 DDAD                KITTI
# 163                 DDAD                KITTI
# 164                 DDAD                KITTI
# 165                 DDAD                KITTI
# 166                 DDAD                KITTI
# 167                 DDAD                KITTI
# 168                KITTI                 DDAD
# 169                KITTI                 DDAD
# 170                KITTI                 DDAD
# 171                KITTI                 DDAD
# 172                KITTI                 DDAD
# 173                KITTI                 DDAD
# 174                KITTI                 DDAD
# 175                KITTI                 DDAD
# 176                KITTI                 DDAD
# 177                KITTI                 DDAD
# 178                KITTI                 DDAD
# 179                KITTI                 DDAD
# 180                KITTI                 DDAD
# 181                KITTI                 DDAD
# 182                KITTI                 DDAD
# 183                KITTI                 DDAD
# 184                KITTI                 DDAD
# 185                KITTI                 DDAD
# 186                KITTI                 DDAD
# 187                KITTI                 DDAD
# 188                KITTI                 DDAD
# 189                KITTI                 DDAD
# 190                KITTI                 DDAD
# 191                KITTI                 DDAD
# 192                 DDAD                KITTI
# 193                 DDAD                KITTI
# 194                 DDAD                KITTI
# 195                 DDAD                KITTI
# 196                 DDAD                KITTI
# 197                 DDAD                KITTI
# 198                 DDAD                KITTI
# 199                 DDAD                KITTI
# 200                 DDAD                KITTI
# 201                 DDAD                KITTI
# 202                 DDAD                KITTI
# 203                 DDAD                KITTI
# 204                 DDAD                KITTI
# 205                 DDAD                KITTI
# 206                 DDAD                KITTI
# 207                 DDAD                KITTI
# 208                 DDAD                KITTI
# 209                 DDAD                KITTI
# 210                 DDAD                KITTI
# 211                 DDAD                KITTI
# 212                 DDAD                KITTI
# 213                 DDAD                KITTI
# 214                 DDAD                KITTI
# 215                 DDAD                KITTI
#
#                           training_method test_dataset   adaptation_state  \
# 0                                 SCDepth        KITTI  before_adaptation
# 1                                 SCDepth        KITTI  before_adaptation
# 2                                 SCDepth        KITTI  before_adaptation
# 3                                 SCDepth         DDAD  before_adaptation
# 4                                 SCDepth         DDAD  before_adaptation
# 5                                 SCDepth         DDAD  before_adaptation
# 6                                 SCDepth        KITTI   after_adaptation
# 7                                 SCDepth        KITTI   after_adaptation
# 8                                 SCDepth        KITTI   after_adaptation
# 9                                 SCDepth         DDAD   after_adaptation
# 10                                SCDepth         DDAD   after_adaptation
# 11                                SCDepth         DDAD   after_adaptation
# 12                             FedSCDepth        KITTI  before_adaptation
# 13                             FedSCDepth        KITTI  before_adaptation
# 14                             FedSCDepth        KITTI  before_adaptation
# 15                             FedSCDepth         DDAD  before_adaptation
# 16                             FedSCDepth         DDAD  before_adaptation
# 17                             FedSCDepth         DDAD  before_adaptation
# 18                             FedSCDepth        KITTI   after_adaptation
# 19                             FedSCDepth        KITTI   after_adaptation
# 20                             FedSCDepth        KITTI   after_adaptation
# 21                             FedSCDepth         DDAD   after_adaptation
# 22                             FedSCDepth         DDAD   after_adaptation
# 23                             FedSCDepth         DDAD   after_adaptation
# 24                           BOFedSCDepth        KITTI  before_adaptation
# 25                           BOFedSCDepth        KITTI  before_adaptation
# 26                           BOFedSCDepth        KITTI  before_adaptation
# 27                           BOFedSCDepth         DDAD  before_adaptation
# 28                           BOFedSCDepth         DDAD  before_adaptation
# 29                           BOFedSCDepth         DDAD  before_adaptation
# 30                           BOFedSCDepth        KITTI   after_adaptation
# 31                           BOFedSCDepth        KITTI   after_adaptation
# 32                           BOFedSCDepth        KITTI   after_adaptation
# 33                           BOFedSCDepth         DDAD   after_adaptation
# 34                           BOFedSCDepth         DDAD   after_adaptation
# 35                           BOFedSCDepth         DDAD   after_adaptation
# 36                                SCDepth        KITTI  before_adaptation
# 37                                SCDepth        KITTI  before_adaptation
# 38                                SCDepth        KITTI  before_adaptation
# 39                                SCDepth         DDAD  before_adaptation
# 40                                SCDepth         DDAD  before_adaptation
# 41                                SCDepth         DDAD  before_adaptation
# 42                                SCDepth        KITTI   after_adaptation
# 43                                SCDepth        KITTI   after_adaptation
# 44                                SCDepth        KITTI   after_adaptation
# 45                                SCDepth         DDAD   after_adaptation
# 46                                SCDepth         DDAD   after_adaptation
# 47                                SCDepth         DDAD   after_adaptation
# 48                             FedSCDepth        KITTI  before_adaptation
# 49                             FedSCDepth        KITTI  before_adaptation
# 50                             FedSCDepth        KITTI  before_adaptation
# 51                             FedSCDepth         DDAD  before_adaptation
# 52                             FedSCDepth         DDAD  before_adaptation
# 53                             FedSCDepth         DDAD  before_adaptation
# 54                             FedSCDepth        KITTI   after_adaptation
# 55                             FedSCDepth        KITTI   after_adaptation
# 56                             FedSCDepth        KITTI   after_adaptation
# 57                             FedSCDepth         DDAD   after_adaptation
# 58                             FedSCDepth         DDAD   after_adaptation
# 59                             FedSCDepth         DDAD   after_adaptation
# 60                           BOFedSCDepth        KITTI  before_adaptation
# 61                           BOFedSCDepth        KITTI  before_adaptation
# 62                           BOFedSCDepth        KITTI  before_adaptation
# 63                           BOFedSCDepth         DDAD  before_adaptation
# 64                           BOFedSCDepth         DDAD  before_adaptation
# 65                           BOFedSCDepth         DDAD  before_adaptation
# 66                           BOFedSCDepth        KITTI   after_adaptation
# 67                           BOFedSCDepth        KITTI   after_adaptation
# 68                           BOFedSCDepth        KITTI   after_adaptation
# 69                           BOFedSCDepth         DDAD   after_adaptation
# 70                           BOFedSCDepth         DDAD   after_adaptation
# 71                           BOFedSCDepth         DDAD   after_adaptation
# 72                    FedSCDepth(Retrain)        KITTI  before_adaptation
# 73                    FedSCDepth(Retrain)        KITTI  before_adaptation
# 74                    FedSCDepth(Retrain)        KITTI  before_adaptation
# 75                    FedSCDepth(Retrain)         DDAD  before_adaptation
# 76                    FedSCDepth(Retrain)         DDAD  before_adaptation
# 77                    FedSCDepth(Retrain)         DDAD  before_adaptation
# 78                    FedSCDepth(Retrain)        KITTI   after_adaptation
# 79                    FedSCDepth(Retrain)        KITTI   after_adaptation
# 80                    FedSCDepth(Retrain)        KITTI   after_adaptation
# 81                    FedSCDepth(Retrain)         DDAD   after_adaptation
# 82                    FedSCDepth(Retrain)         DDAD   after_adaptation
# 83                    FedSCDepth(Retrain)         DDAD   after_adaptation
# 84                    FedSCDepth(Average)        KITTI  before_adaptation
# 85                    FedSCDepth(Average)        KITTI  before_adaptation
# 86                    FedSCDepth(Average)        KITTI  before_adaptation
# 87                    FedSCDepth(Average)         DDAD  before_adaptation
# 88                    FedSCDepth(Average)         DDAD  before_adaptation
# 89                    FedSCDepth(Average)         DDAD  before_adaptation
# 90                    FedSCDepth(Average)        KITTI   after_adaptation
# 91                    FedSCDepth(Average)        KITTI   after_adaptation
# 92                    FedSCDepth(Average)        KITTI   after_adaptation
# 93                    FedSCDepth(Average)         DDAD   after_adaptation
# 94                    FedSCDepth(Average)         DDAD   after_adaptation
# 95                    FedSCDepth(Average)         DDAD   after_adaptation
# 96            FedSCDepth(Average&Retrain)        KITTI  before_adaptation
# 97            FedSCDepth(Average&Retrain)        KITTI  before_adaptation
# 98            FedSCDepth(Average&Retrain)        KITTI  before_adaptation
# 99            FedSCDepth(Average&Retrain)         DDAD  before_adaptation
# 100           FedSCDepth(Average&Retrain)         DDAD  before_adaptation
# 101           FedSCDepth(Average&Retrain)         DDAD  before_adaptation
# 102           FedSCDepth(Average&Retrain)        KITTI   after_adaptation
# 103           FedSCDepth(Average&Retrain)        KITTI   after_adaptation
# 104           FedSCDepth(Average&Retrain)        KITTI   after_adaptation
# 105           FedSCDepth(Average&Retrain)         DDAD   after_adaptation
# 106           FedSCDepth(Average&Retrain)         DDAD   after_adaptation
# 107           FedSCDepth(Average&Retrain)         DDAD   after_adaptation
# 108                 BOFedSCDepth(Retrain)        KITTI  before_adaptation
# 109                 BOFedSCDepth(Retrain)        KITTI  before_adaptation
# 110                 BOFedSCDepth(Retrain)        KITTI  before_adaptation
# 111                 BOFedSCDepth(Retrain)         DDAD  before_adaptation
# 112                 BOFedSCDepth(Retrain)         DDAD  before_adaptation
# 113                 BOFedSCDepth(Retrain)         DDAD  before_adaptation
# 114                 BOFedSCDepth(Retrain)        KITTI   after_adaptation
# 115                 BOFedSCDepth(Retrain)        KITTI   after_adaptation
# 116                 BOFedSCDepth(Retrain)        KITTI   after_adaptation
# 117                 BOFedSCDepth(Retrain)         DDAD   after_adaptation
# 118                 BOFedSCDepth(Retrain)         DDAD   after_adaptation
# 119                 BOFedSCDepth(Retrain)         DDAD   after_adaptation
# 120                   FedSCDepth(Retrain)        KITTI  before_adaptation
# 121                   FedSCDepth(Retrain)        KITTI  before_adaptation
# 122                   FedSCDepth(Retrain)        KITTI  before_adaptation
# 123                   FedSCDepth(Retrain)         DDAD  before_adaptation
# 124                   FedSCDepth(Retrain)         DDAD  before_adaptation
# 125                   FedSCDepth(Retrain)         DDAD  before_adaptation
# 126                   FedSCDepth(Retrain)        KITTI   after_adaptation
# 127                   FedSCDepth(Retrain)        KITTI   after_adaptation
# 128                   FedSCDepth(Retrain)        KITTI   after_adaptation
# 129                   FedSCDepth(Retrain)         DDAD   after_adaptation
# 130                   FedSCDepth(Retrain)         DDAD   after_adaptation
# 131                   FedSCDepth(Retrain)         DDAD   after_adaptation
# 132                   FedSCDepth(Average)        KITTI  before_adaptation
# 133                   FedSCDepth(Average)        KITTI  before_adaptation
# 134                   FedSCDepth(Average)        KITTI  before_adaptation
# 135                   FedSCDepth(Average)         DDAD  before_adaptation
# 136                   FedSCDepth(Average)         DDAD  before_adaptation
# 137                   FedSCDepth(Average)         DDAD  before_adaptation
# 138                   FedSCDepth(Average)        KITTI   after_adaptation
# 139                   FedSCDepth(Average)        KITTI   after_adaptation
# 140                   FedSCDepth(Average)        KITTI   after_adaptation
# 141                   FedSCDepth(Average)         DDAD   after_adaptation
# 142                   FedSCDepth(Average)         DDAD   after_adaptation
# 143                   FedSCDepth(Average)         DDAD   after_adaptation
# 144           FedSCDepth(Average&Retrain)        KITTI  before_adaptation
# 145           FedSCDepth(Average&Retrain)        KITTI  before_adaptation
# 146           FedSCDepth(Average&Retrain)        KITTI  before_adaptation
# 147           FedSCDepth(Average&Retrain)         DDAD  before_adaptation
# 148           FedSCDepth(Average&Retrain)         DDAD  before_adaptation
# 149           FedSCDepth(Average&Retrain)         DDAD  before_adaptation
# 150           FedSCDepth(Average&Retrain)        KITTI   after_adaptation
# 151           FedSCDepth(Average&Retrain)        KITTI   after_adaptation
# 152           FedSCDepth(Average&Retrain)        KITTI   after_adaptation
# 153           FedSCDepth(Average&Retrain)         DDAD   after_adaptation
# 154           FedSCDepth(Average&Retrain)         DDAD   after_adaptation
# 155           FedSCDepth(Average&Retrain)         DDAD   after_adaptation
# 156                 BOFedSCDepth(Retrain)        KITTI  before_adaptation
# 157                 BOFedSCDepth(Retrain)        KITTI  before_adaptation
# 158                 BOFedSCDepth(Retrain)        KITTI  before_adaptation
# 159                 BOFedSCDepth(Retrain)         DDAD  before_adaptation
# 160                 BOFedSCDepth(Retrain)         DDAD  before_adaptation
# 161                 BOFedSCDepth(Retrain)         DDAD  before_adaptation
# 162                 BOFedSCDepth(Retrain)        KITTI   after_adaptation
# 163                 BOFedSCDepth(Retrain)        KITTI   after_adaptation
# 164                 BOFedSCDepth(Retrain)        KITTI   after_adaptation
# 165                 BOFedSCDepth(Retrain)         DDAD   after_adaptation
# 166                 BOFedSCDepth(Retrain)         DDAD   after_adaptation
# 167                 BOFedSCDepth(Retrain)         DDAD   after_adaptation
# 168         BOFedSCDepth(ConstrainedLoss)        KITTI  before_adaptation
# 169         BOFedSCDepth(ConstrainedLoss)        KITTI  before_adaptation
# 170         BOFedSCDepth(ConstrainedLoss)        KITTI  before_adaptation
# 171         BOFedSCDepth(ConstrainedLoss)         DDAD  before_adaptation
# 172         BOFedSCDepth(ConstrainedLoss)         DDAD  before_adaptation
# 173         BOFedSCDepth(ConstrainedLoss)         DDAD  before_adaptation
# 174         BOFedSCDepth(ConstrainedLoss)        KITTI   after_adaptation
# 175         BOFedSCDepth(ConstrainedLoss)        KITTI   after_adaptation
# 176         BOFedSCDepth(ConstrainedLoss)        KITTI   after_adaptation
# 177         BOFedSCDepth(ConstrainedLoss)         DDAD   after_adaptation
# 178         BOFedSCDepth(ConstrainedLoss)         DDAD   after_adaptation
# 179         BOFedSCDepth(ConstrainedLoss)         DDAD   after_adaptation
# 180  BOFedSCDepth(ConstrainedLossRetrain)        KITTI  before_adaptation
# 181  BOFedSCDepth(ConstrainedLossRetrain)        KITTI  before_adaptation
# 182  BOFedSCDepth(ConstrainedLossRetrain)        KITTI  before_adaptation
# 183  BOFedSCDepth(ConstrainedLossRetrain)         DDAD  before_adaptation
# 184  BOFedSCDepth(ConstrainedLossRetrain)         DDAD  before_adaptation
# 185  BOFedSCDepth(ConstrainedLossRetrain)         DDAD  before_adaptation
# 186  BOFedSCDepth(ConstrainedLossRetrain)        KITTI   after_adaptation
# 187  BOFedSCDepth(ConstrainedLossRetrain)        KITTI   after_adaptation
# 188  BOFedSCDepth(ConstrainedLossRetrain)        KITTI   after_adaptation
# 189  BOFedSCDepth(ConstrainedLossRetrain)         DDAD   after_adaptation
# 190  BOFedSCDepth(ConstrainedLossRetrain)         DDAD   after_adaptation
# 191  BOFedSCDepth(ConstrainedLossRetrain)         DDAD   after_adaptation
# 192         BOFedSCDepth(ConstrainedLoss)        KITTI  before_adaptation
# 193         BOFedSCDepth(ConstrainedLoss)        KITTI  before_adaptation
# 194         BOFedSCDepth(ConstrainedLoss)        KITTI  before_adaptation
# 195         BOFedSCDepth(ConstrainedLoss)         DDAD  before_adaptation
# 196         BOFedSCDepth(ConstrainedLoss)         DDAD  before_adaptation
# 197         BOFedSCDepth(ConstrainedLoss)         DDAD  before_adaptation
# 198         BOFedSCDepth(ConstrainedLoss)        KITTI   after_adaptation
# 199         BOFedSCDepth(ConstrainedLoss)        KITTI   after_adaptation
# 200         BOFedSCDepth(ConstrainedLoss)        KITTI   after_adaptation
# 201         BOFedSCDepth(ConstrainedLoss)         DDAD   after_adaptation
# 202         BOFedSCDepth(ConstrainedLoss)         DDAD   after_adaptation
# 203         BOFedSCDepth(ConstrainedLoss)         DDAD   after_adaptation
# 204  BOFedSCDepth(ConstrainedLossRetrain)        KITTI  before_adaptation
# 205  BOFedSCDepth(ConstrainedLossRetrain)        KITTI  before_adaptation
# 206  BOFedSCDepth(ConstrainedLossRetrain)        KITTI  before_adaptation
# 207  BOFedSCDepth(ConstrainedLossRetrain)         DDAD  before_adaptation
# 208  BOFedSCDepth(ConstrainedLossRetrain)         DDAD  before_adaptation
# 209  BOFedSCDepth(ConstrainedLossRetrain)         DDAD  before_adaptation
# 210  BOFedSCDepth(ConstrainedLossRetrain)        KITTI   after_adaptation
# 211  BOFedSCDepth(ConstrainedLossRetrain)        KITTI   after_adaptation
# 212  BOFedSCDepth(ConstrainedLossRetrain)        KITTI   after_adaptation
# 213  BOFedSCDepth(ConstrainedLossRetrain)         DDAD   after_adaptation
# 214  BOFedSCDepth(ConstrainedLossRetrain)         DDAD   after_adaptation
# 215  BOFedSCDepth(ConstrainedLossRetrain)         DDAD   after_adaptation
#
#     test_region_type  test_abs_rel  test_sq_rel  test_log10  test_rmse  \
# 0               full         0.115        0.742       0.050      4.555
# 1            dynamic         0.191        2.072       0.084      7.111
# 2             static         0.106        0.638       0.046      4.275
# 3               full         0.222        4.843       0.109     21.075
# 4            dynamic         0.227        5.795       0.112     19.942
# 5             static         0.226        5.041       0.111     21.395
# 6               full         0.264        3.932       0.095      9.503
# 7            dynamic         0.359        6.881       0.131     11.690
# 8             static         0.262        3.987       0.093      9.452
# 9               full         0.142        2.992       0.063     15.056
# 10           dynamic         0.217        5.253       0.094     16.967
# 11            static         0.139        2.993       0.062     15.067
# 12              full         0.120        0.762       0.052      4.667
# 13           dynamic         0.214        2.382       0.090      7.410
# 14            static         0.109        0.633       0.047      4.378
# 15              full         0.246        5.862       0.123     23.383
# 16           dynamic         0.256        7.411       0.131     22.544
# 17            static         0.251        6.099       0.126     23.748
# 18              full         0.219        2.239       0.083      7.099
# 19           dynamic         0.322        4.645       0.119      9.707
# 20            static         0.212        2.187       0.080      6.940
# 21              full         0.156        3.433       0.075     17.543
# 22           dynamic         0.223        4.845       0.100     17.650
# 23            static         0.152        3.471       0.073     17.642
# 24              full         0.125        0.777       0.055      4.757
# 25           dynamic         0.219        2.299       0.092      7.430
# 26            static         0.114        0.658       0.050      4.512
# 27              full         0.247        5.691       0.122     22.913
# 28           dynamic         0.266        7.465       0.134     22.468
# 29            static         0.251        5.899       0.124     23.243
# 30              full         0.203        2.141       0.077      7.010
# 31           dynamic         0.306        4.640       0.116      9.770
# 32            static         0.196        2.096       0.074      6.843
# 33              full         0.150        3.279       0.072     17.040
# 34           dynamic         0.209        4.617       0.096     17.301
# 35            static         0.147        3.322       0.071     17.142
# 36              full         0.330        4.442       0.123      9.573
# 37           dynamic         0.429        8.628       0.151     12.384
# 38            static         0.326        4.348       0.121      9.433
# 39              full         0.152        3.157       0.068     15.638
# 40           dynamic         0.221        4.707       0.096     16.454
# 41            static         0.148        3.149       0.066     15.656
# 42              full         0.115        0.766       0.051      4.675
# 43           dynamic         0.209        2.531       0.089      7.639
# 44            static         0.107        0.651       0.046      4.384
# 45              full         0.240        5.242       0.118     21.523
# 46           dynamic         0.233        5.959       0.114     19.961
# 47            static         0.247        5.502       0.122     21.893
# 48              full         0.628       14.184       0.355     12.369
# 49           dynamic         0.549       13.785       0.280     13.361
# 50            static         0.628       14.106       0.354     12.623
# 51              full         0.364        8.693       0.229     26.120
# 52           dynamic         0.351       11.741       0.198     27.155
# 53            static         0.382        9.769       0.236     26.557
# 54              full         0.119        0.794       0.051      4.607
# 55           dynamic         0.223        2.871       0.092      7.816
# 56            static         0.109        0.654       0.046      4.258
# 57              full         0.214        4.996       0.107     21.585
# 58           dynamic         0.236        6.360       0.118     20.786
# 59            static         0.217        5.186       0.109     21.903
# 60              full         0.321        3.100       0.124      7.479
# 61           dynamic         0.396        5.569       0.143      9.836
# 62            static         0.306        2.874       0.119      7.266
# 63              full         0.215        5.412       0.113     22.755
# 64           dynamic         0.272        7.901       0.137     22.914
# 65            static         0.213        5.535       0.114     23.021
# 66              full         0.114        0.708       0.051      4.636
# 67           dynamic         0.196        2.155       0.086      7.207
# 68            static         0.105        0.603       0.046      4.383
# 69              full         0.227        5.246       0.113     22.061
# 70           dynamic         0.239        6.568       0.122     21.354
# 71            static         0.232        5.461       0.116     22.392
# 72              full         0.120        0.762       0.052      4.667
# 73           dynamic         0.214        2.382       0.090      7.410
# 74            static         0.109        0.633       0.047      4.378
# 75              full         0.246        5.862       0.123     23.383
# 76           dynamic         0.256        7.411       0.131     22.544
# 77            static         0.251        6.099       0.126     23.748
# 78              full         0.170        1.204       0.069      5.266
# 79           dynamic         0.262        2.956       0.104      7.857
# 80            static         0.159        1.107       0.064      5.036
# 81              full         0.175        3.970       0.085     19.397
# 82           dynamic         0.235        5.756       0.112     19.740
# 83            static         0.171        4.047       0.084     19.566
# 84              full         0.120        0.762       0.052      4.667
# 85           dynamic         0.214        2.382       0.090      7.410
# 86            static         0.109        0.633       0.047      4.378
# 87              full         0.246        5.862       0.123     23.383
# 88           dynamic         0.256        7.411       0.131     22.544
# 89            static         0.251        6.099       0.126     23.748
# 90              full         0.229        2.623       0.086      7.727
# 91           dynamic         0.335        5.316       0.123     10.329
# 92            static         0.222        2.579       0.083      7.580
# 93              full         0.154        3.296       0.073     16.938
# 94           dynamic         0.219        4.718       0.099     17.303
# 95            static         0.150        3.339       0.072     17.046
# 96              full         0.120        0.762       0.052      4.667
# 97           dynamic         0.214        2.382       0.090      7.410
# 98            static         0.109        0.633       0.047      4.378
# 99              full         0.246        5.862       0.123     23.383
# 100          dynamic         0.256        7.411       0.131     22.544
# 101           static         0.251        6.099       0.126     23.748
# 102             full         0.198        1.807       0.077      6.329
# 103          dynamic         0.302        4.140       0.114      9.111
# 104           static         0.188        1.708       0.073      6.106
# 105             full         0.163        3.392       0.076     17.386
# 106          dynamic         0.228        5.004       0.102     17.909
# 107           static         0.159        3.434       0.075     17.507
# 108             full         0.125        0.777       0.055      4.757
# 109          dynamic         0.219        2.299       0.092      7.430
# 110           static         0.114        0.658       0.050      4.512
# 111             full         0.247        5.691       0.122     22.913
# 112          dynamic         0.266        7.465       0.134     22.468
# 113           static         0.251        5.899       0.124     23.243
# 114             full         0.204        1.912       0.079      6.602
# 115          dynamic         0.302        4.160       0.115      9.292
# 116           static         0.197        1.846       0.076      6.417
# 117             full         0.153        3.310       0.073     17.095
# 118          dynamic         0.217        4.746       0.099     17.457
# 119           static         0.149        3.353       0.072     17.209
# 120             full         0.628       14.184       0.355     12.369
# 121          dynamic         0.549       13.785       0.280     13.361
# 122           static         0.628       14.106       0.354     12.623
# 123             full         0.364        8.693       0.229     26.120
# 124          dynamic         0.351       11.741       0.198     27.155
# 125           static         0.382        9.769       0.236     26.557
# 126             full         0.119        0.767       0.052      4.632
# 127          dynamic         0.213        2.716       0.090      7.674
# 128           static         0.109        0.645       0.047      4.328
# 129             full         0.216        4.896       0.108     21.308
# 130          dynamic         0.232        6.176       0.116     20.553
# 131           static         0.220        5.091       0.110     21.629
# 132             full         0.628       14.184       0.355     12.369
# 133          dynamic         0.549       13.785       0.280     13.361
# 134           static         0.628       14.106       0.354     12.623
# 135             full         0.364        8.693       0.229     26.120
# 136          dynamic         0.351       11.741       0.198     27.155
# 137           static         0.382        9.769       0.236     26.557
# 138             full         0.121        0.808       0.052      4.698
# 139          dynamic         0.229        3.094       0.094      8.006
# 140           static         0.111        0.674       0.047      4.359
# 141             full         0.211        4.801       0.105     21.108
# 142          dynamic         0.229        5.956       0.113     20.143
# 143           static         0.215        4.991       0.107     21.426
# 144             full         0.628       14.184       0.355     12.369
# 145          dynamic         0.549       13.785       0.280     13.361
# 146           static         0.628       14.106       0.354     12.623
# 147             full         0.364        8.693       0.229     26.120
# 148          dynamic         0.351       11.741       0.198     27.155
# 149           static         0.382        9.769       0.236     26.557
# 150             full         0.118        0.738       0.052      4.728
# 151          dynamic         0.209        2.401       0.090      7.534
# 152           static         0.109        0.626       0.048      4.462
# 153             full         0.216        5.467       0.111     22.839
# 154          dynamic         0.246        7.287       0.128     22.405
# 155           static         0.220        5.668       0.113     23.162
# 156             full         0.321        3.100       0.124      7.479
# 157          dynamic         0.396        5.569       0.143      9.836
# 158           static         0.306        2.874       0.119      7.266
# 159             full         0.215        5.412       0.113     22.755
# 160          dynamic         0.272        7.901       0.137     22.914
# 161           static         0.213        5.535       0.114     23.021
# 162             full         0.117        0.761       0.051      4.600
# 163          dynamic         0.219        2.911       0.091      7.776
# 164           static         0.107        0.630       0.046      4.268
# 165             full         0.217        4.999       0.108     21.482
# 166          dynamic         0.235        6.130       0.116     20.475
# 167           static         0.220        5.191       0.111     21.798
# 168             full         0.125        0.777       0.055      4.757
# 169          dynamic         0.219        2.299       0.092      7.430
# 170           static         0.114        0.658       0.050      4.512
# 171             full         0.247        5.691       0.122     22.913
# 172          dynamic         0.266        7.465       0.134     22.468
# 173           static         0.251        5.899       0.124     23.243
# 174             full         0.224        2.527       0.084      7.583
# 175          dynamic         0.321        4.926       0.119      9.991
# 176           static         0.217        2.496       0.081      7.456
# 177             full         0.152        3.107       0.070     16.311
# 178          dynamic         0.218        4.619       0.097     16.942
# 179           static         0.148        3.135       0.069     16.398
# 180             full         0.125        0.777       0.055      4.757
# 181          dynamic         0.219        2.299       0.092      7.430
# 182           static         0.114        0.658       0.050      4.512
# 183             full         0.247        5.691       0.122     22.913
# 184          dynamic         0.266        7.465       0.134     22.468
# 185           static         0.251        5.899       0.124     23.243
# 186             full         0.221        2.427       0.083      7.404
# 187          dynamic         0.334        5.289       0.122     10.212
# 188           static         0.213        2.353       0.080      7.230
# 189             full         0.155        3.243       0.073     16.775
# 190          dynamic         0.224        4.814       0.100     17.299
# 191           static         0.152        3.283       0.071     16.885
# 192             full         0.321        3.100       0.124      7.479
# 193          dynamic         0.396        5.569       0.143      9.836
# 194           static         0.306        2.874       0.119      7.266
# 195             full         0.215        5.412       0.113     22.755
# 196          dynamic         0.272        7.901       0.137     22.914
# 197           static         0.213        5.535       0.114     23.021
# 198             full         0.119        0.755       0.052      4.701
# 199          dynamic         0.207        2.340       0.089      7.420
# 200           static         0.109        0.630       0.048      4.428
# 201             full         0.231        5.546       0.117     22.729
# 202          dynamic         0.249        7.100       0.128     22.084
# 203           static         0.235        5.763       0.119     23.065
# 204             full         0.321        3.100       0.124      7.479
# 205          dynamic         0.396        5.569       0.143      9.836
# 206           static         0.306        2.874       0.119      7.266
# 207             full         0.215        5.412       0.113     22.755
# 208          dynamic         0.272        7.901       0.137     22.914
# 209           static         0.213        5.535       0.114     23.021
# 210             full         0.115        0.750       0.050      4.569
# 211          dynamic         0.210        2.635       0.089      7.546
# 212           static         0.105        0.622       0.046      4.243
# 213             full         0.217        4.933       0.108     21.423
# 214          dynamic         0.236        6.193       0.116     20.536
# 215           static         0.220        5.130       0.110     21.758
#
#      test_rmse_log  test_a1  test_a2  test_a3
# 0            0.183    0.872    0.963    0.985
# 1            0.282    0.726    0.891    0.949
# 2            0.159    0.886    0.973    0.991
# 3            0.366    0.628    0.842    0.917
# 4            0.348    0.621    0.826    0.915
# 5            0.370    0.617    0.835    0.913
# 6            0.314    0.670    0.859    0.940
# 7            0.383    0.519    0.760    0.886
# 8            0.303    0.678    0.863    0.944
# 9            0.239    0.816    0.927    0.968
# 10           0.300    0.675    0.866    0.954
# 11           0.232    0.819    0.928    0.969
# 12           0.186    0.859    0.961    0.985
# 13           0.289    0.683    0.876    0.949
# 14           0.161    0.878    0.972    0.992
# 15           0.414    0.579    0.808    0.893
# 16           0.395    0.546    0.773    0.875
# 17           0.419    0.569    0.800    0.887
# 18           0.268    0.706    0.903    0.966
# 19           0.345    0.527    0.804    0.923
# 20           0.253    0.721    0.913    0.971
# 21           0.272    0.783    0.907    0.952
# 22           0.308    0.632    0.869    0.944
# 23           0.267    0.790    0.907    0.952
# 24           0.190    0.848    0.959    0.985
# 25           0.287    0.669    0.876    0.953
# 26           0.167    0.868    0.970    0.991
# 27           0.404    0.574    0.808    0.899
# 28           0.395    0.521    0.764    0.876
# 29           0.408    0.568    0.802    0.895
# 30           0.259    0.736    0.909    0.968
# 31           0.342    0.555    0.811    0.922
# 32           0.243    0.751    0.918    0.973
# 33           0.264    0.790    0.913    0.956
# 34           0.303    0.664    0.870    0.942
# 35           0.259    0.796    0.912    0.956
# 36           0.367    0.511    0.797    0.922
# 37           0.423    0.430    0.700    0.865
# 38           0.357    0.509    0.803    0.928
# 39           0.249    0.794    0.922    0.966
# 40           0.297    0.655    0.883    0.953
# 41           0.242    0.802    0.924    0.967
# 42           0.186    0.865    0.962    0.984
# 43           0.295    0.697    0.876    0.943
# 44           0.161    0.879    0.972    0.991
# 45           0.392    0.590    0.822    0.904
# 46           0.350    0.601    0.829    0.916
# 47           0.399    0.576    0.811    0.897
# 48           1.077    0.317    0.469    0.547
# 49           0.807    0.365    0.534    0.634
# 50           1.074    0.318    0.469    0.549
# 51           0.742    0.436    0.617    0.699
# 52           0.553    0.396    0.603    0.748
# 53           0.757    0.428    0.604    0.685
# 54           0.186    0.865    0.963    0.985
# 55           0.299    0.682    0.868    0.937
# 56           0.159    0.882    0.975    0.992
# 57           0.367    0.646    0.842    0.913
# 58           0.361    0.596    0.811    0.898
# 59           0.371    0.639    0.836    0.909
# 60           0.357    0.484    0.798    0.932
# 61           0.396    0.438    0.727    0.881
# 62           0.341    0.496    0.811    0.942
# 63           0.381    0.615    0.827    0.906
# 64           0.403    0.519    0.748    0.863
# 65           0.380    0.613    0.826    0.905
# 66           0.184    0.871    0.963    0.985
# 67           0.282    0.720    0.891    0.946
# 68           0.160    0.887    0.972    0.991
# 69           0.382    0.612    0.830    0.906
# 70           0.372    0.566    0.803    0.895
# 71           0.387    0.603    0.823    0.902
# 72           0.186    0.859    0.961    0.985
# 73           0.289    0.683    0.876    0.949
# 74           0.161    0.878    0.972    0.992
# 75           0.414    0.579    0.808    0.893
# 76           0.395    0.546    0.773    0.875
# 77           0.419    0.569    0.800    0.887
# 78           0.226    0.772    0.937    0.981
# 79           0.309    0.605    0.849    0.943
# 80           0.206    0.792    0.949    0.987
# 81           0.303    0.736    0.887    0.941
# 82           0.338    0.598    0.829    0.916
# 83           0.299    0.741    0.886    0.941
# 84           0.186    0.859    0.961    0.985
# 85           0.289    0.683    0.876    0.949
# 86           0.161    0.878    0.972    0.992
# 87           0.414    0.579    0.808    0.893
# 88           0.395    0.546    0.773    0.875
# 89           0.419    0.569    0.800    0.887
# 90           0.278    0.697    0.893    0.961
# 91           0.356    0.519    0.789    0.912
# 92           0.265    0.711    0.902    0.966
# 93           0.263    0.787    0.915    0.956
# 94           0.305    0.650    0.865    0.944
# 95           0.258    0.792    0.914    0.956
# 96           0.186    0.859    0.961    0.985
# 97           0.289    0.683    0.876    0.949
# 98           0.161    0.878    0.972    0.992
# 99           0.414    0.579    0.808    0.893
# 100          0.395    0.546    0.773    0.875
# 101          0.419    0.569    0.800    0.887
# 102          0.249    0.738    0.920    0.973
# 103          0.334    0.549    0.825    0.929
# 104          0.232    0.756    0.931    0.979
# 105          0.271    0.770    0.910    0.955
# 106          0.312    0.633    0.855    0.942
# 107          0.266    0.777    0.910    0.955
# 108          0.190    0.848    0.959    0.985
# 109          0.287    0.669    0.876    0.953
# 110          0.167    0.868    0.970    0.991
# 111          0.404    0.574    0.808    0.899
# 112          0.395    0.521    0.764    0.876
# 113          0.408    0.568    0.802    0.895
# 114          0.255    0.722    0.914    0.971
# 115          0.336    0.546    0.822    0.930
# 116          0.240    0.735    0.923    0.976
# 117          0.267    0.787    0.913    0.956
# 118          0.305    0.650    0.863    0.944
# 119          0.261    0.794    0.913    0.956
# 120          1.077    0.317    0.469    0.547
# 121          0.807    0.365    0.534    0.634
# 122          1.074    0.318    0.469    0.549
# 123          0.742    0.436    0.617    0.699
# 124          0.553    0.396    0.603    0.748
# 125          0.757    0.428    0.604    0.685
# 126          0.187    0.863    0.962    0.985
# 127          0.295    0.698    0.870    0.937
# 128          0.161    0.880    0.973    0.991
# 129          0.366    0.636    0.846    0.915
# 130          0.357    0.605    0.816    0.902
# 131          0.370    0.627    0.839    0.911
# 132          1.077    0.317    0.469    0.547
# 133          0.807    0.365    0.534    0.634
# 134          1.074    0.318    0.469    0.549
# 135          0.742    0.436    0.617    0.699
# 136          0.553    0.396    0.603    0.748
# 137          0.757    0.428    0.604    0.685
# 138          0.187    0.861    0.962    0.985
# 139          0.301    0.673    0.864    0.935
# 140          0.161    0.878    0.973    0.992
# 141          0.360    0.649    0.849    0.917
# 142          0.348    0.614    0.826    0.910
# 143          0.364    0.641    0.842    0.913
# 144          1.077    0.317    0.469    0.547
# 145          0.807    0.365    0.534    0.634
# 146          1.074    0.318    0.469    0.549
# 147          0.742    0.436    0.617    0.699
# 148          0.553    0.396    0.603    0.748
# 149          0.757    0.428    0.604    0.685
# 150          0.187    0.861    0.962    0.985
# 151          0.292    0.685    0.878    0.944
# 152          0.163    0.877    0.972    0.992
# 153          0.386    0.641    0.832    0.901
# 154          0.387    0.559    0.782    0.878
# 155          0.389    0.635    0.825    0.897
# 156          0.357    0.484    0.798    0.932
# 157          0.396    0.438    0.727    0.881
# 158          0.341    0.496    0.811    0.942
# 159          0.381    0.615    0.827    0.906
# 160          0.403    0.519    0.748    0.863
# 161          0.380    0.613    0.826    0.905
# 162          0.185    0.869    0.963    0.985
# 163          0.299    0.695    0.872    0.935
# 164          0.158    0.886    0.974    0.992
# 165          0.370    0.638    0.842    0.912
# 166          0.356    0.595    0.817    0.907
# 167          0.373    0.630    0.836    0.908
# 168          0.190    0.848    0.959    0.985
# 169          0.287    0.669    0.876    0.953
# 170          0.167    0.868    0.970    0.991
# 171          0.404    0.574    0.808    0.899
# 172          0.395    0.521    0.764    0.876
# 173          0.408    0.568    0.802    0.895
# 174          0.275    0.705    0.897    0.961
# 175          0.348    0.536    0.805    0.918
# 176          0.262    0.720    0.905    0.966
# 177          0.255    0.796    0.919    0.961
# 178          0.298    0.657    0.874    0.947
# 179          0.249    0.803    0.920    0.961
# 180          0.190    0.848    0.959    0.985
# 181          0.287    0.669    0.876    0.953
# 182          0.167    0.868    0.970    0.991
# 183          0.404    0.574    0.808    0.899
# 184          0.395    0.521    0.764    0.876
# 185          0.408    0.568    0.802    0.895
# 186          0.271    0.708    0.900    0.963
# 187          0.353    0.529    0.795    0.910
# 188          0.257    0.722    0.909    0.968
# 189          0.263    0.783    0.915    0.957
# 190          0.306    0.648    0.866    0.944
# 191          0.257    0.788    0.915    0.957
# 192          0.357    0.484    0.798    0.932
# 193          0.396    0.438    0.727    0.881
# 194          0.341    0.496    0.811    0.942
# 195          0.381    0.615    0.827    0.906
# 196          0.403    0.519    0.748    0.863
# 197          0.380    0.613    0.826    0.905
# 198          0.187    0.863    0.962    0.985
# 199          0.292    0.692    0.882    0.945
# 200          0.162    0.880    0.973    0.992
# 201          0.397    0.606    0.825    0.898
# 202          0.386    0.557    0.791    0.883
# 203          0.402    0.599    0.818    0.894
# 204          0.357    0.484    0.798    0.932
# 205          0.396    0.438    0.727    0.881
# 206          0.341    0.496    0.811    0.942
# 207          0.381    0.615    0.827    0.906
# 208          0.403    0.519    0.748    0.863
# 209          0.380    0.613    0.826    0.905
# 210          0.184    0.870    0.963    0.985
# 211          0.292    0.706    0.878    0.939
# 212          0.158    0.887    0.974    0.992
# 213          0.367    0.638    0.841    0.914
# 214          0.356    0.599    0.819    0.900
# 215          0.371    0.630    0.834    0.910

# %%
import pandas as pd

# Assuming result_df is your input DataFrame
#metrics = ['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log', 'test_a1', 'test_a2', 'test_a3']
metrics = ['test_abs_rel']

# Function to compute the differences between metrics for each group
def compute_metric_differences(group):
    before_adaptation_group = group[group['adaptation_state'] == 'before_adaptation']
    before_adaptation_row = {metric: None for metric in metrics}
    if len(before_adaptation_group) > 0:
        before_adaptation_row = before_adaptation_group.iloc[0]
    after_adaptation_group = group[group['adaptation_state'] == 'after_adaptation']
    after_adaptation_row = {metric: None for metric in metrics}
    if len(after_adaptation_group) > 0:
        after_adaptation_row = after_adaptation_group.iloc[0]
    differences = {}
    for metric in metrics:
        differences[metric] = None
        if before_adaptation_row[metric] and after_adaptation_row[metric]:
            differences[metric] = (before_adaptation_row[metric] - after_adaptation_row[metric]) / before_adaptation_row[metric]
    return pd.Series(differences)

# Grouping by the specified columns and applying the function to compute differences
result_change_df = result_df.groupby(['source_train_dataset', 'target_train_dataset', 'training_method', 'test_dataset', 'test_region_type']).apply(compute_metric_differences).reset_index()

# Renaming columns for clarity
renamed_columns = ['source_train_dataset', 'target_train_dataset', 'training_method', 'test_dataset', 'test_region_type']
renamed_metrics = [f'{metric}_diff_prop' for metric in metrics]
renamed_columns.extend(renamed_metrics)
result_change_df.columns = renamed_columns

# Dropping NaNs
result_change_df = result_change_df.dropna()

# Displaying the resulting DataFrame
display(result_change_df)
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_abs_rel_diff_prop
# 0                  0.121324
# 1                 -0.055814
# 2                 -0.089202
# 3                  0.505051
# 4                  0.644860
# 5                  0.656863
# 6                  0.084559
# 7                 -0.074419
# 8                 -0.103286
# 9                  0.477273
# 10                 0.629283
# 11                 0.643791
# 12                 0.132353
# 13                -0.009302
# 14                -0.032864
# 15                 0.469697
# 16                 0.641745
# 17                 0.656863
# 18                 0.136029
# 19                -0.009302
# 20                -0.032864
# 21                 0.446970
# 22                 0.635514
# 23                 0.650327
# 24                 0.327635
# 25                 0.412088
# 26                 0.431937
# 27                 0.593807
# 28                 0.810510
# 29                 0.826433
# 30                 0.299145
# 31                 0.406593
# 32                 0.424084
# 33                 0.619308
# 34                 0.812102
# 35                 0.826433
# 36                 0.347578
# 37                 0.420330
# 38                 0.437173
# 39                 0.582878
# 40                 0.807325
# 41                 0.823248
# 42                 0.339031
# 43                 0.406593
# 44                 0.424084
# 45                 0.612022
# 46                 0.810510
# 47                 0.826433
# 48                -0.054299
# 49                -0.578947
# 50                -0.668919
# 51                 0.512821
# 52                 0.651515
# 53                 0.671779
# 54                 0.214286
# 55                 0.392713
# 56                 0.414343
# 57                -0.397260
# 58                -0.624000
# 59                -0.719298
# 60                 0.180451
# 61                 0.384615
# 62                 0.410359
# 63                -0.465753
# 64                -0.792000
# 65                -0.903509
# 66                 0.157895
# 67                 0.372470
# 68                 0.394422
# 69                -0.525114
# 70                -0.768000
# 71                -0.868421
# 72                 0.184211
# 73                 0.380567
# 74                 0.406375
# 75                -0.378995
# 76                -0.632000
# 77                -0.728070
# 78                 0.128906
# 79                 0.365854
# 80                 0.394422
# 81                -0.504673
# 82                -0.825000
# 83                -0.944954
# 84                 0.109375
# 85                 0.337398
# 86                 0.366534
# 87                -0.411215
# 88                -0.650000
# 89                -0.724771
# 90                 0.144531
# 91                 0.373984
# 92                 0.402390
# 93                -0.565421
# 94                -0.908333
# 95                -1.036697
# 96                 0.082031
# 97                 0.288618
# 98                 0.318725
# 99                -0.224299
# 100               -0.416667
# 101               -0.458716
# 102                0.044053
# 103                0.360360
# 104                0.384956
# 105               -0.879581
# 106               -1.295652
# 107               -1.471698

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


def plot_diff_prop(df, region_type, source_train_dataset, target_train_dataset):
    # Plotting using Seaborn
    melted_df = pd.melt(df, id_vars=['training_method'], var_name='metric', value_name='value')
    plt.figure(figsize=(12, 8))
    sns.barplot(x='metric', y='value', hue='training_method', data=melted_df, palette='Set2')
    plt.title(f'Difference Proportions Across Test Metrics by Training Method for {region_type} regions in {source_train_dataset} to {target_train_dataset} Domain Adaptation Experiment')
    plt.xlabel('Metric')
    plt.ylabel('Difference Proportion')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.legend(title='Training Method', loc='upper right')
    plt.show()

# %%
for source_train_dataset in result_change_df['source_train_dataset'].unique():
    for target_train_dataset in result_change_df['target_train_dataset'].unique():
        scenario_df = result_change_df[(result_change_df['source_train_dataset'] == source_train_dataset) & (result_change_df['target_train_dataset'] == target_train_dataset)]
        if len(scenario_df) == 0:
            continue # skip
        scenario_df = scenario_df.drop(columns=['source_train_dataset', 'target_train_dataset'])
        for region_type in scenario_df['test_region_type'].unique():
            kitti_to_ddad_by_region_type_df = scenario_df[scenario_df['test_region_type'] == region_type]
            kitti_to_ddad_by_region_type_df = kitti_to_ddad_by_region_type_df.drop(columns=['test_region_type'])
            label_metric = lambda metric: metric.replace('test_', "").replace("_diff_prop", "").replace("_", " ").upper()
            metric_labels = [ label_metric(metric) for metric in renamed_metrics ]
            renamed_columns = ['training_method', 'test_dataset']
            renamed_columns.extend(metric_labels)
            kitti_to_ddad_by_region_type_df.columns = renamed_columns
            kitti_to_ddad_by_region_type_melted_df = pd.melt(kitti_to_ddad_by_region_type_df, id_vars=['training_method', 'test_dataset'], var_name='metric', value_name='value')
            pivoted_df = kitti_to_ddad_by_region_type_melted_df.pivot(index='training_method', columns=['test_dataset', 'metric'], values='value')
            pivoted_df.columns = [f"{col[1]} ({col[0]})" for col in pivoted_df.columns]
            pivoted_df = pivoted_df.reset_index()
            display(pivoted_df)
            plot_diff_prop(pivoted_df, region_type, source_train_dataset, target_train_dataset)
# Out:
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth        0.121324         0.505051
# 1         BOFedSCDepth(ConstrainedLoss)        0.084559         0.477273
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.132353         0.469697
# 3                 BOFedSCDepth(Retrain)        0.136029         0.446970
# 4                            FedSCDepth        0.327635         0.593807
# 5           FedSCDepth(Average&Retrain)        0.299145         0.619308
# 6                   FedSCDepth(Average)        0.347578         0.582878
# 7                   FedSCDepth(Retrain)        0.339031         0.612022
# 8                               SCDepth       -0.054299         0.512821
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth       -0.055814         0.644860
# 1         BOFedSCDepth(ConstrainedLoss)       -0.074419         0.629283
# 2  BOFedSCDepth(ConstrainedLossRetrain)       -0.009302         0.641745
# 3                 BOFedSCDepth(Retrain)       -0.009302         0.635514
# 4                            FedSCDepth        0.412088         0.810510
# 5           FedSCDepth(Average&Retrain)        0.406593         0.812102
# 6                   FedSCDepth(Average)        0.420330         0.807325
# 7                   FedSCDepth(Retrain)        0.406593         0.810510
# 8                               SCDepth       -0.578947         0.651515
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth       -0.089202         0.656863
# 1         BOFedSCDepth(ConstrainedLoss)       -0.103286         0.643791
# 2  BOFedSCDepth(ConstrainedLossRetrain)       -0.032864         0.656863
# 3                 BOFedSCDepth(Retrain)       -0.032864         0.650327
# 4                            FedSCDepth        0.431937         0.826433
# 5           FedSCDepth(Average&Retrain)        0.424084         0.826433
# 6                   FedSCDepth(Average)        0.437173         0.823248
# 7                   FedSCDepth(Retrain)        0.424084         0.826433
# 8                               SCDepth       -0.668919         0.671779
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth        0.214286        -0.397260
# 1         BOFedSCDepth(ConstrainedLoss)        0.180451        -0.465753
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.157895        -0.525114
# 3                 BOFedSCDepth(Retrain)        0.184211        -0.378995
# 4                            FedSCDepth        0.128906        -0.504673
# 5           FedSCDepth(Average&Retrain)        0.109375        -0.411215
# 6                   FedSCDepth(Average)        0.144531        -0.565421
# 7                   FedSCDepth(Retrain)        0.082031        -0.224299
# 8                               SCDepth        0.044053        -0.879581
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth        0.392713        -0.624000
# 1         BOFedSCDepth(ConstrainedLoss)        0.384615        -0.792000
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.372470        -0.768000
# 3                 BOFedSCDepth(Retrain)        0.380567        -0.632000
# 4                            FedSCDepth        0.365854        -0.825000
# 5           FedSCDepth(Average&Retrain)        0.337398        -0.650000
# 6                   FedSCDepth(Average)        0.373984        -0.908333
# 7                   FedSCDepth(Retrain)        0.288618        -0.416667
# 8                               SCDepth        0.360360        -1.295652
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth        0.414343        -0.719298
# 1         BOFedSCDepth(ConstrainedLoss)        0.410359        -0.903509
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.394422        -0.868421
# 3                 BOFedSCDepth(Retrain)        0.406375        -0.728070
# 4                            FedSCDepth        0.394422        -0.944954
# 5           FedSCDepth(Average&Retrain)        0.366534        -0.724771
# 6                   FedSCDepth(Average)        0.402390        -1.036697
# 7                   FedSCDepth(Retrain)        0.318725        -0.458716
# 8                               SCDepth        0.384956        -1.471698
