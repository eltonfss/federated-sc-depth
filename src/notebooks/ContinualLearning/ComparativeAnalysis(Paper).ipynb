# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
font = {'weight' : 'bold', 'size'   : 30}
plt.rc('font', **font)
colors = sns.color_palette("colorblind")
hatches = ['/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*']
from comparative_analysis import ComparativeAnalysis
analysis = ComparativeAnalysis("continuallearningexperiments.csv")
df = analysis.result_df
df = pd.concat(
    [
        df[df['training_method'] == 'FedSCDepth(Retrain)'], 
        df[df['training_method'] == 'FedSCDepth'],
        df[df['training_method'] == 'FedSCDepth(Average)'],
        df[df['training_method'] == 'FedSCDepth(Average&Retrain)'],
    ]
)
df = df.replace({'training_method': 'FedSCDepth(Average)'}, {'training_method': 'CFSCD'})
df = df.replace({'training_method': 'FedSCDepth(Retrain)'}, {'training_method': 'ERFSCD'})
df = df.replace({'training_method': 'FedSCDepth(Average&Retrain)'}, {'training_method': 'CERFSCD'})
df = df.replace({'training_method': 'FedSCDepth'}, {'training_method': 'FSCD'})
df_ddad = df[df['test_dataset'] == 'DDAD']
df_kitti = df[df['test_dataset'] == 'KITTI']
legend_configs = dict(loc='best', prop={'weight':'bold'}, title=None)

# %%
analysis.result_df = df_ddad
analysis.plot_metrics_differences(
    ['test_abs_rel', 'test_sq_rel', 'test_rmse', 'test_rmse_log'], 'full', 
    save_as_pdf=True, colors=colors, hatches=hatches, legend_configs=False
)
analysis.plot_metrics_differences(
    ['test_a1', 'test_a2', 'test_a3'], 'full', 
    save_as_pdf=True, colors=colors, hatches=hatches, legend_configs=legend_configs
)
# Out:
#    source_train_dataset target_train_dataset training_method test_dataset  \
# 0                  DDAD                KITTI         CERFSCD         DDAD
# 1                  DDAD                KITTI         CERFSCD         DDAD
# 2                  DDAD                KITTI         CERFSCD         DDAD
# 3                  DDAD                KITTI           CFSCD         DDAD
# 4                  DDAD                KITTI           CFSCD         DDAD
# 5                  DDAD                KITTI           CFSCD         DDAD
# 6                  DDAD                KITTI          ERFSCD         DDAD
# 7                  DDAD                KITTI          ERFSCD         DDAD
# 8                  DDAD                KITTI          ERFSCD         DDAD
# 9                  DDAD                KITTI            FSCD         DDAD
# 10                 DDAD                KITTI            FSCD         DDAD
# 11                 DDAD                KITTI            FSCD         DDAD
# 12                KITTI                 DDAD         CERFSCD         DDAD
# 13                KITTI                 DDAD         CERFSCD         DDAD
# 14                KITTI                 DDAD         CERFSCD         DDAD
# 15                KITTI                 DDAD           CFSCD         DDAD
# 16                KITTI                 DDAD           CFSCD         DDAD
# 17                KITTI                 DDAD           CFSCD         DDAD
# 18                KITTI                 DDAD          ERFSCD         DDAD
# 19                KITTI                 DDAD          ERFSCD         DDAD
# 20                KITTI                 DDAD          ERFSCD         DDAD
# 21                KITTI                 DDAD            FSCD         DDAD
# 22                KITTI                 DDAD            FSCD         DDAD
# 23                KITTI                 DDAD            FSCD         DDAD
#
#    test_region_type  test_abs_rel  test_sq_rel  test_rmse  test_rmse_log
# 0           dynamic      0.299145     0.379354   0.174922       0.300181
# 1              full      0.406593     0.371103   0.125613       0.479784
# 2            static      0.424084     0.419797   0.127838       0.486129
# 3           dynamic      0.347578     0.492718   0.258221       0.370705
# 4              full      0.420330     0.447717   0.191884       0.514825
# 5            static      0.437173     0.489098   0.193207       0.519155
# 6           dynamic      0.339031     0.473980   0.243123       0.354430
# 7              full      0.406593     0.436788   0.184227       0.506739
# 8            static      0.424084     0.478862   0.185563       0.511229
# 9           dynamic      0.327635     0.458308   0.234542       0.347197
# 10             full      0.412088     0.425285   0.173622       0.505391
# 11           static      0.431937     0.469137   0.175246       0.509908
# 12          dynamic      0.109375     0.324787   0.205598       0.210127
# 13             full      0.337398     0.421358   0.256468       0.345411
# 14           static      0.366534     0.436957   0.262801       0.365155
# 15          dynamic      0.144531     0.363379   0.232479       0.227848
# 16             full      0.373984     0.437735   0.275628       0.364734
# 17           static      0.402390     0.452533   0.282213       0.384248
# 18          dynamic      0.082031     0.223317   0.124379       0.144304
# 19             full      0.288618     0.322757   0.170466       0.268116
# 20           static      0.318725     0.336449   0.176099       0.286396
# 21          dynamic      0.128906     0.346242   0.217087       0.220253
# 22             full      0.365854     0.414364   0.249754       0.342995
# 23           static      0.394422     0.430890   0.257116       0.362768
#   training_method   ABS REL    SQ REL      RMSE  RMSE LOG
# 0         CERFSCD  0.406593  0.371103  0.125613  0.479784
# 1           CFSCD  0.420330  0.447717  0.191884  0.514825
# 2          ERFSCD  0.406593  0.436788  0.184227  0.506739
# 3            FSCD  0.412088  0.425285  0.173622  0.505391
#   training_method   ABS REL    SQ REL      RMSE  RMSE LOG
# 0         CERFSCD  0.337398  0.421358  0.256468  0.345411
# 1           CFSCD  0.373984  0.437735  0.275628  0.364734
# 2          ERFSCD  0.288618  0.322757  0.170466  0.268116
# 3            FSCD  0.365854  0.414364  0.249754  0.342995
#    source_train_dataset target_train_dataset training_method test_dataset  \
# 0                  DDAD                KITTI         CERFSCD         DDAD
# 1                  DDAD                KITTI         CERFSCD         DDAD
# 2                  DDAD                KITTI         CERFSCD         DDAD
# 3                  DDAD                KITTI           CFSCD         DDAD
# 4                  DDAD                KITTI           CFSCD         DDAD
# 5                  DDAD                KITTI           CFSCD         DDAD
# 6                  DDAD                KITTI          ERFSCD         DDAD
# 7                  DDAD                KITTI          ERFSCD         DDAD
# 8                  DDAD                KITTI          ERFSCD         DDAD
# 9                  DDAD                KITTI            FSCD         DDAD
# 10                 DDAD                KITTI            FSCD         DDAD
# 11                 DDAD                KITTI            FSCD         DDAD
# 12                KITTI                 DDAD         CERFSCD         DDAD
# 13                KITTI                 DDAD         CERFSCD         DDAD
# 14                KITTI                 DDAD         CERFSCD         DDAD
# 15                KITTI                 DDAD           CFSCD         DDAD
# 16                KITTI                 DDAD           CFSCD         DDAD
# 17                KITTI                 DDAD           CFSCD         DDAD
# 18                KITTI                 DDAD          ERFSCD         DDAD
# 19                KITTI                 DDAD          ERFSCD         DDAD
# 20                KITTI                 DDAD          ERFSCD         DDAD
# 21                KITTI                 DDAD            FSCD         DDAD
# 22                KITTI                 DDAD            FSCD         DDAD
# 23                KITTI                 DDAD            FSCD         DDAD
#
#    test_region_type   test_a1   test_a2   test_a3
# 0           dynamic -0.411616 -0.296849 -0.173797
# 1              full -0.470183 -0.348460 -0.288984
# 2            static -0.483645 -0.365894 -0.309489
# 3           dynamic -0.550505 -0.369818 -0.216578
# 4              full -0.488532 -0.376013 -0.311874
# 5            static -0.497664 -0.394040 -0.332847
# 6           dynamic -0.527778 -0.353234 -0.205882
# 7              full -0.458716 -0.371151 -0.309013
# 8            static -0.464953 -0.389073 -0.329927
# 9           dynamic -0.505051 -0.344942 -0.200535
# 10             full -0.481651 -0.364668 -0.306152
# 11           static -0.492991 -0.384106 -0.327007
# 12          dynamic -0.159341 -0.106080 -0.076571
# 13             full -0.329879 -0.126238 -0.069429
# 14           static -0.365554 -0.137500 -0.076663
# 15          dynamic -0.190476 -0.119017 -0.078857
# 16             full -0.359240 -0.132426 -0.070549
# 17           static -0.391916 -0.142500 -0.077790
# 18          dynamic -0.095238 -0.072445 -0.046857
# 19             full -0.271157 -0.097772 -0.053751
# 20           static -0.302285 -0.107500 -0.060879
# 21          dynamic -0.157509 -0.124191 -0.078857
# 22             full -0.352332 -0.122525 -0.066069
# 23           static -0.388401 -0.133750 -0.073281
#   training_method        A1        A2        A3
# 0         CERFSCD -0.470183 -0.348460 -0.288984
# 1           CFSCD -0.488532 -0.376013 -0.311874
# 2          ERFSCD -0.458716 -0.371151 -0.309013
# 3            FSCD -0.481651 -0.364668 -0.306152
#   training_method        A1        A2        A3
# 0         CERFSCD -0.329879 -0.126238 -0.069429
# 1           CFSCD -0.359240 -0.132426 -0.070549
# 2          ERFSCD -0.271157 -0.097772 -0.053751
# 3            FSCD -0.352332 -0.122525 -0.066069

# %%
analysis.result_df = df_kitti
analysis.plot_metrics_differences(
    ['test_abs_rel', 'test_sq_rel', 'test_rmse', 'test_rmse_log'], 'full', 
    save_as_pdf=True, colors=colors, hatches=hatches, legend_configs=False
)
analysis.plot_metrics_differences(
    ['test_a1', 'test_a2', 'test_a3'], 'full', 
    save_as_pdf=True, colors=colors, hatches=hatches, legend_configs=legend_configs
)
# Out:
#    source_train_dataset target_train_dataset training_method test_dataset  \
# 0                  DDAD                KITTI         CERFSCD        KITTI
# 1                  DDAD                KITTI         CERFSCD        KITTI
# 2                  DDAD                KITTI         CERFSCD        KITTI
# 3                  DDAD                KITTI           CFSCD        KITTI
# 4                  DDAD                KITTI           CFSCD        KITTI
# 5                  DDAD                KITTI           CFSCD        KITTI
# 6                  DDAD                KITTI          ERFSCD        KITTI
# 7                  DDAD                KITTI          ERFSCD        KITTI
# 8                  DDAD                KITTI          ERFSCD        KITTI
# 9                  DDAD                KITTI            FSCD        KITTI
# 10                 DDAD                KITTI            FSCD        KITTI
# 11                 DDAD                KITTI            FSCD        KITTI
# 12                KITTI                 DDAD         CERFSCD        KITTI
# 13                KITTI                 DDAD         CERFSCD        KITTI
# 14                KITTI                 DDAD         CERFSCD        KITTI
# 15                KITTI                 DDAD           CFSCD        KITTI
# 16                KITTI                 DDAD           CFSCD        KITTI
# 17                KITTI                 DDAD           CFSCD        KITTI
# 18                KITTI                 DDAD          ERFSCD        KITTI
# 19                KITTI                 DDAD          ERFSCD        KITTI
# 20                KITTI                 DDAD          ERFSCD        KITTI
# 21                KITTI                 DDAD            FSCD        KITTI
# 22                KITTI                 DDAD            FSCD        KITTI
# 23                KITTI                 DDAD            FSCD        KITTI
#
#    test_region_type  test_abs_rel  test_sq_rel  test_rmse  test_rmse_log
# 0           dynamic      0.619308     0.825825   0.436120       0.638166
# 1              full      0.812102     0.947970   0.617754       0.826370
# 2            static      0.826433     0.955622   0.646518       0.848231
# 3           dynamic      0.582878     0.775553   0.400793       0.627014
# 4              full      0.807325     0.943034   0.620179       0.826370
# 5            static      0.823248     0.952219   0.654678       0.850093
# 6           dynamic      0.612022     0.802974   0.425642       0.634449
# 7              full      0.810510     0.945925   0.625515       0.826370
# 8            static      0.826433     0.954275   0.657134       0.850093
# 9           dynamic      0.593807     0.791730   0.415014       0.629492
# 10             full      0.810510     0.944021   0.627537       0.827298
# 11           static      0.826433     0.953637   0.662679       0.851955
# 12          dynamic     -0.411215    -0.738035  -0.229555      -0.155709
# 13             full     -0.650000    -1.371391  -0.356117      -0.338710
# 14           static     -0.724771    -1.698262  -0.394701      -0.440994
# 15          dynamic     -0.565421    -1.231738  -0.393927      -0.231834
# 16             full     -0.908333    -2.442257  -0.655667      -0.494624
# 17           static     -1.036697    -3.074250  -0.731384      -0.645963
# 18          dynamic     -0.224299    -0.240974  -0.060324      -0.069204
# 19             full     -0.416667    -0.580052  -0.128348      -0.215054
# 20           static     -0.458716    -0.748815  -0.150297      -0.279503
# 21          dynamic     -0.504673    -0.950042  -0.309987      -0.193772
# 22             full     -0.825000    -1.938320  -0.521106      -0.440860
# 23           static     -0.944954    -2.454976  -0.585199      -0.571429
#   training_method   ABS REL    SQ REL      RMSE  RMSE LOG
# 0         CERFSCD  0.812102  0.947970  0.617754  0.826370
# 1           CFSCD  0.807325  0.943034  0.620179  0.826370
# 2          ERFSCD  0.810510  0.945925  0.625515  0.826370
# 3            FSCD  0.810510  0.944021  0.627537  0.827298
#   training_method   ABS REL    SQ REL      RMSE  RMSE LOG
# 0         CERFSCD -0.650000 -1.371391 -0.356117 -0.338710
# 1           CFSCD -0.908333 -2.442257 -0.655667 -0.494624
# 2          ERFSCD -0.416667 -0.580052 -0.128348 -0.215054
# 3            FSCD -0.825000 -1.938320 -0.521106 -0.440860
#    source_train_dataset target_train_dataset training_method test_dataset  \
# 0                  DDAD                KITTI         CERFSCD        KITTI
# 1                  DDAD                KITTI         CERFSCD        KITTI
# 2                  DDAD                KITTI         CERFSCD        KITTI
# 3                  DDAD                KITTI           CFSCD        KITTI
# 4                  DDAD                KITTI           CFSCD        KITTI
# 5                  DDAD                KITTI           CFSCD        KITTI
# 6                  DDAD                KITTI          ERFSCD        KITTI
# 7                  DDAD                KITTI          ERFSCD        KITTI
# 8                  DDAD                KITTI          ERFSCD        KITTI
# 9                  DDAD                KITTI            FSCD        KITTI
# 10                 DDAD                KITTI            FSCD        KITTI
# 11                 DDAD                KITTI            FSCD        KITTI
# 12                KITTI                 DDAD         CERFSCD        KITTI
# 13                KITTI                 DDAD         CERFSCD        KITTI
# 14                KITTI                 DDAD         CERFSCD        KITTI
# 15                KITTI                 DDAD           CFSCD        KITTI
# 16                KITTI                 DDAD           CFSCD        KITTI
# 17                KITTI                 DDAD           CFSCD        KITTI
# 18                KITTI                 DDAD          ERFSCD        KITTI
# 19                KITTI                 DDAD          ERFSCD        KITTI
# 20                KITTI                 DDAD          ERFSCD        KITTI
# 21                KITTI                 DDAD            FSCD        KITTI
# 22                KITTI                 DDAD            FSCD        KITTI
# 23                KITTI                 DDAD            FSCD        KITTI
#
#    test_region_type   test_a1   test_a2   test_a3
# 0           dynamic -0.876712 -0.644195 -0.488959
# 1              full -1.716088 -1.051173 -0.800731
# 2            static -1.757862 -1.072495 -0.806922
# 3           dynamic -0.843836 -0.617978 -0.474763
# 4              full -1.716088 -1.051173 -0.800731
# 5            static -1.761006 -1.074627 -0.806922
# 6           dynamic -0.912329 -0.629213 -0.477918
# 7              full -1.722397 -1.051173 -0.800731
# 8            static -1.767296 -1.074627 -0.805100
# 9           dynamic -0.868493 -0.625468 -0.477918
# 10             full -1.728707 -1.053305 -0.800731
# 11           static -1.773585 -1.078891 -0.806922
# 12          dynamic  0.196193  0.058219  0.021075
# 13             full  0.140861  0.042664  0.012183
# 14           static  0.138952  0.042181  0.013105
# 15          dynamic  0.240117  0.099315  0.038988
# 16             full  0.188591  0.070760  0.024365
# 17           static  0.190205  0.072016  0.026210
# 18          dynamic  0.114202  0.030822  0.006322
# 19             full  0.101281  0.024974  0.004061
# 20           static  0.097950  0.023663  0.005040
# 21          dynamic  0.228404  0.082192  0.027397
# 22             full  0.178114  0.060354  0.019289
# 23           static  0.178815  0.060700  0.021169
#   training_method        A1        A2        A3
# 0         CERFSCD -1.716088 -1.051173 -0.800731
# 1           CFSCD -1.716088 -1.051173 -0.800731
# 2          ERFSCD -1.722397 -1.051173 -0.800731
# 3            FSCD -1.728707 -1.053305 -0.800731
#   training_method        A1        A2        A3
# 0         CERFSCD  0.140861  0.042664  0.012183
# 1           CFSCD  0.188591  0.070760  0.024365
# 2          ERFSCD  0.101281  0.024974  0.004061
# 3            FSCD  0.178114  0.060354  0.019289
