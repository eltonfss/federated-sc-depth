# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
from comparative_analysis import ComparativeAnalysis
analysis = ComparativeAnalysis("continuallearningexperiments.csv")

# %%
analysis.plot_metrics_differences(['test_abs_rel'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_abs_rel
# 0        0.121324
# 1       -0.055814
# 2       -0.089202
# 3        0.505051
# 4        0.644860
# 5        0.656863
# 6        0.084559
# 7       -0.074419
# 8       -0.103286
# 9        0.477273
# 10       0.629283
# 11       0.643791
# 12       0.132353
# 13      -0.009302
# 14      -0.032864
# 15       0.469697
# 16       0.641745
# 17       0.656863
# 18       0.136029
# 19      -0.009302
# 20      -0.032864
# 21       0.446970
# 22       0.635514
# 23       0.650327
# 24       0.327635
# 25       0.412088
# 26       0.431937
# 27       0.593807
# 28       0.810510
# 29       0.826433
# 30       0.299145
# 31       0.406593
# 32       0.424084
# 33       0.619308
# 34       0.812102
# 35       0.826433
# 36       0.347578
# 37       0.420330
# 38       0.437173
# 39       0.582878
# 40       0.807325
# 41       0.823248
# 42       0.339031
# 43       0.406593
# 44       0.424084
# 45       0.612022
# 46       0.810510
# 47       0.826433
# 48      -0.054299
# 49      -0.578947
# 50      -0.668919
# 51       0.512821
# 52       0.651515
# 53       0.671779
# 54       0.214286
# 55       0.392713
# 56       0.414343
# 57      -0.397260
# 58      -0.624000
# 59      -0.719298
# 60       0.180451
# 61       0.384615
# 62       0.410359
# 63      -0.465753
# 64      -0.792000
# 65      -0.903509
# 66       0.157895
# 67       0.372470
# 68       0.394422
# 69      -0.525114
# 70      -0.768000
# 71      -0.868421
# 72       0.184211
# 73       0.380567
# 74       0.406375
# 75      -0.378995
# 76      -0.632000
# 77      -0.728070
# 78       0.128906
# 79       0.365854
# 80       0.394422
# 81      -0.504673
# 82      -0.825000
# 83      -0.944954
# 84       0.109375
# 85       0.337398
# 86       0.366534
# 87      -0.411215
# 88      -0.650000
# 89      -0.724771
# 90       0.144531
# 91       0.373984
# 92       0.402390
# 93      -0.565421
# 94      -0.908333
# 95      -1.036697
# 96       0.082031
# 97       0.288618
# 98       0.318725
# 99      -0.224299
# 100     -0.416667
# 101     -0.458716
# 102      0.044053
# 103      0.360360
# 104      0.384956
# 105     -0.879581
# 106     -1.295652
# 107     -1.471698
#                         training_method   ABS REL   ABS REL
# 0                          BOFedSCDepth -0.055814  0.644860
# 1         BOFedSCDepth(ConstrainedLoss) -0.074419  0.629283
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.009302  0.641745
# 3                 BOFedSCDepth(Retrain) -0.009302  0.635514
# 4                            FedSCDepth  0.412088  0.810510
# 5           FedSCDepth(Average&Retrain)  0.406593  0.812102
# 6                   FedSCDepth(Average)  0.420330  0.807325
# 7                   FedSCDepth(Retrain)  0.406593  0.810510
# 8                               SCDepth -0.578947  0.651515
#                         training_method   ABS REL   ABS REL
# 0                          BOFedSCDepth  0.392713 -0.624000
# 1         BOFedSCDepth(ConstrainedLoss)  0.384615 -0.792000
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.372470 -0.768000
# 3                 BOFedSCDepth(Retrain)  0.380567 -0.632000
# 4                            FedSCDepth  0.365854 -0.825000
# 5           FedSCDepth(Average&Retrain)  0.337398 -0.650000
# 6                   FedSCDepth(Average)  0.373984 -0.908333
# 7                   FedSCDepth(Retrain)  0.288618 -0.416667
# 8                               SCDepth  0.360360 -1.295652

# %%
analysis.plot_metrics_differences(['test_sq_rel'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_sq_rel
# 0       0.168713
# 1       0.030673
# 2       0.013369
# 3       0.613036
# 4       0.771613
# 5       0.790188
# 6       0.101380
# 7      -0.024760
# 8      -0.041192
# 9       0.579817
# 10      0.756452
# 11      0.780793
# 12      0.216175
# 13      0.088507
# 14      0.073171
# 15      0.526845
# 16      0.758065
# 17      0.783577
# 18      0.224149
# 19      0.076312
# 20      0.062150
# 21      0.477285
# 22      0.754516
# 23      0.780793
# 24      0.458308
# 25      0.425285
# 26      0.469137
# 27      0.791730
# 28      0.944021
# 29      0.953637
# 30      0.379354
# 31      0.371103
# 32      0.419797
# 33      0.825825
# 34      0.947970
# 35      0.955622
# 36      0.492718
# 37      0.447717
# 38      0.489098
# 39      0.775553
# 40      0.943034
# 41      0.952219
# 42      0.473980
# 43      0.436788
# 44      0.478862
# 45      0.802974
# 46      0.945925
# 47      0.954275
# 48     -0.265987
# 49     -0.660437
# 50     -0.747221
# 51      0.706653
# 52      0.827555
# 53      0.850276
# 54      0.381514
# 55      0.423827
# 56      0.436854
# 57     -1.018269
# 58     -1.755470
# 59     -2.185410
# 60      0.381246
# 61      0.454050
# 62      0.468554
# 63     -1.142671
# 64     -2.252252
# 65     -2.793313
# 66      0.355124
# 67      0.430153
# 68      0.443465
# 69     -1.300565
# 70     -2.123552
# 71     -2.575988
# 72      0.364233
# 73      0.418380
# 74      0.431599
# 75     -0.809482
# 76     -1.460746
# 77     -1.805471
# 78      0.346242
# 79      0.414364
# 80      0.430890
# 81     -0.950042
# 82     -1.938320
# 83     -2.454976
# 84      0.324787
# 85      0.421358
# 86      0.436957
# 87     -0.738035
# 88     -1.371391
# 89     -1.698262
# 90      0.363379
# 91      0.437735
# 92      0.452533
# 93     -1.231738
# 94     -2.442257
# 95     -3.074250
# 96      0.223317
# 97      0.322757
# 98      0.336449
# 99     -0.240974
# 100    -0.580052
# 101    -0.748815
# 102     0.093529
# 103     0.382201
# 104     0.406269
# 105    -2.320946
# 106    -4.299191
# 107    -5.249216
#                         training_method    SQ REL    SQ REL
# 0                          BOFedSCDepth  0.030673  0.771613
# 1         BOFedSCDepth(ConstrainedLoss) -0.024760  0.756452
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.088507  0.758065
# 3                 BOFedSCDepth(Retrain)  0.076312  0.754516
# 4                            FedSCDepth  0.425285  0.944021
# 5           FedSCDepth(Average&Retrain)  0.371103  0.947970
# 6                   FedSCDepth(Average)  0.447717  0.943034
# 7                   FedSCDepth(Retrain)  0.436788  0.945925
# 8                               SCDepth -0.660437  0.827555
#                         training_method    SQ REL    SQ REL
# 0                          BOFedSCDepth  0.423827 -1.755470
# 1         BOFedSCDepth(ConstrainedLoss)  0.454050 -2.252252
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.430153 -2.123552
# 3                 BOFedSCDepth(Retrain)  0.418380 -1.460746
# 4                            FedSCDepth  0.414364 -1.938320
# 5           FedSCDepth(Average&Retrain)  0.421358 -1.371391
# 6                   FedSCDepth(Average)  0.437735 -2.442257
# 7                   FedSCDepth(Retrain)  0.322757 -0.580052
# 8                               SCDepth  0.382201 -4.299191

# %%
analysis.plot_metrics_differences(['test_log10'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_log10
# 0      0.109489
# 1      0.000000
# 2     -0.017544
# 3      0.398601
# 4      0.588710
# 5      0.613445
# 6      0.065693
# 7     -0.035398
# 8     -0.043860
# 9      0.377622
# 10     0.580645
# 11     0.596639
# 12     0.153285
# 13     0.044248
# 14     0.035088
# 15     0.377622
# 16     0.596774
# 17     0.613445
# 18     0.153285
# 19     0.044248
# 20     0.026316
# 21     0.363636
# 22     0.588710
# 23     0.613445
# 24     0.404040
# 25     0.532751
# 26     0.538136
# 27     0.671429
# 28     0.856338
# 29     0.870056
# 30     0.353535
# 31     0.515284
# 32     0.521186
# 33     0.678571
# 34     0.853521
# 35     0.864407
# 36     0.429293
# 37     0.541485
# 38     0.546610
# 39     0.664286
# 40     0.853521
# 41     0.867232
# 42     0.414141
# 43     0.528384
# 44     0.533898
# 45     0.678571
# 46     0.853521
# 47     0.867232
# 48    -0.187500
# 49    -0.735294
# 50    -0.848485
# 51     0.410596
# 52     0.585366
# 53     0.619835
# 54     0.283582
# 55     0.409836
# 56     0.427419
# 57    -0.260870
# 58    -0.400000
# 59    -0.480000
# 60     0.276119
# 61     0.426230
# 62     0.443548
# 63    -0.293478
# 64    -0.527273
# 65    -0.620000
# 66     0.253731
# 67     0.401639
# 68     0.427419
# 69    -0.326087
# 70    -0.509091
# 71    -0.600000
# 72     0.261194
# 73     0.401639
# 74     0.419355
# 75    -0.250000
# 76    -0.436364
# 77    -0.520000
# 78     0.236641
# 79     0.390244
# 80     0.420635
# 81    -0.322222
# 82    -0.596154
# 83    -0.702128
# 84     0.221374
# 85     0.382114
# 86     0.404762
# 87    -0.266667
# 88    -0.480769
# 89    -0.553191
# 90     0.244275
# 91     0.406504
# 92     0.428571
# 93    -0.366667
# 94    -0.653846
# 95    -0.765957
# 96     0.145038
# 97     0.308943
# 98     0.333333
# 99    -0.155556
# 100   -0.326923
# 101   -0.361702
# 102    0.160714
# 103    0.422018
# 104    0.441441
# 105   -0.559524
# 106   -0.900000
# 107   -1.021739
#                         training_method     LOG10     LOG10
# 0                          BOFedSCDepth  0.000000  0.588710
# 1         BOFedSCDepth(ConstrainedLoss) -0.035398  0.580645
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.044248  0.596774
# 3                 BOFedSCDepth(Retrain)  0.044248  0.588710
# 4                            FedSCDepth  0.532751  0.856338
# 5           FedSCDepth(Average&Retrain)  0.515284  0.853521
# 6                   FedSCDepth(Average)  0.541485  0.853521
# 7                   FedSCDepth(Retrain)  0.528384  0.853521
# 8                               SCDepth -0.735294  0.585366
#                         training_method     LOG10     LOG10
# 0                          BOFedSCDepth  0.409836 -0.400000
# 1         BOFedSCDepth(ConstrainedLoss)  0.426230 -0.527273
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.401639 -0.509091
# 3                 BOFedSCDepth(Retrain)  0.401639 -0.436364
# 4                            FedSCDepth  0.390244 -0.596154
# 5           FedSCDepth(Average&Retrain)  0.382114 -0.480769
# 6                   FedSCDepth(Average)  0.406504 -0.653846
# 7                   FedSCDepth(Retrain)  0.308943 -0.326923
# 8                               SCDepth  0.422018 -0.900000

# %%
analysis.plot_metrics_differences(['test_rmse'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_rmse
# 0     0.068081
# 1     0.030499
# 2     0.027323
# 3     0.267283
# 4     0.380131
# 5     0.396780
# 6     0.036222
# 7     0.001143
# 8    -0.001911
# 9     0.245628
# 10    0.371440
# 11    0.390586
# 12    0.103779
# 13    0.058537
# 14    0.054863
# 15    0.232818
# 16    0.389089
# 17    0.416047
# 18    0.106441
# 19    0.055944
# 20    0.053125
# 21    0.209435
# 22    0.384945
# 23    0.412607
# 24    0.234542
# 25    0.173622
# 26    0.175246
# 27    0.415014
# 28    0.627537
# 29    0.662679
# 30    0.174922
# 31    0.125613
# 32    0.127838
# 33    0.436120
# 34    0.617754
# 35    0.646518
# 36    0.258221
# 37    0.191884
# 38    0.193207
# 39    0.400793
# 40    0.620179
# 41    0.654678
# 42    0.243123
# 43    0.184227
# 44    0.185563
# 45    0.425642
# 46    0.625515
# 47    0.657134
# 48   -0.213140
# 49   -0.376327
# 50   -0.398378
# 51    0.383156
# 52    0.511647
# 53    0.535249
# 54    0.229972
# 55    0.256317
# 56    0.262488
# 57   -0.314939
# 58   -0.473618
# 59   -0.516622
# 60    0.245950
# 61    0.288133
# 62    0.294497
# 63   -0.344684
# 64   -0.594072
# 65   -0.652482
# 66    0.230061
# 67    0.267883
# 68    0.273545
# 69   -0.374428
# 70   -0.556443
# 71   -0.602394
# 72    0.223028
# 73    0.253917
# 74    0.259605
# 75   -0.250606
# 76   -0.387849
# 77   -0.422207
# 78    0.217087
# 79    0.249754
# 80    0.257116
# 81   -0.309987
# 82   -0.521106
# 83   -0.585199
# 84    0.205598
# 85    0.256468
# 86    0.262801
# 87   -0.229555
# 88   -0.356117
# 89   -0.394701
# 90    0.232479
# 91    0.275628
# 92    0.282213
# 93   -0.393927
# 94   -0.655667
# 95   -0.731384
# 96    0.124379
# 97    0.170466
# 98    0.176099
# 99   -0.060324
# 100  -0.128348
# 101  -0.150297
# 102   0.149183
# 103   0.285599
# 104   0.295770
# 105  -0.643932
# 106  -1.086279
# 107  -1.210994
#                         training_method      RMSE      RMSE
# 0                          BOFedSCDepth  0.030499  0.380131
# 1         BOFedSCDepth(ConstrainedLoss)  0.001143  0.371440
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.058537  0.389089
# 3                 BOFedSCDepth(Retrain)  0.055944  0.384945
# 4                            FedSCDepth  0.173622  0.627537
# 5           FedSCDepth(Average&Retrain)  0.125613  0.617754
# 6                   FedSCDepth(Average)  0.191884  0.620179
# 7                   FedSCDepth(Retrain)  0.184227  0.625515
# 8                               SCDepth -0.376327  0.511647
#                         training_method      RMSE      RMSE
# 0                          BOFedSCDepth  0.256317 -0.473618
# 1         BOFedSCDepth(ConstrainedLoss)  0.288133 -0.594072
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.267883 -0.556443
# 3                 BOFedSCDepth(Retrain)  0.253917 -0.387849
# 4                            FedSCDepth  0.249754 -0.521106
# 5           FedSCDepth(Average&Retrain)  0.256468 -0.356117
# 6                   FedSCDepth(Average)  0.275628 -0.655667
# 7                   FedSCDepth(Retrain)  0.170466 -0.128348
# 8                               SCDepth  0.285599 -1.086279

# %%
analysis.plot_metrics_differences(['test_rmse_log'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_rmse_log
# 0         0.076923
# 1        -0.002625
# 2        -0.018421
# 3         0.287879
# 4         0.484594
# 5         0.530792
# 6         0.042184
# 7        -0.041995
# 8        -0.057895
# 9         0.262626
# 10        0.476190
# 11        0.524927
# 12        0.116625
# 13        0.036745
# 14        0.023684
# 15        0.262626
# 16        0.484594
# 17        0.536657
# 18        0.116625
# 19        0.028871
# 20        0.018421
# 21        0.244949
# 22        0.481793
# 23        0.536657
# 24        0.347197
# 25        0.505391
# 26        0.509908
# 27        0.629492
# 28        0.827298
# 29        0.851955
# 30        0.300181
# 31        0.479784
# 32        0.486129
# 33        0.638166
# 34        0.826370
# 35        0.848231
# 36        0.370705
# 37        0.514825
# 38        0.519155
# 39        0.627014
# 40        0.826370
# 41        0.850093
# 42        0.354430
# 43        0.506739
# 44        0.511229
# 45        0.634449
# 46        0.826370
# 47        0.850093
# 48       -0.178451
# 49       -0.574297
# 50       -0.648760
# 51        0.302600
# 52        0.493188
# 53        0.549020
# 54        0.232911
# 55        0.346535
# 56        0.365196
# 57       -0.191638
# 58       -0.363158
# 59       -0.455090
# 60        0.245570
# 61        0.368812
# 62        0.389706
# 63       -0.212544
# 64       -0.447368
# 65       -0.568862
# 66        0.225316
# 67        0.349010
# 68        0.370098
# 69       -0.229965
# 70       -0.426316
# 71       -0.538922
# 72        0.227848
# 73        0.339109
# 74        0.360294
# 75       -0.170732
# 76       -0.342105
# 77       -0.437126
# 78        0.220253
# 79        0.342995
# 80        0.362768
# 81       -0.193772
# 82       -0.440860
# 83       -0.571429
# 84        0.210127
# 85        0.345411
# 86        0.365155
# 87       -0.155709
# 88       -0.338710
# 89       -0.440994
# 90        0.227848
# 91        0.364734
# 92        0.384248
# 93       -0.231834
# 94       -0.494624
# 95       -0.645963
# 96        0.144304
# 97        0.268116
# 98        0.286396
# 99       -0.069204
# 100      -0.215054
# 101      -0.279503
# 102       0.137931
# 103       0.346995
# 104       0.372973
# 105      -0.358156
# 106      -0.715847
# 107      -0.905660
#                         training_method  RMSE LOG  RMSE LOG
# 0                          BOFedSCDepth -0.002625  0.484594
# 1         BOFedSCDepth(ConstrainedLoss) -0.041995  0.476190
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.036745  0.484594
# 3                 BOFedSCDepth(Retrain)  0.028871  0.481793
# 4                            FedSCDepth  0.505391  0.827298
# 5           FedSCDepth(Average&Retrain)  0.479784  0.826370
# 6                   FedSCDepth(Average)  0.514825  0.826370
# 7                   FedSCDepth(Retrain)  0.506739  0.826370
# 8                               SCDepth -0.574297  0.493188
#                         training_method  RMSE LOG  RMSE LOG
# 0                          BOFedSCDepth  0.346535 -0.363158
# 1         BOFedSCDepth(ConstrainedLoss)  0.368812 -0.447368
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.349010 -0.426316
# 3                 BOFedSCDepth(Retrain)  0.339109 -0.342105
# 4                            FedSCDepth  0.342995 -0.440860
# 5           FedSCDepth(Average&Retrain)  0.345411 -0.338710
# 6                   FedSCDepth(Average)  0.364734 -0.494624
# 7                   FedSCDepth(Retrain)  0.268116 -0.215054
# 8                               SCDepth  0.346995 -0.715847

# %%
analysis.plot_metrics_differences(['test_a1'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#       test_a1
# 0   -0.090559
# 1    0.004878
# 2    0.016313
# 3   -0.643836
# 4   -0.799587
# 5   -0.788306
# 6   -0.073218
# 7    0.014634
# 8    0.022838
# 9   -0.579909
# 10  -0.783058
# 11  -0.774194
# 12  -0.154143
# 13  -0.037398
# 14  -0.027732
# 15  -0.611872
# 16  -0.797521
# 17  -0.788306
# 18  -0.146435
# 19  -0.037398
# 20  -0.027732
# 21  -0.586758
# 22  -0.795455
# 23  -0.786290
# 24  -0.505051
# 25  -0.481651
# 26  -0.492991
# 27  -0.868493
# 28  -1.728707
# 29  -1.773585
# 30  -0.411616
# 31  -0.470183
# 32  -0.483645
# 33  -0.876712
# 34  -1.716088
# 35  -1.757862
# 36  -0.550505
# 37  -0.488532
# 38  -0.497664
# 39  -0.843836
# 40  -1.716088
# 41  -1.761006
# 42  -0.527778
# 43  -0.458716
# 44  -0.464953
# 45  -0.912329
# 46  -1.722397
# 47  -1.767296
# 48   0.082443
# 49   0.256927
# 50   0.281796
# 51  -0.620930
# 52  -0.692759
# 53  -0.726916
# 54  -0.274472
# 55  -0.376307
# 56  -0.401408
# 57   0.170404
# 58   0.132075
# 59   0.134793
# 60  -0.261036
# 61  -0.386760
# 62  -0.413732
# 63   0.198804
# 64   0.168632
# 65   0.170507
# 66  -0.243762
# 67  -0.364111
# 68  -0.387324
# 69   0.209268
# 70   0.165094
# 71   0.168203
# 72  -0.247601
# 73  -0.371080
# 74  -0.397887
# 75   0.183857
# 76   0.148585
# 77   0.153226
# 78  -0.157509
# 79  -0.352332
# 80  -0.388401
# 81   0.228404
# 82   0.178114
# 83   0.178815
# 84  -0.159341
# 85  -0.329879
# 86  -0.365554
# 87   0.196193
# 88   0.140861
# 89   0.138952
# 90  -0.190476
# 91  -0.359240
# 92  -0.391916
# 93   0.240117
# 94   0.188591
# 95   0.190205
# 96  -0.095238
# 97  -0.271157
# 98  -0.302285
# 99   0.114202
# 100  0.101281
# 101  0.097950
# 102 -0.086957
# 103 -0.299363
# 104 -0.327391
# 105  0.285124
# 106  0.231651
# 107  0.234763
#                         training_method        A1        A1
# 0                          BOFedSCDepth  0.004878 -0.799587
# 1         BOFedSCDepth(ConstrainedLoss)  0.014634 -0.783058
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.037398 -0.797521
# 3                 BOFedSCDepth(Retrain) -0.037398 -0.795455
# 4                            FedSCDepth -0.481651 -1.728707
# 5           FedSCDepth(Average&Retrain) -0.470183 -1.716088
# 6                   FedSCDepth(Average) -0.488532 -1.716088
# 7                   FedSCDepth(Retrain) -0.458716 -1.722397
# 8                               SCDepth  0.256927 -0.692759
#                         training_method        A1        A1
# 0                          BOFedSCDepth -0.376307  0.132075
# 1         BOFedSCDepth(ConstrainedLoss) -0.386760  0.168632
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.364111  0.165094
# 3                 BOFedSCDepth(Retrain) -0.371080  0.148585
# 4                            FedSCDepth -0.352332  0.178114
# 5           FedSCDepth(Average&Retrain) -0.329879  0.140861
# 6                   FedSCDepth(Average) -0.359240  0.188591
# 7                   FedSCDepth(Retrain) -0.271157  0.101281
# 8                               SCDepth -0.299363  0.231651

# %%
analysis.plot_metrics_differences(['test_a2'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#       test_a2
# 0   -0.073529
# 1   -0.003628
# 2    0.003632
# 3   -0.225585
# 4   -0.206767
# 5   -0.198520
# 6   -0.057487
# 7    0.002418
# 8    0.009685
# 9   -0.213205
# 10  -0.205514
# 11  -0.199753
# 12  -0.094920
# 13  -0.016929
# 14  -0.009685
# 15  -0.207703
# 16  -0.206767
# 17  -0.200986
# 18  -0.092246
# 19  -0.018138
# 20  -0.012107
# 21  -0.199450
# 22  -0.206767
# 23  -0.200986
# 24  -0.344942
# 25  -0.364668
# 26  -0.384106
# 27  -0.625468
# 28  -1.053305
# 29  -1.078891
# 30  -0.296849
# 31  -0.348460
# 32  -0.365894
# 33  -0.644195
# 34  -1.051173
# 35  -1.072495
# 36  -0.369818
# 37  -0.376013
# 38  -0.394040
# 39  -0.617978
# 40  -1.051173
# 41  -1.074627
# 42  -0.353234
# 43  -0.371151
# 44  -0.389073
# 45  -0.629213
# 46  -1.051173
# 47  -1.074627
# 48   0.061155
# 49   0.108460
# 50   0.122294
# 51  -0.251429
# 52  -0.207026
# 53  -0.210461
# 54  -0.138743
# 55  -0.129950
# 56  -0.137157
# 57   0.074201
# 58   0.052138
# 59   0.053608
# 60  -0.143979
# 61  -0.137376
# 62  -0.147132
# 63   0.081050
# 64   0.064651
# 65   0.067010
# 66  -0.133508
# 67  -0.132426
# 68  -0.140898
# 69   0.092466
# 70   0.061522
# 71   0.062887
# 72  -0.129581
# 73  -0.129950
# 74  -0.138404
# 75   0.061644
# 76   0.046924
# 77   0.048454
# 78  -0.124191
# 79  -0.122525
# 80  -0.133750
# 81   0.082192
# 82   0.060354
# 83   0.060700
# 84  -0.106080
# 85  -0.126238
# 86  -0.137500
# 87   0.058219
# 88   0.042664
# 89   0.042181
# 90  -0.119017
# 91  -0.132426
# 92  -0.142500
# 93   0.099315
# 94   0.070760
# 95   0.072016
# 96  -0.072445
# 97  -0.097772
# 98  -0.107500
# 99   0.030822
# 100  0.024974
# 101  0.023663
# 102 -0.048426
# 103 -0.100950
# 104 -0.111377
# 105  0.147026
# 106  0.107996
# 107  0.113052
#                         training_method        A2        A2
# 0                          BOFedSCDepth -0.003628 -0.206767
# 1         BOFedSCDepth(ConstrainedLoss)  0.002418 -0.205514
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.016929 -0.206767
# 3                 BOFedSCDepth(Retrain) -0.018138 -0.206767
# 4                            FedSCDepth -0.364668 -1.053305
# 5           FedSCDepth(Average&Retrain) -0.348460 -1.051173
# 6                   FedSCDepth(Average) -0.376013 -1.051173
# 7                   FedSCDepth(Retrain) -0.371151 -1.051173
# 8                               SCDepth  0.108460 -0.207026
#                         training_method        A2        A2
# 0                          BOFedSCDepth -0.129950  0.052138
# 1         BOFedSCDepth(ConstrainedLoss) -0.137376  0.064651
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.132426  0.061522
# 3                 BOFedSCDepth(Retrain) -0.129950  0.046924
# 4                            FedSCDepth -0.122525  0.060354
# 5           FedSCDepth(Average&Retrain) -0.126238  0.042664
# 6                   FedSCDepth(Average) -0.132426  0.070760
# 7                   FedSCDepth(Retrain) -0.097772  0.024974
# 8                               SCDepth -0.100950  0.107996

# %%
analysis.plot_metrics_differences(['test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#       test_a3
# 0   -0.037080
# 1    0.000000
# 2    0.003315
# 3   -0.073780
# 4   -0.056867
# 5   -0.052017
# 6   -0.023175
# 7    0.008830
# 8    0.012155
# 9   -0.072645
# 10  -0.056867
# 11  -0.053079
# 12  -0.042874
# 13  -0.008830
# 14  -0.005525
# 15  -0.065834
# 16  -0.056867
# 17  -0.053079
# 18  -0.050985
# 19  -0.006623
# 20  -0.003315
# 21  -0.061294
# 22  -0.056867
# 23  -0.053079
# 24  -0.200535
# 25  -0.306152
# 26  -0.327007
# 27  -0.477918
# 28  -0.800731
# 29  -0.806922
# 30  -0.173797
# 31  -0.288984
# 32  -0.309489
# 33  -0.488959
# 34  -0.800731
# 35  -0.806922
# 36  -0.216578
# 37  -0.311874
# 38  -0.332847
# 39  -0.474763
# 40  -0.800731
# 41  -0.806922
# 42  -0.205882
# 43  -0.309013
# 44  -0.329927
# 45  -0.477918
# 46  -0.800731
# 47  -0.805100
# 48   0.038825
# 49   0.064182
# 50   0.072389
# 51  -0.090173
# 52  -0.067245
# 53  -0.067888
# 54  -0.075342
# 55  -0.063404
# 56  -0.068156
# 57   0.032529
# 58   0.017259
# 59   0.018163
# 60  -0.081050
# 61  -0.068966
# 62  -0.073743
# 63   0.036726
# 64   0.024365
# 65   0.025227
# 66  -0.077626
# 67  -0.064516
# 68  -0.069274
# 69   0.045121
# 70   0.022335
# 71   0.023209
# 72  -0.077626
# 73  -0.063404
# 74  -0.068156
# 75   0.024134
# 76   0.014213
# 77   0.015136
# 78  -0.078857
# 79  -0.066069
# 80  -0.073281
# 81   0.027397
# 82   0.019289
# 83   0.021169
# 84  -0.076571
# 85  -0.069429
# 86  -0.076663
# 87   0.021075
# 88   0.012183
# 89   0.013105
# 90  -0.078857
# 91  -0.070549
# 92  -0.077790
# 93   0.038988
# 94   0.024365
# 95   0.026210
# 96  -0.046857
# 97  -0.053751
# 98  -0.060879
# 99   0.006322
# 100  0.004061
# 101  0.005040
# 102 -0.042623
# 103 -0.055616
# 104 -0.061336
# 105  0.066386
# 106  0.045685
# 107  0.047427
#                         training_method        A3        A3
# 0                          BOFedSCDepth  0.000000 -0.056867
# 1         BOFedSCDepth(ConstrainedLoss)  0.008830 -0.056867
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.008830 -0.056867
# 3                 BOFedSCDepth(Retrain) -0.006623 -0.056867
# 4                            FedSCDepth -0.306152 -0.800731
# 5           FedSCDepth(Average&Retrain) -0.288984 -0.800731
# 6                   FedSCDepth(Average) -0.311874 -0.800731
# 7                   FedSCDepth(Retrain) -0.309013 -0.800731
# 8                               SCDepth  0.064182 -0.067245
#                         training_method        A3        A3
# 0                          BOFedSCDepth -0.063404  0.017259
# 1         BOFedSCDepth(ConstrainedLoss) -0.068966  0.024365
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.064516  0.022335
# 3                 BOFedSCDepth(Retrain) -0.063404  0.014213
# 4                            FedSCDepth -0.066069  0.019289
# 5           FedSCDepth(Average&Retrain) -0.069429  0.012183
# 6                   FedSCDepth(Average) -0.070549  0.024365
# 7                   FedSCDepth(Retrain) -0.053751  0.004061
# 8                               SCDepth -0.055616  0.045685

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log', 'test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_abs_rel  test_sq_rel  test_log10  test_rmse  test_rmse_log  \
# 0        0.121324     0.168713    0.109489   0.068081       0.076923
# 1       -0.055814     0.030673    0.000000   0.030499      -0.002625
# 2       -0.089202     0.013369   -0.017544   0.027323      -0.018421
# 3        0.505051     0.613036    0.398601   0.267283       0.287879
# 4        0.644860     0.771613    0.588710   0.380131       0.484594
# 5        0.656863     0.790188    0.613445   0.396780       0.530792
# 6        0.084559     0.101380    0.065693   0.036222       0.042184
# 7       -0.074419    -0.024760   -0.035398   0.001143      -0.041995
# 8       -0.103286    -0.041192   -0.043860  -0.001911      -0.057895
# 9        0.477273     0.579817    0.377622   0.245628       0.262626
# 10       0.629283     0.756452    0.580645   0.371440       0.476190
# 11       0.643791     0.780793    0.596639   0.390586       0.524927
# 12       0.132353     0.216175    0.153285   0.103779       0.116625
# 13      -0.009302     0.088507    0.044248   0.058537       0.036745
# 14      -0.032864     0.073171    0.035088   0.054863       0.023684
# 15       0.469697     0.526845    0.377622   0.232818       0.262626
# 16       0.641745     0.758065    0.596774   0.389089       0.484594
# 17       0.656863     0.783577    0.613445   0.416047       0.536657
# 18       0.136029     0.224149    0.153285   0.106441       0.116625
# 19      -0.009302     0.076312    0.044248   0.055944       0.028871
# 20      -0.032864     0.062150    0.026316   0.053125       0.018421
# 21       0.446970     0.477285    0.363636   0.209435       0.244949
# 22       0.635514     0.754516    0.588710   0.384945       0.481793
# 23       0.650327     0.780793    0.613445   0.412607       0.536657
# 24       0.327635     0.458308    0.404040   0.234542       0.347197
# 25       0.412088     0.425285    0.532751   0.173622       0.505391
# 26       0.431937     0.469137    0.538136   0.175246       0.509908
# 27       0.593807     0.791730    0.671429   0.415014       0.629492
# 28       0.810510     0.944021    0.856338   0.627537       0.827298
# 29       0.826433     0.953637    0.870056   0.662679       0.851955
# 30       0.299145     0.379354    0.353535   0.174922       0.300181
# 31       0.406593     0.371103    0.515284   0.125613       0.479784
# 32       0.424084     0.419797    0.521186   0.127838       0.486129
# 33       0.619308     0.825825    0.678571   0.436120       0.638166
# 34       0.812102     0.947970    0.853521   0.617754       0.826370
# 35       0.826433     0.955622    0.864407   0.646518       0.848231
# 36       0.347578     0.492718    0.429293   0.258221       0.370705
# 37       0.420330     0.447717    0.541485   0.191884       0.514825
# 38       0.437173     0.489098    0.546610   0.193207       0.519155
# 39       0.582878     0.775553    0.664286   0.400793       0.627014
# 40       0.807325     0.943034    0.853521   0.620179       0.826370
# 41       0.823248     0.952219    0.867232   0.654678       0.850093
# 42       0.339031     0.473980    0.414141   0.243123       0.354430
# 43       0.406593     0.436788    0.528384   0.184227       0.506739
# 44       0.424084     0.478862    0.533898   0.185563       0.511229
# 45       0.612022     0.802974    0.678571   0.425642       0.634449
# 46       0.810510     0.945925    0.853521   0.625515       0.826370
# 47       0.826433     0.954275    0.867232   0.657134       0.850093
# 48      -0.054299    -0.265987   -0.187500  -0.213140      -0.178451
# 49      -0.578947    -0.660437   -0.735294  -0.376327      -0.574297
# 50      -0.668919    -0.747221   -0.848485  -0.398378      -0.648760
# 51       0.512821     0.706653    0.410596   0.383156       0.302600
# 52       0.651515     0.827555    0.585366   0.511647       0.493188
# 53       0.671779     0.850276    0.619835   0.535249       0.549020
# 54       0.214286     0.381514    0.283582   0.229972       0.232911
# 55       0.392713     0.423827    0.409836   0.256317       0.346535
# 56       0.414343     0.436854    0.427419   0.262488       0.365196
# 57      -0.397260    -1.018269   -0.260870  -0.314939      -0.191638
# 58      -0.624000    -1.755470   -0.400000  -0.473618      -0.363158
# 59      -0.719298    -2.185410   -0.480000  -0.516622      -0.455090
# 60       0.180451     0.381246    0.276119   0.245950       0.245570
# 61       0.384615     0.454050    0.426230   0.288133       0.368812
# 62       0.410359     0.468554    0.443548   0.294497       0.389706
# 63      -0.465753    -1.142671   -0.293478  -0.344684      -0.212544
# 64      -0.792000    -2.252252   -0.527273  -0.594072      -0.447368
# 65      -0.903509    -2.793313   -0.620000  -0.652482      -0.568862
# 66       0.157895     0.355124    0.253731   0.230061       0.225316
# 67       0.372470     0.430153    0.401639   0.267883       0.349010
# 68       0.394422     0.443465    0.427419   0.273545       0.370098
# 69      -0.525114    -1.300565   -0.326087  -0.374428      -0.229965
# 70      -0.768000    -2.123552   -0.509091  -0.556443      -0.426316
# 71      -0.868421    -2.575988   -0.600000  -0.602394      -0.538922
# 72       0.184211     0.364233    0.261194   0.223028       0.227848
# 73       0.380567     0.418380    0.401639   0.253917       0.339109
# 74       0.406375     0.431599    0.419355   0.259605       0.360294
# 75      -0.378995    -0.809482   -0.250000  -0.250606      -0.170732
# 76      -0.632000    -1.460746   -0.436364  -0.387849      -0.342105
# 77      -0.728070    -1.805471   -0.520000  -0.422207      -0.437126
# 78       0.128906     0.346242    0.236641   0.217087       0.220253
# 79       0.365854     0.414364    0.390244   0.249754       0.342995
# 80       0.394422     0.430890    0.420635   0.257116       0.362768
# 81      -0.504673    -0.950042   -0.322222  -0.309987      -0.193772
# 82      -0.825000    -1.938320   -0.596154  -0.521106      -0.440860
# 83      -0.944954    -2.454976   -0.702128  -0.585199      -0.571429
# 84       0.109375     0.324787    0.221374   0.205598       0.210127
# 85       0.337398     0.421358    0.382114   0.256468       0.345411
# 86       0.366534     0.436957    0.404762   0.262801       0.365155
# 87      -0.411215    -0.738035   -0.266667  -0.229555      -0.155709
# 88      -0.650000    -1.371391   -0.480769  -0.356117      -0.338710
# 89      -0.724771    -1.698262   -0.553191  -0.394701      -0.440994
# 90       0.144531     0.363379    0.244275   0.232479       0.227848
# 91       0.373984     0.437735    0.406504   0.275628       0.364734
# 92       0.402390     0.452533    0.428571   0.282213       0.384248
# 93      -0.565421    -1.231738   -0.366667  -0.393927      -0.231834
# 94      -0.908333    -2.442257   -0.653846  -0.655667      -0.494624
# 95      -1.036697    -3.074250   -0.765957  -0.731384      -0.645963
# 96       0.082031     0.223317    0.145038   0.124379       0.144304
# 97       0.288618     0.322757    0.308943   0.170466       0.268116
# 98       0.318725     0.336449    0.333333   0.176099       0.286396
# 99      -0.224299    -0.240974   -0.155556  -0.060324      -0.069204
# 100     -0.416667    -0.580052   -0.326923  -0.128348      -0.215054
# 101     -0.458716    -0.748815   -0.361702  -0.150297      -0.279503
# 102      0.044053     0.093529    0.160714   0.149183       0.137931
# 103      0.360360     0.382201    0.422018   0.285599       0.346995
# 104      0.384956     0.406269    0.441441   0.295770       0.372973
# 105     -0.879581    -2.320946   -0.559524  -0.643932      -0.358156
# 106     -1.295652    -4.299191   -0.900000  -1.086279      -0.715847
# 107     -1.471698    -5.249216   -1.021739  -1.210994      -0.905660
#
#       test_a1   test_a2   test_a3
# 0   -0.090559 -0.073529 -0.037080
# 1    0.004878 -0.003628  0.000000
# 2    0.016313  0.003632  0.003315
# 3   -0.643836 -0.225585 -0.073780
# 4   -0.799587 -0.206767 -0.056867
# 5   -0.788306 -0.198520 -0.052017
# 6   -0.073218 -0.057487 -0.023175
# 7    0.014634  0.002418  0.008830
# 8    0.022838  0.009685  0.012155
# 9   -0.579909 -0.213205 -0.072645
# 10  -0.783058 -0.205514 -0.056867
# 11  -0.774194 -0.199753 -0.053079
# 12  -0.154143 -0.094920 -0.042874
# 13  -0.037398 -0.016929 -0.008830
# 14  -0.027732 -0.009685 -0.005525
# 15  -0.611872 -0.207703 -0.065834
# 16  -0.797521 -0.206767 -0.056867
# 17  -0.788306 -0.200986 -0.053079
# 18  -0.146435 -0.092246 -0.050985
# 19  -0.037398 -0.018138 -0.006623
# 20  -0.027732 -0.012107 -0.003315
# 21  -0.586758 -0.199450 -0.061294
# 22  -0.795455 -0.206767 -0.056867
# 23  -0.786290 -0.200986 -0.053079
# 24  -0.505051 -0.344942 -0.200535
# 25  -0.481651 -0.364668 -0.306152
# 26  -0.492991 -0.384106 -0.327007
# 27  -0.868493 -0.625468 -0.477918
# 28  -1.728707 -1.053305 -0.800731
# 29  -1.773585 -1.078891 -0.806922
# 30  -0.411616 -0.296849 -0.173797
# 31  -0.470183 -0.348460 -0.288984
# 32  -0.483645 -0.365894 -0.309489
# 33  -0.876712 -0.644195 -0.488959
# 34  -1.716088 -1.051173 -0.800731
# 35  -1.757862 -1.072495 -0.806922
# 36  -0.550505 -0.369818 -0.216578
# 37  -0.488532 -0.376013 -0.311874
# 38  -0.497664 -0.394040 -0.332847
# 39  -0.843836 -0.617978 -0.474763
# 40  -1.716088 -1.051173 -0.800731
# 41  -1.761006 -1.074627 -0.806922
# 42  -0.527778 -0.353234 -0.205882
# 43  -0.458716 -0.371151 -0.309013
# 44  -0.464953 -0.389073 -0.329927
# 45  -0.912329 -0.629213 -0.477918
# 46  -1.722397 -1.051173 -0.800731
# 47  -1.767296 -1.074627 -0.805100
# 48   0.082443  0.061155  0.038825
# 49   0.256927  0.108460  0.064182
# 50   0.281796  0.122294  0.072389
# 51  -0.620930 -0.251429 -0.090173
# 52  -0.692759 -0.207026 -0.067245
# 53  -0.726916 -0.210461 -0.067888
# 54  -0.274472 -0.138743 -0.075342
# 55  -0.376307 -0.129950 -0.063404
# 56  -0.401408 -0.137157 -0.068156
# 57   0.170404  0.074201  0.032529
# 58   0.132075  0.052138  0.017259
# 59   0.134793  0.053608  0.018163
# 60  -0.261036 -0.143979 -0.081050
# 61  -0.386760 -0.137376 -0.068966
# 62  -0.413732 -0.147132 -0.073743
# 63   0.198804  0.081050  0.036726
# 64   0.168632  0.064651  0.024365
# 65   0.170507  0.067010  0.025227
# 66  -0.243762 -0.133508 -0.077626
# 67  -0.364111 -0.132426 -0.064516
# 68  -0.387324 -0.140898 -0.069274
# 69   0.209268  0.092466  0.045121
# 70   0.165094  0.061522  0.022335
# 71   0.168203  0.062887  0.023209
# 72  -0.247601 -0.129581 -0.077626
# 73  -0.371080 -0.129950 -0.063404
# 74  -0.397887 -0.138404 -0.068156
# 75   0.183857  0.061644  0.024134
# 76   0.148585  0.046924  0.014213
# 77   0.153226  0.048454  0.015136
# 78  -0.157509 -0.124191 -0.078857
# 79  -0.352332 -0.122525 -0.066069
# 80  -0.388401 -0.133750 -0.073281
# 81   0.228404  0.082192  0.027397
# 82   0.178114  0.060354  0.019289
# 83   0.178815  0.060700  0.021169
# 84  -0.159341 -0.106080 -0.076571
# 85  -0.329879 -0.126238 -0.069429
# 86  -0.365554 -0.137500 -0.076663
# 87   0.196193  0.058219  0.021075
# 88   0.140861  0.042664  0.012183
# 89   0.138952  0.042181  0.013105
# 90  -0.190476 -0.119017 -0.078857
# 91  -0.359240 -0.132426 -0.070549
# 92  -0.391916 -0.142500 -0.077790
# 93   0.240117  0.099315  0.038988
# 94   0.188591  0.070760  0.024365
# 95   0.190205  0.072016  0.026210
# 96  -0.095238 -0.072445 -0.046857
# 97  -0.271157 -0.097772 -0.053751
# 98  -0.302285 -0.107500 -0.060879
# 99   0.114202  0.030822  0.006322
# 100  0.101281  0.024974  0.004061
# 101  0.097950  0.023663  0.005040
# 102 -0.086957 -0.048426 -0.042623
# 103 -0.299363 -0.100950 -0.055616
# 104 -0.327391 -0.111377 -0.061336
# 105  0.285124  0.147026  0.066386
# 106  0.231651  0.107996  0.045685
# 107  0.234763  0.113052  0.047427
#                         training_method   ABS REL   ABS REL    SQ REL  \
# 0                          BOFedSCDepth -0.055814  0.644860  0.030673
# 1         BOFedSCDepth(ConstrainedLoss) -0.074419  0.629283 -0.024760
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.009302  0.641745  0.088507
# 3                 BOFedSCDepth(Retrain) -0.009302  0.635514  0.076312
# 4                            FedSCDepth  0.412088  0.810510  0.425285
# 5           FedSCDepth(Average&Retrain)  0.406593  0.812102  0.371103
# 6                   FedSCDepth(Average)  0.420330  0.807325  0.447717
# 7                   FedSCDepth(Retrain)  0.406593  0.810510  0.436788
# 8                               SCDepth -0.578947  0.651515 -0.660437
#
#      SQ REL     LOG10     LOG10      RMSE      RMSE  RMSE LOG  RMSE LOG  \
# 0  0.771613  0.000000  0.588710  0.030499  0.380131 -0.002625  0.484594
# 1  0.756452 -0.035398  0.580645  0.001143  0.371440 -0.041995  0.476190
# 2  0.758065  0.044248  0.596774  0.058537  0.389089  0.036745  0.484594
# 3  0.754516  0.044248  0.588710  0.055944  0.384945  0.028871  0.481793
# 4  0.944021  0.532751  0.856338  0.173622  0.627537  0.505391  0.827298
# 5  0.947970  0.515284  0.853521  0.125613  0.617754  0.479784  0.826370
# 6  0.943034  0.541485  0.853521  0.191884  0.620179  0.514825  0.826370
# 7  0.945925  0.528384  0.853521  0.184227  0.625515  0.506739  0.826370
# 8  0.827555 -0.735294  0.585366 -0.376327  0.511647 -0.574297  0.493188
#
#          A1        A1        A2        A2        A3        A3
# 0  0.004878 -0.799587 -0.003628 -0.206767  0.000000 -0.056867
# 1  0.014634 -0.783058  0.002418 -0.205514  0.008830 -0.056867
# 2 -0.037398 -0.797521 -0.016929 -0.206767 -0.008830 -0.056867
# 3 -0.037398 -0.795455 -0.018138 -0.206767 -0.006623 -0.056867
# 4 -0.481651 -1.728707 -0.364668 -1.053305 -0.306152 -0.800731
# 5 -0.470183 -1.716088 -0.348460 -1.051173 -0.288984 -0.800731
# 6 -0.488532 -1.716088 -0.376013 -1.051173 -0.311874 -0.800731
# 7 -0.458716 -1.722397 -0.371151 -1.051173 -0.309013 -0.800731
# 8  0.256927 -0.692759  0.108460 -0.207026  0.064182 -0.067245
#                         training_method   ABS REL   ABS REL    SQ REL  \
# 0                          BOFedSCDepth  0.392713 -0.624000  0.423827
# 1         BOFedSCDepth(ConstrainedLoss)  0.384615 -0.792000  0.454050
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.372470 -0.768000  0.430153
# 3                 BOFedSCDepth(Retrain)  0.380567 -0.632000  0.418380
# 4                            FedSCDepth  0.365854 -0.825000  0.414364
# 5           FedSCDepth(Average&Retrain)  0.337398 -0.650000  0.421358
# 6                   FedSCDepth(Average)  0.373984 -0.908333  0.437735
# 7                   FedSCDepth(Retrain)  0.288618 -0.416667  0.322757
# 8                               SCDepth  0.360360 -1.295652  0.382201
#
#      SQ REL     LOG10     LOG10      RMSE      RMSE  RMSE LOG  RMSE LOG  \
# 0 -1.755470  0.409836 -0.400000  0.256317 -0.473618  0.346535 -0.363158
# 1 -2.252252  0.426230 -0.527273  0.288133 -0.594072  0.368812 -0.447368
# 2 -2.123552  0.401639 -0.509091  0.267883 -0.556443  0.349010 -0.426316
# 3 -1.460746  0.401639 -0.436364  0.253917 -0.387849  0.339109 -0.342105
# 4 -1.938320  0.390244 -0.596154  0.249754 -0.521106  0.342995 -0.440860
# 5 -1.371391  0.382114 -0.480769  0.256468 -0.356117  0.345411 -0.338710
# 6 -2.442257  0.406504 -0.653846  0.275628 -0.655667  0.364734 -0.494624
# 7 -0.580052  0.308943 -0.326923  0.170466 -0.128348  0.268116 -0.215054
# 8 -4.299191  0.422018 -0.900000  0.285599 -1.086279  0.346995 -0.715847
#
#          A1        A1        A2        A2        A3        A3
# 0 -0.376307  0.132075 -0.129950  0.052138 -0.063404  0.017259
# 1 -0.386760  0.168632 -0.137376  0.064651 -0.068966  0.024365
# 2 -0.364111  0.165094 -0.132426  0.061522 -0.064516  0.022335
# 3 -0.371080  0.148585 -0.129950  0.046924 -0.063404  0.014213
# 4 -0.352332  0.178114 -0.122525  0.060354 -0.066069  0.019289
# 5 -0.329879  0.140861 -0.126238  0.042664 -0.069429  0.012183
# 6 -0.359240  0.188591 -0.132426  0.070760 -0.070549  0.024365
# 7 -0.271157  0.101281 -0.097772  0.024974 -0.053751  0.004061
# 8 -0.299363  0.231651 -0.100950  0.107996 -0.055616  0.045685

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_abs_rel  test_sq_rel  test_log10  test_rmse  test_rmse_log
# 0        0.121324     0.168713    0.109489   0.068081       0.076923
# 1       -0.055814     0.030673    0.000000   0.030499      -0.002625
# 2       -0.089202     0.013369   -0.017544   0.027323      -0.018421
# 3        0.505051     0.613036    0.398601   0.267283       0.287879
# 4        0.644860     0.771613    0.588710   0.380131       0.484594
# 5        0.656863     0.790188    0.613445   0.396780       0.530792
# 6        0.084559     0.101380    0.065693   0.036222       0.042184
# 7       -0.074419    -0.024760   -0.035398   0.001143      -0.041995
# 8       -0.103286    -0.041192   -0.043860  -0.001911      -0.057895
# 9        0.477273     0.579817    0.377622   0.245628       0.262626
# 10       0.629283     0.756452    0.580645   0.371440       0.476190
# 11       0.643791     0.780793    0.596639   0.390586       0.524927
# 12       0.132353     0.216175    0.153285   0.103779       0.116625
# 13      -0.009302     0.088507    0.044248   0.058537       0.036745
# 14      -0.032864     0.073171    0.035088   0.054863       0.023684
# 15       0.469697     0.526845    0.377622   0.232818       0.262626
# 16       0.641745     0.758065    0.596774   0.389089       0.484594
# 17       0.656863     0.783577    0.613445   0.416047       0.536657
# 18       0.136029     0.224149    0.153285   0.106441       0.116625
# 19      -0.009302     0.076312    0.044248   0.055944       0.028871
# 20      -0.032864     0.062150    0.026316   0.053125       0.018421
# 21       0.446970     0.477285    0.363636   0.209435       0.244949
# 22       0.635514     0.754516    0.588710   0.384945       0.481793
# 23       0.650327     0.780793    0.613445   0.412607       0.536657
# 24       0.327635     0.458308    0.404040   0.234542       0.347197
# 25       0.412088     0.425285    0.532751   0.173622       0.505391
# 26       0.431937     0.469137    0.538136   0.175246       0.509908
# 27       0.593807     0.791730    0.671429   0.415014       0.629492
# 28       0.810510     0.944021    0.856338   0.627537       0.827298
# 29       0.826433     0.953637    0.870056   0.662679       0.851955
# 30       0.299145     0.379354    0.353535   0.174922       0.300181
# 31       0.406593     0.371103    0.515284   0.125613       0.479784
# 32       0.424084     0.419797    0.521186   0.127838       0.486129
# 33       0.619308     0.825825    0.678571   0.436120       0.638166
# 34       0.812102     0.947970    0.853521   0.617754       0.826370
# 35       0.826433     0.955622    0.864407   0.646518       0.848231
# 36       0.347578     0.492718    0.429293   0.258221       0.370705
# 37       0.420330     0.447717    0.541485   0.191884       0.514825
# 38       0.437173     0.489098    0.546610   0.193207       0.519155
# 39       0.582878     0.775553    0.664286   0.400793       0.627014
# 40       0.807325     0.943034    0.853521   0.620179       0.826370
# 41       0.823248     0.952219    0.867232   0.654678       0.850093
# 42       0.339031     0.473980    0.414141   0.243123       0.354430
# 43       0.406593     0.436788    0.528384   0.184227       0.506739
# 44       0.424084     0.478862    0.533898   0.185563       0.511229
# 45       0.612022     0.802974    0.678571   0.425642       0.634449
# 46       0.810510     0.945925    0.853521   0.625515       0.826370
# 47       0.826433     0.954275    0.867232   0.657134       0.850093
# 48      -0.054299    -0.265987   -0.187500  -0.213140      -0.178451
# 49      -0.578947    -0.660437   -0.735294  -0.376327      -0.574297
# 50      -0.668919    -0.747221   -0.848485  -0.398378      -0.648760
# 51       0.512821     0.706653    0.410596   0.383156       0.302600
# 52       0.651515     0.827555    0.585366   0.511647       0.493188
# 53       0.671779     0.850276    0.619835   0.535249       0.549020
# 54       0.214286     0.381514    0.283582   0.229972       0.232911
# 55       0.392713     0.423827    0.409836   0.256317       0.346535
# 56       0.414343     0.436854    0.427419   0.262488       0.365196
# 57      -0.397260    -1.018269   -0.260870  -0.314939      -0.191638
# 58      -0.624000    -1.755470   -0.400000  -0.473618      -0.363158
# 59      -0.719298    -2.185410   -0.480000  -0.516622      -0.455090
# 60       0.180451     0.381246    0.276119   0.245950       0.245570
# 61       0.384615     0.454050    0.426230   0.288133       0.368812
# 62       0.410359     0.468554    0.443548   0.294497       0.389706
# 63      -0.465753    -1.142671   -0.293478  -0.344684      -0.212544
# 64      -0.792000    -2.252252   -0.527273  -0.594072      -0.447368
# 65      -0.903509    -2.793313   -0.620000  -0.652482      -0.568862
# 66       0.157895     0.355124    0.253731   0.230061       0.225316
# 67       0.372470     0.430153    0.401639   0.267883       0.349010
# 68       0.394422     0.443465    0.427419   0.273545       0.370098
# 69      -0.525114    -1.300565   -0.326087  -0.374428      -0.229965
# 70      -0.768000    -2.123552   -0.509091  -0.556443      -0.426316
# 71      -0.868421    -2.575988   -0.600000  -0.602394      -0.538922
# 72       0.184211     0.364233    0.261194   0.223028       0.227848
# 73       0.380567     0.418380    0.401639   0.253917       0.339109
# 74       0.406375     0.431599    0.419355   0.259605       0.360294
# 75      -0.378995    -0.809482   -0.250000  -0.250606      -0.170732
# 76      -0.632000    -1.460746   -0.436364  -0.387849      -0.342105
# 77      -0.728070    -1.805471   -0.520000  -0.422207      -0.437126
# 78       0.128906     0.346242    0.236641   0.217087       0.220253
# 79       0.365854     0.414364    0.390244   0.249754       0.342995
# 80       0.394422     0.430890    0.420635   0.257116       0.362768
# 81      -0.504673    -0.950042   -0.322222  -0.309987      -0.193772
# 82      -0.825000    -1.938320   -0.596154  -0.521106      -0.440860
# 83      -0.944954    -2.454976   -0.702128  -0.585199      -0.571429
# 84       0.109375     0.324787    0.221374   0.205598       0.210127
# 85       0.337398     0.421358    0.382114   0.256468       0.345411
# 86       0.366534     0.436957    0.404762   0.262801       0.365155
# 87      -0.411215    -0.738035   -0.266667  -0.229555      -0.155709
# 88      -0.650000    -1.371391   -0.480769  -0.356117      -0.338710
# 89      -0.724771    -1.698262   -0.553191  -0.394701      -0.440994
# 90       0.144531     0.363379    0.244275   0.232479       0.227848
# 91       0.373984     0.437735    0.406504   0.275628       0.364734
# 92       0.402390     0.452533    0.428571   0.282213       0.384248
# 93      -0.565421    -1.231738   -0.366667  -0.393927      -0.231834
# 94      -0.908333    -2.442257   -0.653846  -0.655667      -0.494624
# 95      -1.036697    -3.074250   -0.765957  -0.731384      -0.645963
# 96       0.082031     0.223317    0.145038   0.124379       0.144304
# 97       0.288618     0.322757    0.308943   0.170466       0.268116
# 98       0.318725     0.336449    0.333333   0.176099       0.286396
# 99      -0.224299    -0.240974   -0.155556  -0.060324      -0.069204
# 100     -0.416667    -0.580052   -0.326923  -0.128348      -0.215054
# 101     -0.458716    -0.748815   -0.361702  -0.150297      -0.279503
# 102      0.044053     0.093529    0.160714   0.149183       0.137931
# 103      0.360360     0.382201    0.422018   0.285599       0.346995
# 104      0.384956     0.406269    0.441441   0.295770       0.372973
# 105     -0.879581    -2.320946   -0.559524  -0.643932      -0.358156
# 106     -1.295652    -4.299191   -0.900000  -1.086279      -0.715847
# 107     -1.471698    -5.249216   -1.021739  -1.210994      -0.905660
#                         training_method   ABS REL   ABS REL    SQ REL  \
# 0                          BOFedSCDepth -0.055814  0.644860  0.030673
# 1         BOFedSCDepth(ConstrainedLoss) -0.074419  0.629283 -0.024760
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.009302  0.641745  0.088507
# 3                 BOFedSCDepth(Retrain) -0.009302  0.635514  0.076312
# 4                            FedSCDepth  0.412088  0.810510  0.425285
# 5           FedSCDepth(Average&Retrain)  0.406593  0.812102  0.371103
# 6                   FedSCDepth(Average)  0.420330  0.807325  0.447717
# 7                   FedSCDepth(Retrain)  0.406593  0.810510  0.436788
# 8                               SCDepth -0.578947  0.651515 -0.660437
#
#      SQ REL     LOG10     LOG10      RMSE      RMSE  RMSE LOG  RMSE LOG
# 0  0.771613  0.000000  0.588710  0.030499  0.380131 -0.002625  0.484594
# 1  0.756452 -0.035398  0.580645  0.001143  0.371440 -0.041995  0.476190
# 2  0.758065  0.044248  0.596774  0.058537  0.389089  0.036745  0.484594
# 3  0.754516  0.044248  0.588710  0.055944  0.384945  0.028871  0.481793
# 4  0.944021  0.532751  0.856338  0.173622  0.627537  0.505391  0.827298
# 5  0.947970  0.515284  0.853521  0.125613  0.617754  0.479784  0.826370
# 6  0.943034  0.541485  0.853521  0.191884  0.620179  0.514825  0.826370
# 7  0.945925  0.528384  0.853521  0.184227  0.625515  0.506739  0.826370
# 8  0.827555 -0.735294  0.585366 -0.376327  0.511647 -0.574297  0.493188
#                         training_method   ABS REL   ABS REL    SQ REL  \
# 0                          BOFedSCDepth  0.392713 -0.624000  0.423827
# 1         BOFedSCDepth(ConstrainedLoss)  0.384615 -0.792000  0.454050
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.372470 -0.768000  0.430153
# 3                 BOFedSCDepth(Retrain)  0.380567 -0.632000  0.418380
# 4                            FedSCDepth  0.365854 -0.825000  0.414364
# 5           FedSCDepth(Average&Retrain)  0.337398 -0.650000  0.421358
# 6                   FedSCDepth(Average)  0.373984 -0.908333  0.437735
# 7                   FedSCDepth(Retrain)  0.288618 -0.416667  0.322757
# 8                               SCDepth  0.360360 -1.295652  0.382201
#
#      SQ REL     LOG10     LOG10      RMSE      RMSE  RMSE LOG  RMSE LOG
# 0 -1.755470  0.409836 -0.400000  0.256317 -0.473618  0.346535 -0.363158
# 1 -2.252252  0.426230 -0.527273  0.288133 -0.594072  0.368812 -0.447368
# 2 -2.123552  0.401639 -0.509091  0.267883 -0.556443  0.349010 -0.426316
# 3 -1.460746  0.401639 -0.436364  0.253917 -0.387849  0.339109 -0.342105
# 4 -1.938320  0.390244 -0.596154  0.249754 -0.521106  0.342995 -0.440860
# 5 -1.371391  0.382114 -0.480769  0.256468 -0.356117  0.345411 -0.338710
# 6 -2.442257  0.406504 -0.653846  0.275628 -0.655667  0.364734 -0.494624
# 7 -0.580052  0.308943 -0.326923  0.170466 -0.128348  0.268116 -0.215054
# 8 -4.299191  0.422018 -0.900000  0.285599 -1.086279  0.346995 -0.715847

# %%
analysis.plot_metrics_differences(['test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#       test_a1   test_a2   test_a3
# 0   -0.090559 -0.073529 -0.037080
# 1    0.004878 -0.003628  0.000000
# 2    0.016313  0.003632  0.003315
# 3   -0.643836 -0.225585 -0.073780
# 4   -0.799587 -0.206767 -0.056867
# 5   -0.788306 -0.198520 -0.052017
# 6   -0.073218 -0.057487 -0.023175
# 7    0.014634  0.002418  0.008830
# 8    0.022838  0.009685  0.012155
# 9   -0.579909 -0.213205 -0.072645
# 10  -0.783058 -0.205514 -0.056867
# 11  -0.774194 -0.199753 -0.053079
# 12  -0.154143 -0.094920 -0.042874
# 13  -0.037398 -0.016929 -0.008830
# 14  -0.027732 -0.009685 -0.005525
# 15  -0.611872 -0.207703 -0.065834
# 16  -0.797521 -0.206767 -0.056867
# 17  -0.788306 -0.200986 -0.053079
# 18  -0.146435 -0.092246 -0.050985
# 19  -0.037398 -0.018138 -0.006623
# 20  -0.027732 -0.012107 -0.003315
# 21  -0.586758 -0.199450 -0.061294
# 22  -0.795455 -0.206767 -0.056867
# 23  -0.786290 -0.200986 -0.053079
# 24  -0.505051 -0.344942 -0.200535
# 25  -0.481651 -0.364668 -0.306152
# 26  -0.492991 -0.384106 -0.327007
# 27  -0.868493 -0.625468 -0.477918
# 28  -1.728707 -1.053305 -0.800731
# 29  -1.773585 -1.078891 -0.806922
# 30  -0.411616 -0.296849 -0.173797
# 31  -0.470183 -0.348460 -0.288984
# 32  -0.483645 -0.365894 -0.309489
# 33  -0.876712 -0.644195 -0.488959
# 34  -1.716088 -1.051173 -0.800731
# 35  -1.757862 -1.072495 -0.806922
# 36  -0.550505 -0.369818 -0.216578
# 37  -0.488532 -0.376013 -0.311874
# 38  -0.497664 -0.394040 -0.332847
# 39  -0.843836 -0.617978 -0.474763
# 40  -1.716088 -1.051173 -0.800731
# 41  -1.761006 -1.074627 -0.806922
# 42  -0.527778 -0.353234 -0.205882
# 43  -0.458716 -0.371151 -0.309013
# 44  -0.464953 -0.389073 -0.329927
# 45  -0.912329 -0.629213 -0.477918
# 46  -1.722397 -1.051173 -0.800731
# 47  -1.767296 -1.074627 -0.805100
# 48   0.082443  0.061155  0.038825
# 49   0.256927  0.108460  0.064182
# 50   0.281796  0.122294  0.072389
# 51  -0.620930 -0.251429 -0.090173
# 52  -0.692759 -0.207026 -0.067245
# 53  -0.726916 -0.210461 -0.067888
# 54  -0.274472 -0.138743 -0.075342
# 55  -0.376307 -0.129950 -0.063404
# 56  -0.401408 -0.137157 -0.068156
# 57   0.170404  0.074201  0.032529
# 58   0.132075  0.052138  0.017259
# 59   0.134793  0.053608  0.018163
# 60  -0.261036 -0.143979 -0.081050
# 61  -0.386760 -0.137376 -0.068966
# 62  -0.413732 -0.147132 -0.073743
# 63   0.198804  0.081050  0.036726
# 64   0.168632  0.064651  0.024365
# 65   0.170507  0.067010  0.025227
# 66  -0.243762 -0.133508 -0.077626
# 67  -0.364111 -0.132426 -0.064516
# 68  -0.387324 -0.140898 -0.069274
# 69   0.209268  0.092466  0.045121
# 70   0.165094  0.061522  0.022335
# 71   0.168203  0.062887  0.023209
# 72  -0.247601 -0.129581 -0.077626
# 73  -0.371080 -0.129950 -0.063404
# 74  -0.397887 -0.138404 -0.068156
# 75   0.183857  0.061644  0.024134
# 76   0.148585  0.046924  0.014213
# 77   0.153226  0.048454  0.015136
# 78  -0.157509 -0.124191 -0.078857
# 79  -0.352332 -0.122525 -0.066069
# 80  -0.388401 -0.133750 -0.073281
# 81   0.228404  0.082192  0.027397
# 82   0.178114  0.060354  0.019289
# 83   0.178815  0.060700  0.021169
# 84  -0.159341 -0.106080 -0.076571
# 85  -0.329879 -0.126238 -0.069429
# 86  -0.365554 -0.137500 -0.076663
# 87   0.196193  0.058219  0.021075
# 88   0.140861  0.042664  0.012183
# 89   0.138952  0.042181  0.013105
# 90  -0.190476 -0.119017 -0.078857
# 91  -0.359240 -0.132426 -0.070549
# 92  -0.391916 -0.142500 -0.077790
# 93   0.240117  0.099315  0.038988
# 94   0.188591  0.070760  0.024365
# 95   0.190205  0.072016  0.026210
# 96  -0.095238 -0.072445 -0.046857
# 97  -0.271157 -0.097772 -0.053751
# 98  -0.302285 -0.107500 -0.060879
# 99   0.114202  0.030822  0.006322
# 100  0.101281  0.024974  0.004061
# 101  0.097950  0.023663  0.005040
# 102 -0.086957 -0.048426 -0.042623
# 103 -0.299363 -0.100950 -0.055616
# 104 -0.327391 -0.111377 -0.061336
# 105  0.285124  0.147026  0.066386
# 106  0.231651  0.107996  0.045685
# 107  0.234763  0.113052  0.047427
#                         training_method        A1        A1        A2  \
# 0                          BOFedSCDepth  0.004878 -0.799587 -0.003628
# 1         BOFedSCDepth(ConstrainedLoss)  0.014634 -0.783058  0.002418
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.037398 -0.797521 -0.016929
# 3                 BOFedSCDepth(Retrain) -0.037398 -0.795455 -0.018138
# 4                            FedSCDepth -0.481651 -1.728707 -0.364668
# 5           FedSCDepth(Average&Retrain) -0.470183 -1.716088 -0.348460
# 6                   FedSCDepth(Average) -0.488532 -1.716088 -0.376013
# 7                   FedSCDepth(Retrain) -0.458716 -1.722397 -0.371151
# 8                               SCDepth  0.256927 -0.692759  0.108460
#
#          A2        A3        A3
# 0 -0.206767  0.000000 -0.056867
# 1 -0.205514  0.008830 -0.056867
# 2 -0.206767 -0.008830 -0.056867
# 3 -0.206767 -0.006623 -0.056867
# 4 -1.053305 -0.306152 -0.800731
# 5 -1.051173 -0.288984 -0.800731
# 6 -1.051173 -0.311874 -0.800731
# 7 -1.051173 -0.309013 -0.800731
# 8 -0.207026  0.064182 -0.067245
#                         training_method        A1        A1        A2  \
# 0                          BOFedSCDepth -0.376307  0.132075 -0.129950
# 1         BOFedSCDepth(ConstrainedLoss) -0.386760  0.168632 -0.137376
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.364111  0.165094 -0.132426
# 3                 BOFedSCDepth(Retrain) -0.371080  0.148585 -0.129950
# 4                            FedSCDepth -0.352332  0.178114 -0.122525
# 5           FedSCDepth(Average&Retrain) -0.329879  0.140861 -0.126238
# 6                   FedSCDepth(Average) -0.359240  0.188591 -0.132426
# 7                   FedSCDepth(Retrain) -0.271157  0.101281 -0.097772
# 8                               SCDepth -0.299363  0.231651 -0.100950
#
#          A2        A3        A3
# 0  0.052138 -0.063404  0.017259
# 1  0.064651 -0.068966  0.024365
# 2  0.061522 -0.064516  0.022335
# 3  0.046924 -0.063404  0.014213
# 4  0.060354 -0.066069  0.019289
# 5  0.042664 -0.069429  0.012183
# 6  0.070760 -0.070549  0.024365
# 7  0.024974 -0.053751  0.004061
# 8  0.107996 -0.055616  0.045685

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_rmse', 'test_a1', 'test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# 19                  DDAD                KITTI
# 20                  DDAD                KITTI
# 21                  DDAD                KITTI
# 22                  DDAD                KITTI
# 23                  DDAD                KITTI
# 24                  DDAD                KITTI
# 25                  DDAD                KITTI
# 26                  DDAD                KITTI
# 27                  DDAD                KITTI
# 28                  DDAD                KITTI
# 29                  DDAD                KITTI
# 30                  DDAD                KITTI
# 31                  DDAD                KITTI
# 32                  DDAD                KITTI
# 33                  DDAD                KITTI
# 34                  DDAD                KITTI
# 35                  DDAD                KITTI
# 36                  DDAD                KITTI
# 37                  DDAD                KITTI
# 38                  DDAD                KITTI
# 39                  DDAD                KITTI
# 40                  DDAD                KITTI
# 41                  DDAD                KITTI
# 42                  DDAD                KITTI
# 43                  DDAD                KITTI
# 44                  DDAD                KITTI
# 45                  DDAD                KITTI
# 46                  DDAD                KITTI
# 47                  DDAD                KITTI
# 48                  DDAD                KITTI
# 49                  DDAD                KITTI
# 50                  DDAD                KITTI
# 51                  DDAD                KITTI
# 52                  DDAD                KITTI
# 53                  DDAD                KITTI
# 54                 KITTI                 DDAD
# 55                 KITTI                 DDAD
# 56                 KITTI                 DDAD
# 57                 KITTI                 DDAD
# 58                 KITTI                 DDAD
# 59                 KITTI                 DDAD
# 60                 KITTI                 DDAD
# 61                 KITTI                 DDAD
# 62                 KITTI                 DDAD
# 63                 KITTI                 DDAD
# 64                 KITTI                 DDAD
# 65                 KITTI                 DDAD
# 66                 KITTI                 DDAD
# 67                 KITTI                 DDAD
# 68                 KITTI                 DDAD
# 69                 KITTI                 DDAD
# 70                 KITTI                 DDAD
# 71                 KITTI                 DDAD
# 72                 KITTI                 DDAD
# 73                 KITTI                 DDAD
# 74                 KITTI                 DDAD
# 75                 KITTI                 DDAD
# 76                 KITTI                 DDAD
# 77                 KITTI                 DDAD
# 78                 KITTI                 DDAD
# 79                 KITTI                 DDAD
# 80                 KITTI                 DDAD
# 81                 KITTI                 DDAD
# 82                 KITTI                 DDAD
# 83                 KITTI                 DDAD
# 84                 KITTI                 DDAD
# 85                 KITTI                 DDAD
# 86                 KITTI                 DDAD
# 87                 KITTI                 DDAD
# 88                 KITTI                 DDAD
# 89                 KITTI                 DDAD
# 90                 KITTI                 DDAD
# 91                 KITTI                 DDAD
# 92                 KITTI                 DDAD
# 93                 KITTI                 DDAD
# 94                 KITTI                 DDAD
# 95                 KITTI                 DDAD
# 96                 KITTI                 DDAD
# 97                 KITTI                 DDAD
# 98                 KITTI                 DDAD
# 99                 KITTI                 DDAD
# 100                KITTI                 DDAD
# 101                KITTI                 DDAD
# 102                KITTI                 DDAD
# 103                KITTI                 DDAD
# 104                KITTI                 DDAD
# 105                KITTI                 DDAD
# 106                KITTI                 DDAD
# 107                KITTI                 DDAD
#
#                           training_method test_dataset test_region_type  \
# 0                            BOFedSCDepth         DDAD          dynamic
# 1                            BOFedSCDepth         DDAD             full
# 2                            BOFedSCDepth         DDAD           static
# 3                            BOFedSCDepth        KITTI          dynamic
# 4                            BOFedSCDepth        KITTI             full
# 5                            BOFedSCDepth        KITTI           static
# 6           BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7           BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8           BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9           BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                  BOFedSCDepth(Retrain)         DDAD             full
# 20                  BOFedSCDepth(Retrain)         DDAD           static
# 21                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                  BOFedSCDepth(Retrain)        KITTI             full
# 23                  BOFedSCDepth(Retrain)        KITTI           static
# 24                             FedSCDepth         DDAD          dynamic
# 25                             FedSCDepth         DDAD             full
# 26                             FedSCDepth         DDAD           static
# 27                             FedSCDepth        KITTI          dynamic
# 28                             FedSCDepth        KITTI             full
# 29                             FedSCDepth        KITTI           static
# 30            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 31            FedSCDepth(Average&Retrain)         DDAD             full
# 32            FedSCDepth(Average&Retrain)         DDAD           static
# 33            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 34            FedSCDepth(Average&Retrain)        KITTI             full
# 35            FedSCDepth(Average&Retrain)        KITTI           static
# 36                    FedSCDepth(Average)         DDAD          dynamic
# 37                    FedSCDepth(Average)         DDAD             full
# 38                    FedSCDepth(Average)         DDAD           static
# 39                    FedSCDepth(Average)        KITTI          dynamic
# 40                    FedSCDepth(Average)        KITTI             full
# 41                    FedSCDepth(Average)        KITTI           static
# 42                    FedSCDepth(Retrain)         DDAD          dynamic
# 43                    FedSCDepth(Retrain)         DDAD             full
# 44                    FedSCDepth(Retrain)         DDAD           static
# 45                    FedSCDepth(Retrain)        KITTI          dynamic
# 46                    FedSCDepth(Retrain)        KITTI             full
# 47                    FedSCDepth(Retrain)        KITTI           static
# 48                                SCDepth         DDAD          dynamic
# 49                                SCDepth         DDAD             full
# 50                                SCDepth         DDAD           static
# 51                                SCDepth        KITTI          dynamic
# 52                                SCDepth        KITTI             full
# 53                                SCDepth        KITTI           static
# 54                           BOFedSCDepth         DDAD          dynamic
# 55                           BOFedSCDepth         DDAD             full
# 56                           BOFedSCDepth         DDAD           static
# 57                           BOFedSCDepth        KITTI          dynamic
# 58                           BOFedSCDepth        KITTI             full
# 59                           BOFedSCDepth        KITTI           static
# 60          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 61          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 62          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 63          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 64          BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 65          BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 66   BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 67   BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 68   BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 69   BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 70   BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 71   BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 72                  BOFedSCDepth(Retrain)         DDAD          dynamic
# 73                  BOFedSCDepth(Retrain)         DDAD             full
# 74                  BOFedSCDepth(Retrain)         DDAD           static
# 75                  BOFedSCDepth(Retrain)        KITTI          dynamic
# 76                  BOFedSCDepth(Retrain)        KITTI             full
# 77                  BOFedSCDepth(Retrain)        KITTI           static
# 78                             FedSCDepth         DDAD          dynamic
# 79                             FedSCDepth         DDAD             full
# 80                             FedSCDepth         DDAD           static
# 81                             FedSCDepth        KITTI          dynamic
# 82                             FedSCDepth        KITTI             full
# 83                             FedSCDepth        KITTI           static
# 84            FedSCDepth(Average&Retrain)         DDAD          dynamic
# 85            FedSCDepth(Average&Retrain)         DDAD             full
# 86            FedSCDepth(Average&Retrain)         DDAD           static
# 87            FedSCDepth(Average&Retrain)        KITTI          dynamic
# 88            FedSCDepth(Average&Retrain)        KITTI             full
# 89            FedSCDepth(Average&Retrain)        KITTI           static
# 90                    FedSCDepth(Average)         DDAD          dynamic
# 91                    FedSCDepth(Average)         DDAD             full
# 92                    FedSCDepth(Average)         DDAD           static
# 93                    FedSCDepth(Average)        KITTI          dynamic
# 94                    FedSCDepth(Average)        KITTI             full
# 95                    FedSCDepth(Average)        KITTI           static
# 96                    FedSCDepth(Retrain)         DDAD          dynamic
# 97                    FedSCDepth(Retrain)         DDAD             full
# 98                    FedSCDepth(Retrain)         DDAD           static
# 99                    FedSCDepth(Retrain)        KITTI          dynamic
# 100                   FedSCDepth(Retrain)        KITTI             full
# 101                   FedSCDepth(Retrain)        KITTI           static
# 102                               SCDepth         DDAD          dynamic
# 103                               SCDepth         DDAD             full
# 104                               SCDepth         DDAD           static
# 105                               SCDepth        KITTI          dynamic
# 106                               SCDepth        KITTI             full
# 107                               SCDepth        KITTI           static
#
#      test_abs_rel  test_rmse   test_a1   test_a3
# 0        0.121324   0.068081 -0.090559 -0.037080
# 1       -0.055814   0.030499  0.004878  0.000000
# 2       -0.089202   0.027323  0.016313  0.003315
# 3        0.505051   0.267283 -0.643836 -0.073780
# 4        0.644860   0.380131 -0.799587 -0.056867
# 5        0.656863   0.396780 -0.788306 -0.052017
# 6        0.084559   0.036222 -0.073218 -0.023175
# 7       -0.074419   0.001143  0.014634  0.008830
# 8       -0.103286  -0.001911  0.022838  0.012155
# 9        0.477273   0.245628 -0.579909 -0.072645
# 10       0.629283   0.371440 -0.783058 -0.056867
# 11       0.643791   0.390586 -0.774194 -0.053079
# 12       0.132353   0.103779 -0.154143 -0.042874
# 13      -0.009302   0.058537 -0.037398 -0.008830
# 14      -0.032864   0.054863 -0.027732 -0.005525
# 15       0.469697   0.232818 -0.611872 -0.065834
# 16       0.641745   0.389089 -0.797521 -0.056867
# 17       0.656863   0.416047 -0.788306 -0.053079
# 18       0.136029   0.106441 -0.146435 -0.050985
# 19      -0.009302   0.055944 -0.037398 -0.006623
# 20      -0.032864   0.053125 -0.027732 -0.003315
# 21       0.446970   0.209435 -0.586758 -0.061294
# 22       0.635514   0.384945 -0.795455 -0.056867
# 23       0.650327   0.412607 -0.786290 -0.053079
# 24       0.327635   0.234542 -0.505051 -0.200535
# 25       0.412088   0.173622 -0.481651 -0.306152
# 26       0.431937   0.175246 -0.492991 -0.327007
# 27       0.593807   0.415014 -0.868493 -0.477918
# 28       0.810510   0.627537 -1.728707 -0.800731
# 29       0.826433   0.662679 -1.773585 -0.806922
# 30       0.299145   0.174922 -0.411616 -0.173797
# 31       0.406593   0.125613 -0.470183 -0.288984
# 32       0.424084   0.127838 -0.483645 -0.309489
# 33       0.619308   0.436120 -0.876712 -0.488959
# 34       0.812102   0.617754 -1.716088 -0.800731
# 35       0.826433   0.646518 -1.757862 -0.806922
# 36       0.347578   0.258221 -0.550505 -0.216578
# 37       0.420330   0.191884 -0.488532 -0.311874
# 38       0.437173   0.193207 -0.497664 -0.332847
# 39       0.582878   0.400793 -0.843836 -0.474763
# 40       0.807325   0.620179 -1.716088 -0.800731
# 41       0.823248   0.654678 -1.761006 -0.806922
# 42       0.339031   0.243123 -0.527778 -0.205882
# 43       0.406593   0.184227 -0.458716 -0.309013
# 44       0.424084   0.185563 -0.464953 -0.329927
# 45       0.612022   0.425642 -0.912329 -0.477918
# 46       0.810510   0.625515 -1.722397 -0.800731
# 47       0.826433   0.657134 -1.767296 -0.805100
# 48      -0.054299  -0.213140  0.082443  0.038825
# 49      -0.578947  -0.376327  0.256927  0.064182
# 50      -0.668919  -0.398378  0.281796  0.072389
# 51       0.512821   0.383156 -0.620930 -0.090173
# 52       0.651515   0.511647 -0.692759 -0.067245
# 53       0.671779   0.535249 -0.726916 -0.067888
# 54       0.214286   0.229972 -0.274472 -0.075342
# 55       0.392713   0.256317 -0.376307 -0.063404
# 56       0.414343   0.262488 -0.401408 -0.068156
# 57      -0.397260  -0.314939  0.170404  0.032529
# 58      -0.624000  -0.473618  0.132075  0.017259
# 59      -0.719298  -0.516622  0.134793  0.018163
# 60       0.180451   0.245950 -0.261036 -0.081050
# 61       0.384615   0.288133 -0.386760 -0.068966
# 62       0.410359   0.294497 -0.413732 -0.073743
# 63      -0.465753  -0.344684  0.198804  0.036726
# 64      -0.792000  -0.594072  0.168632  0.024365
# 65      -0.903509  -0.652482  0.170507  0.025227
# 66       0.157895   0.230061 -0.243762 -0.077626
# 67       0.372470   0.267883 -0.364111 -0.064516
# 68       0.394422   0.273545 -0.387324 -0.069274
# 69      -0.525114  -0.374428  0.209268  0.045121
# 70      -0.768000  -0.556443  0.165094  0.022335
# 71      -0.868421  -0.602394  0.168203  0.023209
# 72       0.184211   0.223028 -0.247601 -0.077626
# 73       0.380567   0.253917 -0.371080 -0.063404
# 74       0.406375   0.259605 -0.397887 -0.068156
# 75      -0.378995  -0.250606  0.183857  0.024134
# 76      -0.632000  -0.387849  0.148585  0.014213
# 77      -0.728070  -0.422207  0.153226  0.015136
# 78       0.128906   0.217087 -0.157509 -0.078857
# 79       0.365854   0.249754 -0.352332 -0.066069
# 80       0.394422   0.257116 -0.388401 -0.073281
# 81      -0.504673  -0.309987  0.228404  0.027397
# 82      -0.825000  -0.521106  0.178114  0.019289
# 83      -0.944954  -0.585199  0.178815  0.021169
# 84       0.109375   0.205598 -0.159341 -0.076571
# 85       0.337398   0.256468 -0.329879 -0.069429
# 86       0.366534   0.262801 -0.365554 -0.076663
# 87      -0.411215  -0.229555  0.196193  0.021075
# 88      -0.650000  -0.356117  0.140861  0.012183
# 89      -0.724771  -0.394701  0.138952  0.013105
# 90       0.144531   0.232479 -0.190476 -0.078857
# 91       0.373984   0.275628 -0.359240 -0.070549
# 92       0.402390   0.282213 -0.391916 -0.077790
# 93      -0.565421  -0.393927  0.240117  0.038988
# 94      -0.908333  -0.655667  0.188591  0.024365
# 95      -1.036697  -0.731384  0.190205  0.026210
# 96       0.082031   0.124379 -0.095238 -0.046857
# 97       0.288618   0.170466 -0.271157 -0.053751
# 98       0.318725   0.176099 -0.302285 -0.060879
# 99      -0.224299  -0.060324  0.114202  0.006322
# 100     -0.416667  -0.128348  0.101281  0.004061
# 101     -0.458716  -0.150297  0.097950  0.005040
# 102      0.044053   0.149183 -0.086957 -0.042623
# 103      0.360360   0.285599 -0.299363 -0.055616
# 104      0.384956   0.295770 -0.327391 -0.061336
# 105     -0.879581  -0.643932  0.285124  0.066386
# 106     -1.295652  -1.086279  0.231651  0.045685
# 107     -1.471698  -1.210994  0.234763  0.047427
#                         training_method   ABS REL   ABS REL      RMSE  \
# 0                          BOFedSCDepth -0.055814  0.644860  0.030499
# 1         BOFedSCDepth(ConstrainedLoss) -0.074419  0.629283  0.001143
# 2  BOFedSCDepth(ConstrainedLossRetrain) -0.009302  0.641745  0.058537
# 3                 BOFedSCDepth(Retrain) -0.009302  0.635514  0.055944
# 4                            FedSCDepth  0.412088  0.810510  0.173622
# 5           FedSCDepth(Average&Retrain)  0.406593  0.812102  0.125613
# 6                   FedSCDepth(Average)  0.420330  0.807325  0.191884
# 7                   FedSCDepth(Retrain)  0.406593  0.810510  0.184227
# 8                               SCDepth -0.578947  0.651515 -0.376327
#
#        RMSE        A1        A1        A3        A3
# 0  0.380131  0.004878 -0.799587  0.000000 -0.056867
# 1  0.371440  0.014634 -0.783058  0.008830 -0.056867
# 2  0.389089 -0.037398 -0.797521 -0.008830 -0.056867
# 3  0.384945 -0.037398 -0.795455 -0.006623 -0.056867
# 4  0.627537 -0.481651 -1.728707 -0.306152 -0.800731
# 5  0.617754 -0.470183 -1.716088 -0.288984 -0.800731
# 6  0.620179 -0.488532 -1.716088 -0.311874 -0.800731
# 7  0.625515 -0.458716 -1.722397 -0.309013 -0.800731
# 8  0.511647  0.256927 -0.692759  0.064182 -0.067245
#                         training_method   ABS REL   ABS REL      RMSE  \
# 0                          BOFedSCDepth  0.392713 -0.624000  0.256317
# 1         BOFedSCDepth(ConstrainedLoss)  0.384615 -0.792000  0.288133
# 2  BOFedSCDepth(ConstrainedLossRetrain)  0.372470 -0.768000  0.267883
# 3                 BOFedSCDepth(Retrain)  0.380567 -0.632000  0.253917
# 4                            FedSCDepth  0.365854 -0.825000  0.249754
# 5           FedSCDepth(Average&Retrain)  0.337398 -0.650000  0.256468
# 6                   FedSCDepth(Average)  0.373984 -0.908333  0.275628
# 7                   FedSCDepth(Retrain)  0.288618 -0.416667  0.170466
# 8                               SCDepth  0.360360 -1.295652  0.285599
#
#        RMSE        A1        A1        A3        A3
# 0 -0.473618 -0.376307  0.132075 -0.063404  0.017259
# 1 -0.594072 -0.386760  0.168632 -0.068966  0.024365
# 2 -0.556443 -0.364111  0.165094 -0.064516  0.022335
# 3 -0.387849 -0.371080  0.148585 -0.063404  0.014213
# 4 -0.521106 -0.352332  0.178114 -0.066069  0.019289
# 5 -0.356117 -0.329879  0.140861 -0.069429  0.012183
# 6 -0.655667 -0.359240  0.188591 -0.070549  0.024365
# 7 -0.128348 -0.271157  0.101281 -0.053751  0.004061
# 8 -1.086279 -0.299363  0.231651 -0.055616  0.045685
