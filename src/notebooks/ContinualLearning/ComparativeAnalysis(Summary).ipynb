# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
from comparative_analysis import ComparativeAnalysis
analysis = ComparativeAnalysis("domainadaptationexperiments.csv")

# %%
analysis.plot_metrics_differences(['test_abs_rel'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_abs_rel
# 0       0.121324
# 1      -0.055814
# 2      -0.089202
# 3       0.505051
# 4       0.644860
# 5       0.656863
# 6       0.084559
# 7      -0.074419
# 8      -0.103286
# 9       0.477273
# 10      0.629283
# 11      0.643791
# 12      0.132353
# 13     -0.009302
# 14     -0.032864
# 15      0.469697
# 16      0.641745
# 17      0.656863
# 18      0.136029
# 19     -0.009302
# 20     -0.032864
# 21      0.446970
# 22      0.635514
# 23      0.650327
# 24      0.327635
# 25      0.412088
# 26      0.431937
# 27     -0.066986
# 28      0.206667
# 29      0.258503
# 30      0.339031
# 31      0.406593
# 32      0.424084
# 33     -0.019139
# 34      0.206667
# 35      0.258503
# 36     -0.054299
# 37     -0.578947
# 38     -0.668919
# 39      0.512821
# 40      0.651515
# 41      0.671779
# 42      0.214286
# 43      0.392713
# 44      0.414343
# 45     -0.397260
# 46     -0.624000
# 47     -0.719298
# 48      0.180451
# 49      0.384615
# 50      0.410359
# 51     -0.465753
# 52     -0.792000
# 53     -0.903509
# 54      0.157895
# 55      0.372470
# 56      0.394422
# 57     -0.525114
# 58     -0.768000
# 59     -0.868421
# 60      0.184211
# 61      0.380567
# 62      0.406375
# 63     -0.378995
# 64     -0.632000
# 65     -0.728070
# 66      0.128906
# 67      0.365854
# 68      0.394422
# 69     -0.504673
# 70     -0.825000
# 71     -0.944954
# 72      0.082031
# 73      0.288618
# 74      0.318725
# 75     -0.224299
# 76     -0.416667
# 77     -0.458716
# 78      0.044053
# 79      0.360360
# 80      0.384956
# 81     -0.879581
# 82     -1.295652
# 83     -1.471698
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth       -0.055814         0.644860
# 1         BOFedSCDepth(ConstrainedLoss)       -0.074419         0.629283
# 2  BOFedSCDepth(ConstrainedLossRetrain)       -0.009302         0.641745
# 3                 BOFedSCDepth(Retrain)       -0.009302         0.635514
# 4                            FedSCDepth        0.412088         0.206667
# 5                   FedSCDepth(Retrain)        0.406593         0.206667
# 6                               SCDepth       -0.578947         0.651515
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0                          BOFedSCDepth        0.392713        -0.624000
# 1         BOFedSCDepth(ConstrainedLoss)        0.384615        -0.792000
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.372470        -0.768000
# 3                 BOFedSCDepth(Retrain)        0.380567        -0.632000
# 4                            FedSCDepth        0.365854        -0.825000
# 5                   FedSCDepth(Retrain)        0.288618        -0.416667
# 6                               SCDepth        0.360360        -1.295652

# %%
analysis.plot_metrics_differences(['test_sq_rel'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_sq_rel
# 0      0.168713
# 1      0.030673
# 2      0.013369
# 3      0.613036
# 4      0.771613
# 5      0.790188
# 6      0.101380
# 7     -0.024760
# 8     -0.041192
# 9      0.579817
# 10     0.756452
# 11     0.780793
# 12     0.216175
# 13     0.088507
# 14     0.073171
# 15     0.526845
# 16     0.758065
# 17     0.783577
# 18     0.224149
# 19     0.076312
# 20     0.062150
# 21     0.477285
# 22     0.754516
# 23     0.780793
# 24     0.458308
# 25     0.425285
# 26     0.469137
# 27     0.378168
# 28     0.757853
# 29     0.803131
# 30     0.473980
# 31     0.436788
# 32     0.478862
# 33     0.411739
# 34     0.766087
# 35     0.805840
# 36    -0.265987
# 37    -0.660437
# 38    -0.747221
# 39     0.706653
# 40     0.827555
# 41     0.850276
# 42     0.381514
# 43     0.423827
# 44     0.436854
# 45    -1.018269
# 46    -1.755470
# 47    -2.185410
# 48     0.381246
# 49     0.454050
# 50     0.468554
# 51    -1.142671
# 52    -2.252252
# 53    -2.793313
# 54     0.355124
# 55     0.430153
# 56     0.443465
# 57    -1.300565
# 58    -2.123552
# 59    -2.575988
# 60     0.364233
# 61     0.418380
# 62     0.431599
# 63    -0.809482
# 64    -1.460746
# 65    -1.805471
# 66     0.346242
# 67     0.414364
# 68     0.430890
# 69    -0.950042
# 70    -1.938320
# 71    -2.454976
# 72     0.223317
# 73     0.322757
# 74     0.336449
# 75    -0.240974
# 76    -0.580052
# 77    -0.748815
# 78     0.093529
# 79     0.382201
# 80     0.406269
# 81    -2.320946
# 82    -4.299191
# 83    -5.249216
#                         training_method  SQ REL (DDAD)  SQ REL (KITTI)
# 0                          BOFedSCDepth       0.030673        0.771613
# 1         BOFedSCDepth(ConstrainedLoss)      -0.024760        0.756452
# 2  BOFedSCDepth(ConstrainedLossRetrain)       0.088507        0.758065
# 3                 BOFedSCDepth(Retrain)       0.076312        0.754516
# 4                            FedSCDepth       0.425285        0.757853
# 5                   FedSCDepth(Retrain)       0.436788        0.766087
# 6                               SCDepth      -0.660437        0.827555
#                         training_method  SQ REL (DDAD)  SQ REL (KITTI)
# 0                          BOFedSCDepth       0.423827       -1.755470
# 1         BOFedSCDepth(ConstrainedLoss)       0.454050       -2.252252
# 2  BOFedSCDepth(ConstrainedLossRetrain)       0.430153       -2.123552
# 3                 BOFedSCDepth(Retrain)       0.418380       -1.460746
# 4                            FedSCDepth       0.414364       -1.938320
# 5                   FedSCDepth(Retrain)       0.322757       -0.580052
# 6                               SCDepth       0.382201       -4.299191

# %%
analysis.plot_metrics_differences(['test_log10'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_log10
# 0     0.109489
# 1     0.000000
# 2    -0.017544
# 3     0.398601
# 4     0.588710
# 5     0.613445
# 6     0.065693
# 7    -0.035398
# 8    -0.043860
# 9     0.377622
# 10    0.580645
# 11    0.596639
# 12    0.153285
# 13    0.044248
# 14    0.035088
# 15    0.377622
# 16    0.596774
# 17    0.613445
# 18    0.153285
# 19    0.044248
# 20    0.026316
# 21    0.363636
# 22    0.588710
# 23    0.613445
# 24    0.404040
# 25    0.532751
# 26    0.538136
# 27    0.041667
# 28    0.291667
# 29    0.352113
# 30    0.414141
# 31    0.528384
# 32    0.533898
# 33    0.062500
# 34    0.277778
# 35    0.338028
# 36   -0.187500
# 37   -0.735294
# 38   -0.848485
# 39    0.410596
# 40    0.585366
# 41    0.619835
# 42    0.283582
# 43    0.409836
# 44    0.427419
# 45   -0.260870
# 46   -0.400000
# 47   -0.480000
# 48    0.276119
# 49    0.426230
# 50    0.443548
# 51   -0.293478
# 52   -0.527273
# 53   -0.620000
# 54    0.253731
# 55    0.401639
# 56    0.427419
# 57   -0.326087
# 58   -0.509091
# 59   -0.600000
# 60    0.261194
# 61    0.401639
# 62    0.419355
# 63   -0.250000
# 64   -0.436364
# 65   -0.520000
# 66    0.236641
# 67    0.390244
# 68    0.420635
# 69   -0.322222
# 70   -0.596154
# 71   -0.702128
# 72    0.145038
# 73    0.308943
# 74    0.333333
# 75   -0.155556
# 76   -0.326923
# 77   -0.361702
# 78    0.160714
# 79    0.422018
# 80    0.441441
# 81   -0.559524
# 82   -0.900000
# 83   -1.021739
#                         training_method  LOG10 (DDAD)  LOG10 (KITTI)
# 0                          BOFedSCDepth      0.000000       0.588710
# 1         BOFedSCDepth(ConstrainedLoss)     -0.035398       0.580645
# 2  BOFedSCDepth(ConstrainedLossRetrain)      0.044248       0.596774
# 3                 BOFedSCDepth(Retrain)      0.044248       0.588710
# 4                            FedSCDepth      0.532751       0.291667
# 5                   FedSCDepth(Retrain)      0.528384       0.277778
# 6                               SCDepth     -0.735294       0.585366
#                         training_method  LOG10 (DDAD)  LOG10 (KITTI)
# 0                          BOFedSCDepth      0.409836      -0.400000
# 1         BOFedSCDepth(ConstrainedLoss)      0.426230      -0.527273
# 2  BOFedSCDepth(ConstrainedLossRetrain)      0.401639      -0.509091
# 3                 BOFedSCDepth(Retrain)      0.401639      -0.436364
# 4                            FedSCDepth      0.390244      -0.596154
# 5                   FedSCDepth(Retrain)      0.308943      -0.326923
# 6                               SCDepth      0.422018      -0.900000

# %%
analysis.plot_metrics_differences(['test_rmse'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_rmse
# 0    0.068081
# 1    0.030499
# 2    0.027323
# 3    0.267283
# 4    0.380131
# 5    0.396780
# 6    0.036222
# 7    0.001143
# 8   -0.001911
# 9    0.245628
# 10   0.371440
# 11   0.390586
# 12   0.103779
# 13   0.058537
# 14   0.054863
# 15   0.232818
# 16   0.389089
# 17   0.416047
# 18   0.106441
# 19   0.055944
# 20   0.053125
# 21   0.209435
# 22   0.384945
# 23   0.412607
# 24   0.234542
# 25   0.173622
# 26   0.175246
# 27   0.548234
# 28   0.729636
# 29   0.751604
# 30   0.243123
# 31   0.184227
# 32   0.185563
# 33   0.556442
# 34   0.728169
# 35   0.747521
# 36  -0.213140
# 37  -0.376327
# 38  -0.398378
# 39   0.383156
# 40   0.511647
# 41   0.535249
# 42   0.229972
# 43   0.256317
# 44   0.262488
# 45  -0.314939
# 46  -0.473618
# 47  -0.516622
# 48   0.245950
# 49   0.288133
# 50   0.294497
# 51  -0.344684
# 52  -0.594072
# 53  -0.652482
# 54   0.230061
# 55   0.267883
# 56   0.273545
# 57  -0.374428
# 58  -0.556443
# 59  -0.602394
# 60   0.223028
# 61   0.253917
# 62   0.259605
# 63  -0.250606
# 64  -0.387849
# 65  -0.422207
# 66   0.217087
# 67   0.249754
# 68   0.257116
# 69  -0.309987
# 70  -0.521106
# 71  -0.585199
# 72   0.124379
# 73   0.170466
# 74   0.176099
# 75  -0.060324
# 76  -0.128348
# 77  -0.150297
# 78   0.149183
# 79   0.285599
# 80   0.295770
# 81  -0.643932
# 82  -1.086279
# 83  -1.210994
#                         training_method  RMSE (DDAD)  RMSE (KITTI)
# 0                          BOFedSCDepth     0.030499      0.380131
# 1         BOFedSCDepth(ConstrainedLoss)     0.001143      0.371440
# 2  BOFedSCDepth(ConstrainedLossRetrain)     0.058537      0.389089
# 3                 BOFedSCDepth(Retrain)     0.055944      0.384945
# 4                            FedSCDepth     0.173622      0.729636
# 5                   FedSCDepth(Retrain)     0.184227      0.728169
# 6                               SCDepth    -0.376327      0.511647
#                         training_method  RMSE (DDAD)  RMSE (KITTI)
# 0                          BOFedSCDepth     0.256317     -0.473618
# 1         BOFedSCDepth(ConstrainedLoss)     0.288133     -0.594072
# 2  BOFedSCDepth(ConstrainedLossRetrain)     0.267883     -0.556443
# 3                 BOFedSCDepth(Retrain)     0.253917     -0.387849
# 4                            FedSCDepth     0.249754     -0.521106
# 5                   FedSCDepth(Retrain)     0.170466     -0.128348
# 6                               SCDepth     0.285599     -1.086279

# %%
analysis.plot_metrics_differences(['test_rmse_log'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_rmse_log
# 0        0.076923
# 1       -0.002625
# 2       -0.018421
# 3        0.287879
# 4        0.484594
# 5        0.530792
# 6        0.042184
# 7       -0.041995
# 8       -0.057895
# 9        0.262626
# 10       0.476190
# 11       0.524927
# 12       0.116625
# 13       0.036745
# 14       0.023684
# 15       0.262626
# 16       0.484594
# 17       0.536657
# 18       0.116625
# 19       0.028871
# 20       0.018421
# 21       0.244949
# 22       0.481793
# 23       0.536657
# 24       0.347197
# 25       0.505391
# 26       0.509908
# 27       0.013201
# 28       0.295455
# 29       0.386100
# 30       0.354430
# 31       0.506739
# 32       0.511229
# 33       0.026403
# 34       0.291667
# 35       0.378378
# 36      -0.178451
# 37      -0.574297
# 38      -0.648760
# 39       0.302600
# 40       0.493188
# 41       0.549020
# 42       0.232911
# 43       0.346535
# 44       0.365196
# 45      -0.191638
# 46      -0.363158
# 47      -0.455090
# 48       0.245570
# 49       0.368812
# 50       0.389706
# 51      -0.212544
# 52      -0.447368
# 53      -0.568862
# 54       0.225316
# 55       0.349010
# 56       0.370098
# 57      -0.229965
# 58      -0.426316
# 59      -0.538922
# 60       0.227848
# 61       0.339109
# 62       0.360294
# 63      -0.170732
# 64      -0.342105
# 65      -0.437126
# 66       0.220253
# 67       0.342995
# 68       0.362768
# 69      -0.193772
# 70      -0.440860
# 71      -0.571429
# 72       0.144304
# 73       0.268116
# 74       0.286396
# 75      -0.069204
# 76      -0.215054
# 77      -0.279503
# 78       0.137931
# 79       0.346995
# 80       0.372973
# 81      -0.358156
# 82      -0.715847
# 83      -0.905660
#                         training_method  RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0                          BOFedSCDepth        -0.002625          0.484594
# 1         BOFedSCDepth(ConstrainedLoss)        -0.041995          0.476190
# 2  BOFedSCDepth(ConstrainedLossRetrain)         0.036745          0.484594
# 3                 BOFedSCDepth(Retrain)         0.028871          0.481793
# 4                            FedSCDepth         0.505391          0.295455
# 5                   FedSCDepth(Retrain)         0.506739          0.291667
# 6                               SCDepth        -0.574297          0.493188
#                         training_method  RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0                          BOFedSCDepth         0.346535         -0.363158
# 1         BOFedSCDepth(ConstrainedLoss)         0.368812         -0.447368
# 2  BOFedSCDepth(ConstrainedLossRetrain)         0.349010         -0.426316
# 3                 BOFedSCDepth(Retrain)         0.339109         -0.342105
# 4                            FedSCDepth         0.342995         -0.440860
# 5                   FedSCDepth(Retrain)         0.268116         -0.215054
# 6                               SCDepth         0.346995         -0.715847

# %%
analysis.plot_metrics_differences(['test_a1'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#      test_a1
# 0  -0.090559
# 1   0.004878
# 2   0.016313
# 3  -0.643836
# 4  -0.799587
# 5  -0.788306
# 6  -0.073218
# 7   0.014634
# 8   0.022838
# 9  -0.579909
# 10 -0.783058
# 11 -0.774194
# 12 -0.154143
# 13 -0.037398
# 14 -0.027732
# 15 -0.611872
# 16 -0.797521
# 17 -0.788306
# 18 -0.146435
# 19 -0.037398
# 20 -0.027732
# 21 -0.586758
# 22 -0.795455
# 23 -0.786290
# 24 -0.505051
# 25 -0.481651
# 26 -0.492991
# 27 -0.027108
# 28 -0.094937
# 29 -0.108040
# 30 -0.527778
# 31 -0.458716
# 32 -0.464953
# 33 -0.051205
# 34 -0.092405
# 35 -0.105528
# 36  0.082443
# 37  0.256927
# 38  0.281796
# 39 -0.620930
# 40 -0.692759
# 41 -0.726916
# 42 -0.274472
# 43 -0.376307
# 44 -0.401408
# 45  0.170404
# 46  0.132075
# 47  0.134793
# 48 -0.261036
# 49 -0.386760
# 50 -0.413732
# 51  0.198804
# 52  0.168632
# 53  0.170507
# 54 -0.243762
# 55 -0.364111
# 56 -0.387324
# 57  0.209268
# 58  0.165094
# 59  0.168203
# 60 -0.247601
# 61 -0.371080
# 62 -0.397887
# 63  0.183857
# 64  0.148585
# 65  0.153226
# 66 -0.157509
# 67 -0.352332
# 68 -0.388401
# 69  0.228404
# 70  0.178114
# 71  0.178815
# 72 -0.095238
# 73 -0.271157
# 74 -0.302285
# 75  0.114202
# 76  0.101281
# 77  0.097950
# 78 -0.086957
# 79 -0.299363
# 80 -0.327391
# 81  0.285124
# 82  0.231651
# 83  0.234763
#                         training_method  A1 (DDAD)  A1 (KITTI)
# 0                          BOFedSCDepth   0.004878   -0.799587
# 1         BOFedSCDepth(ConstrainedLoss)   0.014634   -0.783058
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.037398   -0.797521
# 3                 BOFedSCDepth(Retrain)  -0.037398   -0.795455
# 4                            FedSCDepth  -0.481651   -0.094937
# 5                   FedSCDepth(Retrain)  -0.458716   -0.092405
# 6                               SCDepth   0.256927   -0.692759
#                         training_method  A1 (DDAD)  A1 (KITTI)
# 0                          BOFedSCDepth  -0.376307    0.132075
# 1         BOFedSCDepth(ConstrainedLoss)  -0.386760    0.168632
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.364111    0.165094
# 3                 BOFedSCDepth(Retrain)  -0.371080    0.148585
# 4                            FedSCDepth  -0.352332    0.178114
# 5                   FedSCDepth(Retrain)  -0.271157    0.101281
# 6                               SCDepth  -0.299363    0.231651

# %%
analysis.plot_metrics_differences(['test_a2'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#      test_a2
# 0  -0.073529
# 1  -0.003628
# 2   0.003632
# 3  -0.225585
# 4  -0.206767
# 5  -0.198520
# 6  -0.057487
# 7   0.002418
# 8   0.009685
# 9  -0.213205
# 10 -0.205514
# 11 -0.199753
# 12 -0.094920
# 13 -0.016929
# 14 -0.009685
# 15 -0.207703
# 16 -0.206767
# 17 -0.200986
# 18 -0.092246
# 19 -0.018138
# 20 -0.012107
# 21 -0.199450
# 22 -0.206767
# 23 -0.200986
# 24 -0.344942
# 25 -0.364668
# 26 -0.384106
# 27  0.002299
# 28 -0.054765
# 29 -0.069079
# 30 -0.353234
# 31 -0.371151
# 32 -0.389073
# 33  0.000000
# 34 -0.053669
# 35 -0.066886
# 36  0.061155
# 37  0.108460
# 38  0.122294
# 39 -0.251429
# 40 -0.207026
# 41 -0.210461
# 42 -0.138743
# 43 -0.129950
# 44 -0.137157
# 45  0.074201
# 46  0.052138
# 47  0.053608
# 48 -0.143979
# 49 -0.137376
# 50 -0.147132
# 51  0.081050
# 52  0.064651
# 53  0.067010
# 54 -0.133508
# 55 -0.132426
# 56 -0.140898
# 57  0.092466
# 58  0.061522
# 59  0.062887
# 60 -0.129581
# 61 -0.129950
# 62 -0.138404
# 63  0.061644
# 64  0.046924
# 65  0.048454
# 66 -0.124191
# 67 -0.122525
# 68 -0.133750
# 69  0.082192
# 70  0.060354
# 71  0.060700
# 72 -0.072445
# 73 -0.097772
# 74 -0.107500
# 75  0.030822
# 76  0.024974
# 77  0.023663
# 78 -0.048426
# 79 -0.100950
# 80 -0.111377
# 81  0.147026
# 82  0.107996
# 83  0.113052
#                         training_method  A2 (DDAD)  A2 (KITTI)
# 0                          BOFedSCDepth  -0.003628   -0.206767
# 1         BOFedSCDepth(ConstrainedLoss)   0.002418   -0.205514
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.016929   -0.206767
# 3                 BOFedSCDepth(Retrain)  -0.018138   -0.206767
# 4                            FedSCDepth  -0.364668   -0.054765
# 5                   FedSCDepth(Retrain)  -0.371151   -0.053669
# 6                               SCDepth   0.108460   -0.207026
#                         training_method  A2 (DDAD)  A2 (KITTI)
# 0                          BOFedSCDepth  -0.129950    0.052138
# 1         BOFedSCDepth(ConstrainedLoss)  -0.137376    0.064651
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.132426    0.061522
# 3                 BOFedSCDepth(Retrain)  -0.129950    0.046924
# 4                            FedSCDepth  -0.122525    0.060354
# 5                   FedSCDepth(Retrain)  -0.097772    0.024974
# 6                               SCDepth  -0.100950    0.107996

# %%
analysis.plot_metrics_differences(['test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#      test_a3
# 0  -0.037080
# 1   0.000000
# 2   0.003315
# 3  -0.073780
# 4  -0.056867
# 5  -0.052017
# 6  -0.023175
# 7   0.008830
# 8   0.012155
# 9  -0.072645
# 10 -0.056867
# 11 -0.053079
# 12 -0.042874
# 13 -0.008830
# 14 -0.005525
# 15 -0.065834
# 16 -0.056867
# 17 -0.053079
# 18 -0.050985
# 19 -0.006623
# 20 -0.003315
# 21 -0.061294
# 22 -0.056867
# 23 -0.053079
# 24 -0.200535
# 25 -0.306152
# 26 -0.327007
# 27  0.005308
# 28 -0.030335
# 29 -0.037657
# 30 -0.205882
# 31 -0.309013
# 32 -0.329927
# 33  0.005308
# 34 -0.030335
# 35 -0.036611
# 36  0.038825
# 37  0.064182
# 38  0.072389
# 39 -0.090173
# 40 -0.067245
# 41 -0.067888
# 42 -0.075342
# 43 -0.063404
# 44 -0.068156
# 45  0.032529
# 46  0.017259
# 47  0.018163
# 48 -0.081050
# 49 -0.068966
# 50 -0.073743
# 51  0.036726
# 52  0.024365
# 53  0.025227
# 54 -0.077626
# 55 -0.064516
# 56 -0.069274
# 57  0.045121
# 58  0.022335
# 59  0.023209
# 60 -0.077626
# 61 -0.063404
# 62 -0.068156
# 63  0.024134
# 64  0.014213
# 65  0.015136
# 66 -0.078857
# 67 -0.066069
# 68 -0.073281
# 69  0.027397
# 70  0.019289
# 71  0.021169
# 72 -0.046857
# 73 -0.053751
# 74 -0.060879
# 75  0.006322
# 76  0.004061
# 77  0.005040
# 78 -0.042623
# 79 -0.055616
# 80 -0.061336
# 81  0.066386
# 82  0.045685
# 83  0.047427
#                         training_method  A3 (DDAD)  A3 (KITTI)
# 0                          BOFedSCDepth   0.000000   -0.056867
# 1         BOFedSCDepth(ConstrainedLoss)   0.008830   -0.056867
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.008830   -0.056867
# 3                 BOFedSCDepth(Retrain)  -0.006623   -0.056867
# 4                            FedSCDepth  -0.306152   -0.030335
# 5                   FedSCDepth(Retrain)  -0.309013   -0.030335
# 6                               SCDepth   0.064182   -0.067245
#                         training_method  A3 (DDAD)  A3 (KITTI)
# 0                          BOFedSCDepth  -0.063404    0.017259
# 1         BOFedSCDepth(ConstrainedLoss)  -0.068966    0.024365
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.064516    0.022335
# 3                 BOFedSCDepth(Retrain)  -0.063404    0.014213
# 4                            FedSCDepth  -0.066069    0.019289
# 5                   FedSCDepth(Retrain)  -0.053751    0.004061
# 6                               SCDepth  -0.055616    0.045685

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log', 'test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_abs_rel  test_sq_rel  test_log10  test_rmse  test_rmse_log   test_a1  \
# 0       0.121324     0.168713    0.109489   0.068081       0.076923 -0.090559
# 1      -0.055814     0.030673    0.000000   0.030499      -0.002625  0.004878
# 2      -0.089202     0.013369   -0.017544   0.027323      -0.018421  0.016313
# 3       0.505051     0.613036    0.398601   0.267283       0.287879 -0.643836
# 4       0.644860     0.771613    0.588710   0.380131       0.484594 -0.799587
# 5       0.656863     0.790188    0.613445   0.396780       0.530792 -0.788306
# 6       0.084559     0.101380    0.065693   0.036222       0.042184 -0.073218
# 7      -0.074419    -0.024760   -0.035398   0.001143      -0.041995  0.014634
# 8      -0.103286    -0.041192   -0.043860  -0.001911      -0.057895  0.022838
# 9       0.477273     0.579817    0.377622   0.245628       0.262626 -0.579909
# 10      0.629283     0.756452    0.580645   0.371440       0.476190 -0.783058
# 11      0.643791     0.780793    0.596639   0.390586       0.524927 -0.774194
# 12      0.132353     0.216175    0.153285   0.103779       0.116625 -0.154143
# 13     -0.009302     0.088507    0.044248   0.058537       0.036745 -0.037398
# 14     -0.032864     0.073171    0.035088   0.054863       0.023684 -0.027732
# 15      0.469697     0.526845    0.377622   0.232818       0.262626 -0.611872
# 16      0.641745     0.758065    0.596774   0.389089       0.484594 -0.797521
# 17      0.656863     0.783577    0.613445   0.416047       0.536657 -0.788306
# 18      0.136029     0.224149    0.153285   0.106441       0.116625 -0.146435
# 19     -0.009302     0.076312    0.044248   0.055944       0.028871 -0.037398
# 20     -0.032864     0.062150    0.026316   0.053125       0.018421 -0.027732
# 21      0.446970     0.477285    0.363636   0.209435       0.244949 -0.586758
# 22      0.635514     0.754516    0.588710   0.384945       0.481793 -0.795455
# 23      0.650327     0.780793    0.613445   0.412607       0.536657 -0.786290
# 24      0.327635     0.458308    0.404040   0.234542       0.347197 -0.505051
# 25      0.412088     0.425285    0.532751   0.173622       0.505391 -0.481651
# 26      0.431937     0.469137    0.538136   0.175246       0.509908 -0.492991
# 27     -0.066986     0.378168    0.041667   0.548234       0.013201 -0.027108
# 28      0.206667     0.757853    0.291667   0.729636       0.295455 -0.094937
# 29      0.258503     0.803131    0.352113   0.751604       0.386100 -0.108040
# 30      0.339031     0.473980    0.414141   0.243123       0.354430 -0.527778
# 31      0.406593     0.436788    0.528384   0.184227       0.506739 -0.458716
# 32      0.424084     0.478862    0.533898   0.185563       0.511229 -0.464953
# 33     -0.019139     0.411739    0.062500   0.556442       0.026403 -0.051205
# 34      0.206667     0.766087    0.277778   0.728169       0.291667 -0.092405
# 35      0.258503     0.805840    0.338028   0.747521       0.378378 -0.105528
# 36     -0.054299    -0.265987   -0.187500  -0.213140      -0.178451  0.082443
# 37     -0.578947    -0.660437   -0.735294  -0.376327      -0.574297  0.256927
# 38     -0.668919    -0.747221   -0.848485  -0.398378      -0.648760  0.281796
# 39      0.512821     0.706653    0.410596   0.383156       0.302600 -0.620930
# 40      0.651515     0.827555    0.585366   0.511647       0.493188 -0.692759
# 41      0.671779     0.850276    0.619835   0.535249       0.549020 -0.726916
# 42      0.214286     0.381514    0.283582   0.229972       0.232911 -0.274472
# 43      0.392713     0.423827    0.409836   0.256317       0.346535 -0.376307
# 44      0.414343     0.436854    0.427419   0.262488       0.365196 -0.401408
# 45     -0.397260    -1.018269   -0.260870  -0.314939      -0.191638  0.170404
# 46     -0.624000    -1.755470   -0.400000  -0.473618      -0.363158  0.132075
# 47     -0.719298    -2.185410   -0.480000  -0.516622      -0.455090  0.134793
# 48      0.180451     0.381246    0.276119   0.245950       0.245570 -0.261036
# 49      0.384615     0.454050    0.426230   0.288133       0.368812 -0.386760
# 50      0.410359     0.468554    0.443548   0.294497       0.389706 -0.413732
# 51     -0.465753    -1.142671   -0.293478  -0.344684      -0.212544  0.198804
# 52     -0.792000    -2.252252   -0.527273  -0.594072      -0.447368  0.168632
# 53     -0.903509    -2.793313   -0.620000  -0.652482      -0.568862  0.170507
# 54      0.157895     0.355124    0.253731   0.230061       0.225316 -0.243762
# 55      0.372470     0.430153    0.401639   0.267883       0.349010 -0.364111
# 56      0.394422     0.443465    0.427419   0.273545       0.370098 -0.387324
# 57     -0.525114    -1.300565   -0.326087  -0.374428      -0.229965  0.209268
# 58     -0.768000    -2.123552   -0.509091  -0.556443      -0.426316  0.165094
# 59     -0.868421    -2.575988   -0.600000  -0.602394      -0.538922  0.168203
# 60      0.184211     0.364233    0.261194   0.223028       0.227848 -0.247601
# 61      0.380567     0.418380    0.401639   0.253917       0.339109 -0.371080
# 62      0.406375     0.431599    0.419355   0.259605       0.360294 -0.397887
# 63     -0.378995    -0.809482   -0.250000  -0.250606      -0.170732  0.183857
# 64     -0.632000    -1.460746   -0.436364  -0.387849      -0.342105  0.148585
# 65     -0.728070    -1.805471   -0.520000  -0.422207      -0.437126  0.153226
# 66      0.128906     0.346242    0.236641   0.217087       0.220253 -0.157509
# 67      0.365854     0.414364    0.390244   0.249754       0.342995 -0.352332
# 68      0.394422     0.430890    0.420635   0.257116       0.362768 -0.388401
# 69     -0.504673    -0.950042   -0.322222  -0.309987      -0.193772  0.228404
# 70     -0.825000    -1.938320   -0.596154  -0.521106      -0.440860  0.178114
# 71     -0.944954    -2.454976   -0.702128  -0.585199      -0.571429  0.178815
# 72      0.082031     0.223317    0.145038   0.124379       0.144304 -0.095238
# 73      0.288618     0.322757    0.308943   0.170466       0.268116 -0.271157
# 74      0.318725     0.336449    0.333333   0.176099       0.286396 -0.302285
# 75     -0.224299    -0.240974   -0.155556  -0.060324      -0.069204  0.114202
# 76     -0.416667    -0.580052   -0.326923  -0.128348      -0.215054  0.101281
# 77     -0.458716    -0.748815   -0.361702  -0.150297      -0.279503  0.097950
# 78      0.044053     0.093529    0.160714   0.149183       0.137931 -0.086957
# 79      0.360360     0.382201    0.422018   0.285599       0.346995 -0.299363
# 80      0.384956     0.406269    0.441441   0.295770       0.372973 -0.327391
# 81     -0.879581    -2.320946   -0.559524  -0.643932      -0.358156  0.285124
# 82     -1.295652    -4.299191   -0.900000  -1.086279      -0.715847  0.231651
# 83     -1.471698    -5.249216   -1.021739  -1.210994      -0.905660  0.234763
#
#      test_a2   test_a3
# 0  -0.073529 -0.037080
# 1  -0.003628  0.000000
# 2   0.003632  0.003315
# 3  -0.225585 -0.073780
# 4  -0.206767 -0.056867
# 5  -0.198520 -0.052017
# 6  -0.057487 -0.023175
# 7   0.002418  0.008830
# 8   0.009685  0.012155
# 9  -0.213205 -0.072645
# 10 -0.205514 -0.056867
# 11 -0.199753 -0.053079
# 12 -0.094920 -0.042874
# 13 -0.016929 -0.008830
# 14 -0.009685 -0.005525
# 15 -0.207703 -0.065834
# 16 -0.206767 -0.056867
# 17 -0.200986 -0.053079
# 18 -0.092246 -0.050985
# 19 -0.018138 -0.006623
# 20 -0.012107 -0.003315
# 21 -0.199450 -0.061294
# 22 -0.206767 -0.056867
# 23 -0.200986 -0.053079
# 24 -0.344942 -0.200535
# 25 -0.364668 -0.306152
# 26 -0.384106 -0.327007
# 27  0.002299  0.005308
# 28 -0.054765 -0.030335
# 29 -0.069079 -0.037657
# 30 -0.353234 -0.205882
# 31 -0.371151 -0.309013
# 32 -0.389073 -0.329927
# 33  0.000000  0.005308
# 34 -0.053669 -0.030335
# 35 -0.066886 -0.036611
# 36  0.061155  0.038825
# 37  0.108460  0.064182
# 38  0.122294  0.072389
# 39 -0.251429 -0.090173
# 40 -0.207026 -0.067245
# 41 -0.210461 -0.067888
# 42 -0.138743 -0.075342
# 43 -0.129950 -0.063404
# 44 -0.137157 -0.068156
# 45  0.074201  0.032529
# 46  0.052138  0.017259
# 47  0.053608  0.018163
# 48 -0.143979 -0.081050
# 49 -0.137376 -0.068966
# 50 -0.147132 -0.073743
# 51  0.081050  0.036726
# 52  0.064651  0.024365
# 53  0.067010  0.025227
# 54 -0.133508 -0.077626
# 55 -0.132426 -0.064516
# 56 -0.140898 -0.069274
# 57  0.092466  0.045121
# 58  0.061522  0.022335
# 59  0.062887  0.023209
# 60 -0.129581 -0.077626
# 61 -0.129950 -0.063404
# 62 -0.138404 -0.068156
# 63  0.061644  0.024134
# 64  0.046924  0.014213
# 65  0.048454  0.015136
# 66 -0.124191 -0.078857
# 67 -0.122525 -0.066069
# 68 -0.133750 -0.073281
# 69  0.082192  0.027397
# 70  0.060354  0.019289
# 71  0.060700  0.021169
# 72 -0.072445 -0.046857
# 73 -0.097772 -0.053751
# 74 -0.107500 -0.060879
# 75  0.030822  0.006322
# 76  0.024974  0.004061
# 77  0.023663  0.005040
# 78 -0.048426 -0.042623
# 79 -0.100950 -0.055616
# 80 -0.111377 -0.061336
# 81  0.147026  0.066386
# 82  0.107996  0.045685
# 83  0.113052  0.047427
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)  \
# 0                          BOFedSCDepth       -0.055814         0.644860
# 1         BOFedSCDepth(ConstrainedLoss)       -0.074419         0.629283
# 2  BOFedSCDepth(ConstrainedLossRetrain)       -0.009302         0.641745
# 3                 BOFedSCDepth(Retrain)       -0.009302         0.635514
# 4                            FedSCDepth        0.412088         0.206667
# 5                   FedSCDepth(Retrain)        0.406593         0.206667
# 6                               SCDepth       -0.578947         0.651515
#
#    SQ REL (DDAD)  SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  \
# 0       0.030673        0.771613      0.000000       0.588710     0.030499
# 1      -0.024760        0.756452     -0.035398       0.580645     0.001143
# 2       0.088507        0.758065      0.044248       0.596774     0.058537
# 3       0.076312        0.754516      0.044248       0.588710     0.055944
# 4       0.425285        0.757853      0.532751       0.291667     0.173622
# 5       0.436788        0.766087      0.528384       0.277778     0.184227
# 6      -0.660437        0.827555     -0.735294       0.585366    -0.376327
#
#    RMSE (KITTI)  RMSE LOG (DDAD)  RMSE LOG (KITTI)  A1 (DDAD)  A1 (KITTI)  \
# 0      0.380131        -0.002625          0.484594   0.004878   -0.799587
# 1      0.371440        -0.041995          0.476190   0.014634   -0.783058
# 2      0.389089         0.036745          0.484594  -0.037398   -0.797521
# 3      0.384945         0.028871          0.481793  -0.037398   -0.795455
# 4      0.729636         0.505391          0.295455  -0.481651   -0.094937
# 5      0.728169         0.506739          0.291667  -0.458716   -0.092405
# 6      0.511647        -0.574297          0.493188   0.256927   -0.692759
#
#    A2 (DDAD)  A2 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0  -0.003628   -0.206767   0.000000   -0.056867
# 1   0.002418   -0.205514   0.008830   -0.056867
# 2  -0.016929   -0.206767  -0.008830   -0.056867
# 3  -0.018138   -0.206767  -0.006623   -0.056867
# 4  -0.364668   -0.054765  -0.306152   -0.030335
# 5  -0.371151   -0.053669  -0.309013   -0.030335
# 6   0.108460   -0.207026   0.064182   -0.067245
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)  \
# 0                          BOFedSCDepth        0.392713        -0.624000
# 1         BOFedSCDepth(ConstrainedLoss)        0.384615        -0.792000
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.372470        -0.768000
# 3                 BOFedSCDepth(Retrain)        0.380567        -0.632000
# 4                            FedSCDepth        0.365854        -0.825000
# 5                   FedSCDepth(Retrain)        0.288618        -0.416667
# 6                               SCDepth        0.360360        -1.295652
#
#    SQ REL (DDAD)  SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  \
# 0       0.423827       -1.755470      0.409836      -0.400000     0.256317
# 1       0.454050       -2.252252      0.426230      -0.527273     0.288133
# 2       0.430153       -2.123552      0.401639      -0.509091     0.267883
# 3       0.418380       -1.460746      0.401639      -0.436364     0.253917
# 4       0.414364       -1.938320      0.390244      -0.596154     0.249754
# 5       0.322757       -0.580052      0.308943      -0.326923     0.170466
# 6       0.382201       -4.299191      0.422018      -0.900000     0.285599
#
#    RMSE (KITTI)  RMSE LOG (DDAD)  RMSE LOG (KITTI)  A1 (DDAD)  A1 (KITTI)  \
# 0     -0.473618         0.346535         -0.363158  -0.376307    0.132075
# 1     -0.594072         0.368812         -0.447368  -0.386760    0.168632
# 2     -0.556443         0.349010         -0.426316  -0.364111    0.165094
# 3     -0.387849         0.339109         -0.342105  -0.371080    0.148585
# 4     -0.521106         0.342995         -0.440860  -0.352332    0.178114
# 5     -0.128348         0.268116         -0.215054  -0.271157    0.101281
# 6     -1.086279         0.346995         -0.715847  -0.299363    0.231651
#
#    A2 (DDAD)  A2 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0  -0.129950    0.052138  -0.063404    0.017259
# 1  -0.137376    0.064651  -0.068966    0.024365
# 2  -0.132426    0.061522  -0.064516    0.022335
# 3  -0.129950    0.046924  -0.063404    0.014213
# 4  -0.122525    0.060354  -0.066069    0.019289
# 5  -0.097772    0.024974  -0.053751    0.004061
# 6  -0.100950    0.107996  -0.055616    0.045685

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_abs_rel  test_sq_rel  test_log10  test_rmse  test_rmse_log
# 0       0.121324     0.168713    0.109489   0.068081       0.076923
# 1      -0.055814     0.030673    0.000000   0.030499      -0.002625
# 2      -0.089202     0.013369   -0.017544   0.027323      -0.018421
# 3       0.505051     0.613036    0.398601   0.267283       0.287879
# 4       0.644860     0.771613    0.588710   0.380131       0.484594
# 5       0.656863     0.790188    0.613445   0.396780       0.530792
# 6       0.084559     0.101380    0.065693   0.036222       0.042184
# 7      -0.074419    -0.024760   -0.035398   0.001143      -0.041995
# 8      -0.103286    -0.041192   -0.043860  -0.001911      -0.057895
# 9       0.477273     0.579817    0.377622   0.245628       0.262626
# 10      0.629283     0.756452    0.580645   0.371440       0.476190
# 11      0.643791     0.780793    0.596639   0.390586       0.524927
# 12      0.132353     0.216175    0.153285   0.103779       0.116625
# 13     -0.009302     0.088507    0.044248   0.058537       0.036745
# 14     -0.032864     0.073171    0.035088   0.054863       0.023684
# 15      0.469697     0.526845    0.377622   0.232818       0.262626
# 16      0.641745     0.758065    0.596774   0.389089       0.484594
# 17      0.656863     0.783577    0.613445   0.416047       0.536657
# 18      0.136029     0.224149    0.153285   0.106441       0.116625
# 19     -0.009302     0.076312    0.044248   0.055944       0.028871
# 20     -0.032864     0.062150    0.026316   0.053125       0.018421
# 21      0.446970     0.477285    0.363636   0.209435       0.244949
# 22      0.635514     0.754516    0.588710   0.384945       0.481793
# 23      0.650327     0.780793    0.613445   0.412607       0.536657
# 24      0.327635     0.458308    0.404040   0.234542       0.347197
# 25      0.412088     0.425285    0.532751   0.173622       0.505391
# 26      0.431937     0.469137    0.538136   0.175246       0.509908
# 27     -0.066986     0.378168    0.041667   0.548234       0.013201
# 28      0.206667     0.757853    0.291667   0.729636       0.295455
# 29      0.258503     0.803131    0.352113   0.751604       0.386100
# 30      0.339031     0.473980    0.414141   0.243123       0.354430
# 31      0.406593     0.436788    0.528384   0.184227       0.506739
# 32      0.424084     0.478862    0.533898   0.185563       0.511229
# 33     -0.019139     0.411739    0.062500   0.556442       0.026403
# 34      0.206667     0.766087    0.277778   0.728169       0.291667
# 35      0.258503     0.805840    0.338028   0.747521       0.378378
# 36     -0.054299    -0.265987   -0.187500  -0.213140      -0.178451
# 37     -0.578947    -0.660437   -0.735294  -0.376327      -0.574297
# 38     -0.668919    -0.747221   -0.848485  -0.398378      -0.648760
# 39      0.512821     0.706653    0.410596   0.383156       0.302600
# 40      0.651515     0.827555    0.585366   0.511647       0.493188
# 41      0.671779     0.850276    0.619835   0.535249       0.549020
# 42      0.214286     0.381514    0.283582   0.229972       0.232911
# 43      0.392713     0.423827    0.409836   0.256317       0.346535
# 44      0.414343     0.436854    0.427419   0.262488       0.365196
# 45     -0.397260    -1.018269   -0.260870  -0.314939      -0.191638
# 46     -0.624000    -1.755470   -0.400000  -0.473618      -0.363158
# 47     -0.719298    -2.185410   -0.480000  -0.516622      -0.455090
# 48      0.180451     0.381246    0.276119   0.245950       0.245570
# 49      0.384615     0.454050    0.426230   0.288133       0.368812
# 50      0.410359     0.468554    0.443548   0.294497       0.389706
# 51     -0.465753    -1.142671   -0.293478  -0.344684      -0.212544
# 52     -0.792000    -2.252252   -0.527273  -0.594072      -0.447368
# 53     -0.903509    -2.793313   -0.620000  -0.652482      -0.568862
# 54      0.157895     0.355124    0.253731   0.230061       0.225316
# 55      0.372470     0.430153    0.401639   0.267883       0.349010
# 56      0.394422     0.443465    0.427419   0.273545       0.370098
# 57     -0.525114    -1.300565   -0.326087  -0.374428      -0.229965
# 58     -0.768000    -2.123552   -0.509091  -0.556443      -0.426316
# 59     -0.868421    -2.575988   -0.600000  -0.602394      -0.538922
# 60      0.184211     0.364233    0.261194   0.223028       0.227848
# 61      0.380567     0.418380    0.401639   0.253917       0.339109
# 62      0.406375     0.431599    0.419355   0.259605       0.360294
# 63     -0.378995    -0.809482   -0.250000  -0.250606      -0.170732
# 64     -0.632000    -1.460746   -0.436364  -0.387849      -0.342105
# 65     -0.728070    -1.805471   -0.520000  -0.422207      -0.437126
# 66      0.128906     0.346242    0.236641   0.217087       0.220253
# 67      0.365854     0.414364    0.390244   0.249754       0.342995
# 68      0.394422     0.430890    0.420635   0.257116       0.362768
# 69     -0.504673    -0.950042   -0.322222  -0.309987      -0.193772
# 70     -0.825000    -1.938320   -0.596154  -0.521106      -0.440860
# 71     -0.944954    -2.454976   -0.702128  -0.585199      -0.571429
# 72      0.082031     0.223317    0.145038   0.124379       0.144304
# 73      0.288618     0.322757    0.308943   0.170466       0.268116
# 74      0.318725     0.336449    0.333333   0.176099       0.286396
# 75     -0.224299    -0.240974   -0.155556  -0.060324      -0.069204
# 76     -0.416667    -0.580052   -0.326923  -0.128348      -0.215054
# 77     -0.458716    -0.748815   -0.361702  -0.150297      -0.279503
# 78      0.044053     0.093529    0.160714   0.149183       0.137931
# 79      0.360360     0.382201    0.422018   0.285599       0.346995
# 80      0.384956     0.406269    0.441441   0.295770       0.372973
# 81     -0.879581    -2.320946   -0.559524  -0.643932      -0.358156
# 82     -1.295652    -4.299191   -0.900000  -1.086279      -0.715847
# 83     -1.471698    -5.249216   -1.021739  -1.210994      -0.905660
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)  \
# 0                          BOFedSCDepth       -0.055814         0.644860
# 1         BOFedSCDepth(ConstrainedLoss)       -0.074419         0.629283
# 2  BOFedSCDepth(ConstrainedLossRetrain)       -0.009302         0.641745
# 3                 BOFedSCDepth(Retrain)       -0.009302         0.635514
# 4                            FedSCDepth        0.412088         0.206667
# 5                   FedSCDepth(Retrain)        0.406593         0.206667
# 6                               SCDepth       -0.578947         0.651515
#
#    SQ REL (DDAD)  SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  \
# 0       0.030673        0.771613      0.000000       0.588710     0.030499
# 1      -0.024760        0.756452     -0.035398       0.580645     0.001143
# 2       0.088507        0.758065      0.044248       0.596774     0.058537
# 3       0.076312        0.754516      0.044248       0.588710     0.055944
# 4       0.425285        0.757853      0.532751       0.291667     0.173622
# 5       0.436788        0.766087      0.528384       0.277778     0.184227
# 6      -0.660437        0.827555     -0.735294       0.585366    -0.376327
#
#    RMSE (KITTI)  RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0      0.380131        -0.002625          0.484594
# 1      0.371440        -0.041995          0.476190
# 2      0.389089         0.036745          0.484594
# 3      0.384945         0.028871          0.481793
# 4      0.729636         0.505391          0.295455
# 5      0.728169         0.506739          0.291667
# 6      0.511647        -0.574297          0.493188
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)  \
# 0                          BOFedSCDepth        0.392713        -0.624000
# 1         BOFedSCDepth(ConstrainedLoss)        0.384615        -0.792000
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.372470        -0.768000
# 3                 BOFedSCDepth(Retrain)        0.380567        -0.632000
# 4                            FedSCDepth        0.365854        -0.825000
# 5                   FedSCDepth(Retrain)        0.288618        -0.416667
# 6                               SCDepth        0.360360        -1.295652
#
#    SQ REL (DDAD)  SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  \
# 0       0.423827       -1.755470      0.409836      -0.400000     0.256317
# 1       0.454050       -2.252252      0.426230      -0.527273     0.288133
# 2       0.430153       -2.123552      0.401639      -0.509091     0.267883
# 3       0.418380       -1.460746      0.401639      -0.436364     0.253917
# 4       0.414364       -1.938320      0.390244      -0.596154     0.249754
# 5       0.322757       -0.580052      0.308943      -0.326923     0.170466
# 6       0.382201       -4.299191      0.422018      -0.900000     0.285599
#
#    RMSE (KITTI)  RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0     -0.473618         0.346535         -0.363158
# 1     -0.594072         0.368812         -0.447368
# 2     -0.556443         0.349010         -0.426316
# 3     -0.387849         0.339109         -0.342105
# 4     -0.521106         0.342995         -0.440860
# 5     -0.128348         0.268116         -0.215054
# 6     -1.086279         0.346995         -0.715847

# %%
analysis.plot_metrics_differences(['test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#      test_a1   test_a2   test_a3
# 0  -0.090559 -0.073529 -0.037080
# 1   0.004878 -0.003628  0.000000
# 2   0.016313  0.003632  0.003315
# 3  -0.643836 -0.225585 -0.073780
# 4  -0.799587 -0.206767 -0.056867
# 5  -0.788306 -0.198520 -0.052017
# 6  -0.073218 -0.057487 -0.023175
# 7   0.014634  0.002418  0.008830
# 8   0.022838  0.009685  0.012155
# 9  -0.579909 -0.213205 -0.072645
# 10 -0.783058 -0.205514 -0.056867
# 11 -0.774194 -0.199753 -0.053079
# 12 -0.154143 -0.094920 -0.042874
# 13 -0.037398 -0.016929 -0.008830
# 14 -0.027732 -0.009685 -0.005525
# 15 -0.611872 -0.207703 -0.065834
# 16 -0.797521 -0.206767 -0.056867
# 17 -0.788306 -0.200986 -0.053079
# 18 -0.146435 -0.092246 -0.050985
# 19 -0.037398 -0.018138 -0.006623
# 20 -0.027732 -0.012107 -0.003315
# 21 -0.586758 -0.199450 -0.061294
# 22 -0.795455 -0.206767 -0.056867
# 23 -0.786290 -0.200986 -0.053079
# 24 -0.505051 -0.344942 -0.200535
# 25 -0.481651 -0.364668 -0.306152
# 26 -0.492991 -0.384106 -0.327007
# 27 -0.027108  0.002299  0.005308
# 28 -0.094937 -0.054765 -0.030335
# 29 -0.108040 -0.069079 -0.037657
# 30 -0.527778 -0.353234 -0.205882
# 31 -0.458716 -0.371151 -0.309013
# 32 -0.464953 -0.389073 -0.329927
# 33 -0.051205  0.000000  0.005308
# 34 -0.092405 -0.053669 -0.030335
# 35 -0.105528 -0.066886 -0.036611
# 36  0.082443  0.061155  0.038825
# 37  0.256927  0.108460  0.064182
# 38  0.281796  0.122294  0.072389
# 39 -0.620930 -0.251429 -0.090173
# 40 -0.692759 -0.207026 -0.067245
# 41 -0.726916 -0.210461 -0.067888
# 42 -0.274472 -0.138743 -0.075342
# 43 -0.376307 -0.129950 -0.063404
# 44 -0.401408 -0.137157 -0.068156
# 45  0.170404  0.074201  0.032529
# 46  0.132075  0.052138  0.017259
# 47  0.134793  0.053608  0.018163
# 48 -0.261036 -0.143979 -0.081050
# 49 -0.386760 -0.137376 -0.068966
# 50 -0.413732 -0.147132 -0.073743
# 51  0.198804  0.081050  0.036726
# 52  0.168632  0.064651  0.024365
# 53  0.170507  0.067010  0.025227
# 54 -0.243762 -0.133508 -0.077626
# 55 -0.364111 -0.132426 -0.064516
# 56 -0.387324 -0.140898 -0.069274
# 57  0.209268  0.092466  0.045121
# 58  0.165094  0.061522  0.022335
# 59  0.168203  0.062887  0.023209
# 60 -0.247601 -0.129581 -0.077626
# 61 -0.371080 -0.129950 -0.063404
# 62 -0.397887 -0.138404 -0.068156
# 63  0.183857  0.061644  0.024134
# 64  0.148585  0.046924  0.014213
# 65  0.153226  0.048454  0.015136
# 66 -0.157509 -0.124191 -0.078857
# 67 -0.352332 -0.122525 -0.066069
# 68 -0.388401 -0.133750 -0.073281
# 69  0.228404  0.082192  0.027397
# 70  0.178114  0.060354  0.019289
# 71  0.178815  0.060700  0.021169
# 72 -0.095238 -0.072445 -0.046857
# 73 -0.271157 -0.097772 -0.053751
# 74 -0.302285 -0.107500 -0.060879
# 75  0.114202  0.030822  0.006322
# 76  0.101281  0.024974  0.004061
# 77  0.097950  0.023663  0.005040
# 78 -0.086957 -0.048426 -0.042623
# 79 -0.299363 -0.100950 -0.055616
# 80 -0.327391 -0.111377 -0.061336
# 81  0.285124  0.147026  0.066386
# 82  0.231651  0.107996  0.045685
# 83  0.234763  0.113052  0.047427
#                         training_method  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  \
# 0                          BOFedSCDepth   0.004878   -0.799587  -0.003628
# 1         BOFedSCDepth(ConstrainedLoss)   0.014634   -0.783058   0.002418
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.037398   -0.797521  -0.016929
# 3                 BOFedSCDepth(Retrain)  -0.037398   -0.795455  -0.018138
# 4                            FedSCDepth  -0.481651   -0.094937  -0.364668
# 5                   FedSCDepth(Retrain)  -0.458716   -0.092405  -0.371151
# 6                               SCDepth   0.256927   -0.692759   0.108460
#
#    A2 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0   -0.206767   0.000000   -0.056867
# 1   -0.205514   0.008830   -0.056867
# 2   -0.206767  -0.008830   -0.056867
# 3   -0.206767  -0.006623   -0.056867
# 4   -0.054765  -0.306152   -0.030335
# 5   -0.053669  -0.309013   -0.030335
# 6   -0.207026   0.064182   -0.067245
#                         training_method  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  \
# 0                          BOFedSCDepth  -0.376307    0.132075  -0.129950
# 1         BOFedSCDepth(ConstrainedLoss)  -0.386760    0.168632  -0.137376
# 2  BOFedSCDepth(ConstrainedLossRetrain)  -0.364111    0.165094  -0.132426
# 3                 BOFedSCDepth(Retrain)  -0.371080    0.148585  -0.129950
# 4                            FedSCDepth  -0.352332    0.178114  -0.122525
# 5                   FedSCDepth(Retrain)  -0.271157    0.101281  -0.097772
# 6                               SCDepth  -0.299363    0.231651  -0.100950
#
#    A2 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0    0.052138  -0.063404    0.017259
# 1    0.064651  -0.068966    0.024365
# 2    0.061522  -0.064516    0.022335
# 3    0.046924  -0.063404    0.014213
# 4    0.060354  -0.066069    0.019289
# 5    0.024974  -0.053751    0.004061
# 6    0.107996  -0.055616    0.045685

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_rmse', 'test_a1', 'test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset  \
# 0                  DDAD                KITTI
# 1                  DDAD                KITTI
# 2                  DDAD                KITTI
# 3                  DDAD                KITTI
# 4                  DDAD                KITTI
# 5                  DDAD                KITTI
# 6                  DDAD                KITTI
# 7                  DDAD                KITTI
# 8                  DDAD                KITTI
# 9                  DDAD                KITTI
# 10                 DDAD                KITTI
# 11                 DDAD                KITTI
# 12                 DDAD                KITTI
# 13                 DDAD                KITTI
# 14                 DDAD                KITTI
# 15                 DDAD                KITTI
# 16                 DDAD                KITTI
# 17                 DDAD                KITTI
# 18                 DDAD                KITTI
# 19                 DDAD                KITTI
# 20                 DDAD                KITTI
# 21                 DDAD                KITTI
# 22                 DDAD                KITTI
# 23                 DDAD                KITTI
# 24                 DDAD                KITTI
# 25                 DDAD                KITTI
# 26                 DDAD                KITTI
# 27                 DDAD                KITTI
# 28                 DDAD                KITTI
# 29                 DDAD                KITTI
# 30                 DDAD                KITTI
# 31                 DDAD                KITTI
# 32                 DDAD                KITTI
# 33                 DDAD                KITTI
# 34                 DDAD                KITTI
# 35                 DDAD                KITTI
# 36                 DDAD                KITTI
# 37                 DDAD                KITTI
# 38                 DDAD                KITTI
# 39                 DDAD                KITTI
# 40                 DDAD                KITTI
# 41                 DDAD                KITTI
# 42                KITTI                 DDAD
# 43                KITTI                 DDAD
# 44                KITTI                 DDAD
# 45                KITTI                 DDAD
# 46                KITTI                 DDAD
# 47                KITTI                 DDAD
# 48                KITTI                 DDAD
# 49                KITTI                 DDAD
# 50                KITTI                 DDAD
# 51                KITTI                 DDAD
# 52                KITTI                 DDAD
# 53                KITTI                 DDAD
# 54                KITTI                 DDAD
# 55                KITTI                 DDAD
# 56                KITTI                 DDAD
# 57                KITTI                 DDAD
# 58                KITTI                 DDAD
# 59                KITTI                 DDAD
# 60                KITTI                 DDAD
# 61                KITTI                 DDAD
# 62                KITTI                 DDAD
# 63                KITTI                 DDAD
# 64                KITTI                 DDAD
# 65                KITTI                 DDAD
# 66                KITTI                 DDAD
# 67                KITTI                 DDAD
# 68                KITTI                 DDAD
# 69                KITTI                 DDAD
# 70                KITTI                 DDAD
# 71                KITTI                 DDAD
# 72                KITTI                 DDAD
# 73                KITTI                 DDAD
# 74                KITTI                 DDAD
# 75                KITTI                 DDAD
# 76                KITTI                 DDAD
# 77                KITTI                 DDAD
# 78                KITTI                 DDAD
# 79                KITTI                 DDAD
# 80                KITTI                 DDAD
# 81                KITTI                 DDAD
# 82                KITTI                 DDAD
# 83                KITTI                 DDAD
#
#                          training_method test_dataset test_region_type  \
# 0                           BOFedSCDepth         DDAD          dynamic
# 1                           BOFedSCDepth         DDAD             full
# 2                           BOFedSCDepth         DDAD           static
# 3                           BOFedSCDepth        KITTI          dynamic
# 4                           BOFedSCDepth        KITTI             full
# 5                           BOFedSCDepth        KITTI           static
# 6          BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 7          BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 8          BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 9          BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 10         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 11         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 12  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 13  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 14  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 15  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 16  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 17  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 18                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 19                 BOFedSCDepth(Retrain)         DDAD             full
# 20                 BOFedSCDepth(Retrain)         DDAD           static
# 21                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 22                 BOFedSCDepth(Retrain)        KITTI             full
# 23                 BOFedSCDepth(Retrain)        KITTI           static
# 24                            FedSCDepth         DDAD          dynamic
# 25                            FedSCDepth         DDAD             full
# 26                            FedSCDepth         DDAD           static
# 27                            FedSCDepth        KITTI          dynamic
# 28                            FedSCDepth        KITTI             full
# 29                            FedSCDepth        KITTI           static
# 30                   FedSCDepth(Retrain)         DDAD          dynamic
# 31                   FedSCDepth(Retrain)         DDAD             full
# 32                   FedSCDepth(Retrain)         DDAD           static
# 33                   FedSCDepth(Retrain)        KITTI          dynamic
# 34                   FedSCDepth(Retrain)        KITTI             full
# 35                   FedSCDepth(Retrain)        KITTI           static
# 36                               SCDepth         DDAD          dynamic
# 37                               SCDepth         DDAD             full
# 38                               SCDepth         DDAD           static
# 39                               SCDepth        KITTI          dynamic
# 40                               SCDepth        KITTI             full
# 41                               SCDepth        KITTI           static
# 42                          BOFedSCDepth         DDAD          dynamic
# 43                          BOFedSCDepth         DDAD             full
# 44                          BOFedSCDepth         DDAD           static
# 45                          BOFedSCDepth        KITTI          dynamic
# 46                          BOFedSCDepth        KITTI             full
# 47                          BOFedSCDepth        KITTI           static
# 48         BOFedSCDepth(ConstrainedLoss)         DDAD          dynamic
# 49         BOFedSCDepth(ConstrainedLoss)         DDAD             full
# 50         BOFedSCDepth(ConstrainedLoss)         DDAD           static
# 51         BOFedSCDepth(ConstrainedLoss)        KITTI          dynamic
# 52         BOFedSCDepth(ConstrainedLoss)        KITTI             full
# 53         BOFedSCDepth(ConstrainedLoss)        KITTI           static
# 54  BOFedSCDepth(ConstrainedLossRetrain)         DDAD          dynamic
# 55  BOFedSCDepth(ConstrainedLossRetrain)         DDAD             full
# 56  BOFedSCDepth(ConstrainedLossRetrain)         DDAD           static
# 57  BOFedSCDepth(ConstrainedLossRetrain)        KITTI          dynamic
# 58  BOFedSCDepth(ConstrainedLossRetrain)        KITTI             full
# 59  BOFedSCDepth(ConstrainedLossRetrain)        KITTI           static
# 60                 BOFedSCDepth(Retrain)         DDAD          dynamic
# 61                 BOFedSCDepth(Retrain)         DDAD             full
# 62                 BOFedSCDepth(Retrain)         DDAD           static
# 63                 BOFedSCDepth(Retrain)        KITTI          dynamic
# 64                 BOFedSCDepth(Retrain)        KITTI             full
# 65                 BOFedSCDepth(Retrain)        KITTI           static
# 66                            FedSCDepth         DDAD          dynamic
# 67                            FedSCDepth         DDAD             full
# 68                            FedSCDepth         DDAD           static
# 69                            FedSCDepth        KITTI          dynamic
# 70                            FedSCDepth        KITTI             full
# 71                            FedSCDepth        KITTI           static
# 72                   FedSCDepth(Retrain)         DDAD          dynamic
# 73                   FedSCDepth(Retrain)         DDAD             full
# 74                   FedSCDepth(Retrain)         DDAD           static
# 75                   FedSCDepth(Retrain)        KITTI          dynamic
# 76                   FedSCDepth(Retrain)        KITTI             full
# 77                   FedSCDepth(Retrain)        KITTI           static
# 78                               SCDepth         DDAD          dynamic
# 79                               SCDepth         DDAD             full
# 80                               SCDepth         DDAD           static
# 81                               SCDepth        KITTI          dynamic
# 82                               SCDepth        KITTI             full
# 83                               SCDepth        KITTI           static
#
#     test_abs_rel  test_rmse   test_a1   test_a3
# 0       0.121324   0.068081 -0.090559 -0.037080
# 1      -0.055814   0.030499  0.004878  0.000000
# 2      -0.089202   0.027323  0.016313  0.003315
# 3       0.505051   0.267283 -0.643836 -0.073780
# 4       0.644860   0.380131 -0.799587 -0.056867
# 5       0.656863   0.396780 -0.788306 -0.052017
# 6       0.084559   0.036222 -0.073218 -0.023175
# 7      -0.074419   0.001143  0.014634  0.008830
# 8      -0.103286  -0.001911  0.022838  0.012155
# 9       0.477273   0.245628 -0.579909 -0.072645
# 10      0.629283   0.371440 -0.783058 -0.056867
# 11      0.643791   0.390586 -0.774194 -0.053079
# 12      0.132353   0.103779 -0.154143 -0.042874
# 13     -0.009302   0.058537 -0.037398 -0.008830
# 14     -0.032864   0.054863 -0.027732 -0.005525
# 15      0.469697   0.232818 -0.611872 -0.065834
# 16      0.641745   0.389089 -0.797521 -0.056867
# 17      0.656863   0.416047 -0.788306 -0.053079
# 18      0.136029   0.106441 -0.146435 -0.050985
# 19     -0.009302   0.055944 -0.037398 -0.006623
# 20     -0.032864   0.053125 -0.027732 -0.003315
# 21      0.446970   0.209435 -0.586758 -0.061294
# 22      0.635514   0.384945 -0.795455 -0.056867
# 23      0.650327   0.412607 -0.786290 -0.053079
# 24      0.327635   0.234542 -0.505051 -0.200535
# 25      0.412088   0.173622 -0.481651 -0.306152
# 26      0.431937   0.175246 -0.492991 -0.327007
# 27     -0.066986   0.548234 -0.027108  0.005308
# 28      0.206667   0.729636 -0.094937 -0.030335
# 29      0.258503   0.751604 -0.108040 -0.037657
# 30      0.339031   0.243123 -0.527778 -0.205882
# 31      0.406593   0.184227 -0.458716 -0.309013
# 32      0.424084   0.185563 -0.464953 -0.329927
# 33     -0.019139   0.556442 -0.051205  0.005308
# 34      0.206667   0.728169 -0.092405 -0.030335
# 35      0.258503   0.747521 -0.105528 -0.036611
# 36     -0.054299  -0.213140  0.082443  0.038825
# 37     -0.578947  -0.376327  0.256927  0.064182
# 38     -0.668919  -0.398378  0.281796  0.072389
# 39      0.512821   0.383156 -0.620930 -0.090173
# 40      0.651515   0.511647 -0.692759 -0.067245
# 41      0.671779   0.535249 -0.726916 -0.067888
# 42      0.214286   0.229972 -0.274472 -0.075342
# 43      0.392713   0.256317 -0.376307 -0.063404
# 44      0.414343   0.262488 -0.401408 -0.068156
# 45     -0.397260  -0.314939  0.170404  0.032529
# 46     -0.624000  -0.473618  0.132075  0.017259
# 47     -0.719298  -0.516622  0.134793  0.018163
# 48      0.180451   0.245950 -0.261036 -0.081050
# 49      0.384615   0.288133 -0.386760 -0.068966
# 50      0.410359   0.294497 -0.413732 -0.073743
# 51     -0.465753  -0.344684  0.198804  0.036726
# 52     -0.792000  -0.594072  0.168632  0.024365
# 53     -0.903509  -0.652482  0.170507  0.025227
# 54      0.157895   0.230061 -0.243762 -0.077626
# 55      0.372470   0.267883 -0.364111 -0.064516
# 56      0.394422   0.273545 -0.387324 -0.069274
# 57     -0.525114  -0.374428  0.209268  0.045121
# 58     -0.768000  -0.556443  0.165094  0.022335
# 59     -0.868421  -0.602394  0.168203  0.023209
# 60      0.184211   0.223028 -0.247601 -0.077626
# 61      0.380567   0.253917 -0.371080 -0.063404
# 62      0.406375   0.259605 -0.397887 -0.068156
# 63     -0.378995  -0.250606  0.183857  0.024134
# 64     -0.632000  -0.387849  0.148585  0.014213
# 65     -0.728070  -0.422207  0.153226  0.015136
# 66      0.128906   0.217087 -0.157509 -0.078857
# 67      0.365854   0.249754 -0.352332 -0.066069
# 68      0.394422   0.257116 -0.388401 -0.073281
# 69     -0.504673  -0.309987  0.228404  0.027397
# 70     -0.825000  -0.521106  0.178114  0.019289
# 71     -0.944954  -0.585199  0.178815  0.021169
# 72      0.082031   0.124379 -0.095238 -0.046857
# 73      0.288618   0.170466 -0.271157 -0.053751
# 74      0.318725   0.176099 -0.302285 -0.060879
# 75     -0.224299  -0.060324  0.114202  0.006322
# 76     -0.416667  -0.128348  0.101281  0.004061
# 77     -0.458716  -0.150297  0.097950  0.005040
# 78      0.044053   0.149183 -0.086957 -0.042623
# 79      0.360360   0.285599 -0.299363 -0.055616
# 80      0.384956   0.295770 -0.327391 -0.061336
# 81     -0.879581  -0.643932  0.285124  0.066386
# 82     -1.295652  -1.086279  0.231651  0.045685
# 83     -1.471698  -1.210994  0.234763  0.047427
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)  \
# 0                          BOFedSCDepth       -0.055814         0.644860
# 1         BOFedSCDepth(ConstrainedLoss)       -0.074419         0.629283
# 2  BOFedSCDepth(ConstrainedLossRetrain)       -0.009302         0.641745
# 3                 BOFedSCDepth(Retrain)       -0.009302         0.635514
# 4                            FedSCDepth        0.412088         0.206667
# 5                   FedSCDepth(Retrain)        0.406593         0.206667
# 6                               SCDepth       -0.578947         0.651515
#
#    RMSE (DDAD)  RMSE (KITTI)  A1 (DDAD)  A1 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0     0.030499      0.380131   0.004878   -0.799587   0.000000   -0.056867
# 1     0.001143      0.371440   0.014634   -0.783058   0.008830   -0.056867
# 2     0.058537      0.389089  -0.037398   -0.797521  -0.008830   -0.056867
# 3     0.055944      0.384945  -0.037398   -0.795455  -0.006623   -0.056867
# 4     0.173622      0.729636  -0.481651   -0.094937  -0.306152   -0.030335
# 5     0.184227      0.728169  -0.458716   -0.092405  -0.309013   -0.030335
# 6    -0.376327      0.511647   0.256927   -0.692759   0.064182   -0.067245
#                         training_method  ABS REL (DDAD)  ABS REL (KITTI)  \
# 0                          BOFedSCDepth        0.392713        -0.624000
# 1         BOFedSCDepth(ConstrainedLoss)        0.384615        -0.792000
# 2  BOFedSCDepth(ConstrainedLossRetrain)        0.372470        -0.768000
# 3                 BOFedSCDepth(Retrain)        0.380567        -0.632000
# 4                            FedSCDepth        0.365854        -0.825000
# 5                   FedSCDepth(Retrain)        0.288618        -0.416667
# 6                               SCDepth        0.360360        -1.295652
#
#    RMSE (DDAD)  RMSE (KITTI)  A1 (DDAD)  A1 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0     0.256317     -0.473618  -0.376307    0.132075  -0.063404    0.017259
# 1     0.288133     -0.594072  -0.386760    0.168632  -0.068966    0.024365
# 2     0.267883     -0.556443  -0.364111    0.165094  -0.064516    0.022335
# 3     0.253917     -0.387849  -0.371080    0.148585  -0.063404    0.014213
# 4     0.249754     -0.521106  -0.352332    0.178114  -0.066069    0.019289
# 5     0.170466     -0.128348  -0.271157    0.101281  -0.053751    0.004061
# 6     0.285599     -1.086279  -0.299363    0.231651  -0.055616    0.045685
