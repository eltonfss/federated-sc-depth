# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
from comparative_analysis import ComparativeAnalysis
analysis = ComparativeAnalysis("continuallearningexperiments.csv")

# %%
analysis.plot_metrics_differences(['test_abs_rel'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_sq_rel'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_log10'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_rmse'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_rmse_log'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_a1'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_a2'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log', 'test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_rmse', 'test_a1', 'test_a3'], 'full')
# Out:
#     source_train_dataset target_train_dataset  \
# 0                   DDAD                KITTI
# 1                   DDAD                KITTI
# 2                   DDAD                KITTI
# 3                   DDAD                KITTI
# 4                   DDAD                KITTI
# 5                   DDAD                KITTI
# 6                   DDAD                KITTI
# 7                   DDAD                KITTI
# 8                   DDAD                KITTI
# 9                   DDAD                KITTI
# 10                  DDAD                KITTI
# 11                  DDAD                KITTI
# 12                  DDAD                KITTI
# 13                  DDAD                KITTI
# 14                  DDAD                KITTI
# 15                  DDAD                KITTI
# 16                  DDAD                KITTI
# 17                  DDAD                KITTI
# 18                  DDAD                KITTI
# ...
