# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
from comparative_analysis import ComparativeAnalysis
analysis = ComparativeAnalysis("domainadaptationexperiments.csv")
df = analysis.result_df
df = pd.concat([df[df['training_method'] == 'FedSCDepth(Retrain)'], df[df['training_method'] == 'FedSCDepth']])
analysis.result_df = df

# %%
analysis.plot_metrics_differences(['test_abs_rel'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_abs_rel
# 0          DDAD          dynamic      0.327635
# 1          DDAD             full      0.412088
# 2          DDAD           static      0.431937
# 3         KITTI          dynamic     -0.066986
# 4         KITTI             full      0.206667
# 5         KITTI           static      0.258503
# 6          DDAD          dynamic      0.339031
# 7          DDAD             full      0.406593
# 8          DDAD           static      0.424084
# 9         KITTI          dynamic     -0.019139
# 10        KITTI             full      0.206667
# 11        KITTI           static      0.258503
# 12         DDAD          dynamic      0.128906
# 13         DDAD             full      0.365854
# 14         DDAD           static      0.394422
# 15        KITTI          dynamic     -0.504673
# 16        KITTI             full     -0.825000
# 17        KITTI           static     -0.944954
# 18         DDAD          dynamic      0.082031
# 19         DDAD             full      0.288618
# 20         DDAD           static      0.318725
# 21        KITTI          dynamic     -0.224299
# 22        KITTI             full     -0.416667
# 23        KITTI           static     -0.458716
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0           FedSCDepth        0.412088         0.206667
# 1  FedSCDepth(Retrain)        0.406593         0.206667
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)
# 0           FedSCDepth        0.365854        -0.825000
# 1  FedSCDepth(Retrain)        0.288618        -0.416667

# %%
analysis.plot_metrics_differences(['test_sq_rel'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_sq_rel
# 0          DDAD          dynamic     0.458308
# 1          DDAD             full     0.425285
# 2          DDAD           static     0.469137
# 3         KITTI          dynamic     0.378168
# 4         KITTI             full     0.757853
# 5         KITTI           static     0.803131
# 6          DDAD          dynamic     0.473980
# 7          DDAD             full     0.436788
# 8          DDAD           static     0.478862
# 9         KITTI          dynamic     0.411739
# 10        KITTI             full     0.766087
# 11        KITTI           static     0.805840
# 12         DDAD          dynamic     0.346242
# 13         DDAD             full     0.414364
# 14         DDAD           static     0.430890
# 15        KITTI          dynamic    -0.950042
# 16        KITTI             full    -1.938320
# 17        KITTI           static    -2.454976
# 18         DDAD          dynamic     0.223317
# 19         DDAD             full     0.322757
# 20         DDAD           static     0.336449
# 21        KITTI          dynamic    -0.240974
# 22        KITTI             full    -0.580052
# 23        KITTI           static    -0.748815
#        training_method  SQ REL (DDAD)  SQ REL (KITTI)
# 0           FedSCDepth       0.425285        0.757853
# 1  FedSCDepth(Retrain)       0.436788        0.766087
#        training_method  SQ REL (DDAD)  SQ REL (KITTI)
# 0           FedSCDepth       0.414364       -1.938320
# 1  FedSCDepth(Retrain)       0.322757       -0.580052

# %%
analysis.plot_metrics_differences(['test_log10'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_log10
# 0          DDAD          dynamic    0.404040
# 1          DDAD             full    0.532751
# 2          DDAD           static    0.538136
# 3         KITTI          dynamic    0.041667
# 4         KITTI             full    0.291667
# 5         KITTI           static    0.352113
# 6          DDAD          dynamic    0.414141
# 7          DDAD             full    0.528384
# 8          DDAD           static    0.533898
# 9         KITTI          dynamic    0.062500
# 10        KITTI             full    0.277778
# 11        KITTI           static    0.338028
# 12         DDAD          dynamic    0.236641
# 13         DDAD             full    0.390244
# 14         DDAD           static    0.420635
# 15        KITTI          dynamic   -0.322222
# 16        KITTI             full   -0.596154
# 17        KITTI           static   -0.702128
# 18         DDAD          dynamic    0.145038
# 19         DDAD             full    0.308943
# 20         DDAD           static    0.333333
# 21        KITTI          dynamic   -0.155556
# 22        KITTI             full   -0.326923
# 23        KITTI           static   -0.361702
#        training_method  LOG10 (DDAD)  LOG10 (KITTI)
# 0           FedSCDepth      0.532751       0.291667
# 1  FedSCDepth(Retrain)      0.528384       0.277778
#        training_method  LOG10 (DDAD)  LOG10 (KITTI)
# 0           FedSCDepth      0.390244      -0.596154
# 1  FedSCDepth(Retrain)      0.308943      -0.326923

# %%
analysis.plot_metrics_differences(['test_rmse'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_rmse
# 0          DDAD          dynamic   0.234542
# 1          DDAD             full   0.173622
# 2          DDAD           static   0.175246
# 3         KITTI          dynamic   0.548234
# 4         KITTI             full   0.729636
# 5         KITTI           static   0.751604
# 6          DDAD          dynamic   0.243123
# 7          DDAD             full   0.184227
# 8          DDAD           static   0.185563
# 9         KITTI          dynamic   0.556442
# 10        KITTI             full   0.728169
# 11        KITTI           static   0.747521
# 12         DDAD          dynamic   0.217087
# 13         DDAD             full   0.249754
# 14         DDAD           static   0.257116
# 15        KITTI          dynamic  -0.309987
# 16        KITTI             full  -0.521106
# 17        KITTI           static  -0.585199
# 18         DDAD          dynamic   0.124379
# 19         DDAD             full   0.170466
# 20         DDAD           static   0.176099
# 21        KITTI          dynamic  -0.060324
# 22        KITTI             full  -0.128348
# 23        KITTI           static  -0.150297
#        training_method  RMSE (DDAD)  RMSE (KITTI)
# 0           FedSCDepth     0.173622      0.729636
# 1  FedSCDepth(Retrain)     0.184227      0.728169
#        training_method  RMSE (DDAD)  RMSE (KITTI)
# 0           FedSCDepth     0.249754     -0.521106
# 1  FedSCDepth(Retrain)     0.170466     -0.128348

# %%
analysis.plot_metrics_differences(['test_rmse_log'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_rmse_log
# 0          DDAD          dynamic       0.347197
# 1          DDAD             full       0.505391
# 2          DDAD           static       0.509908
# 3         KITTI          dynamic       0.013201
# 4         KITTI             full       0.295455
# 5         KITTI           static       0.386100
# 6          DDAD          dynamic       0.354430
# 7          DDAD             full       0.506739
# 8          DDAD           static       0.511229
# 9         KITTI          dynamic       0.026403
# 10        KITTI             full       0.291667
# 11        KITTI           static       0.378378
# 12         DDAD          dynamic       0.220253
# 13         DDAD             full       0.342995
# 14         DDAD           static       0.362768
# 15        KITTI          dynamic      -0.193772
# 16        KITTI             full      -0.440860
# 17        KITTI           static      -0.571429
# 18         DDAD          dynamic       0.144304
# 19         DDAD             full       0.268116
# 20         DDAD           static       0.286396
# 21        KITTI          dynamic      -0.069204
# 22        KITTI             full      -0.215054
# 23        KITTI           static      -0.279503
#        training_method  RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0           FedSCDepth         0.505391          0.295455
# 1  FedSCDepth(Retrain)         0.506739          0.291667
#        training_method  RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0           FedSCDepth         0.342995         -0.440860
# 1  FedSCDepth(Retrain)         0.268116         -0.215054

# %%
analysis.plot_metrics_differences(['test_a1'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type   test_a1
# 0          DDAD          dynamic -0.505051
# 1          DDAD             full -0.481651
# 2          DDAD           static -0.492991
# 3         KITTI          dynamic -0.027108
# 4         KITTI             full -0.094937
# 5         KITTI           static -0.108040
# 6          DDAD          dynamic -0.527778
# 7          DDAD             full -0.458716
# 8          DDAD           static -0.464953
# 9         KITTI          dynamic -0.051205
# 10        KITTI             full -0.092405
# 11        KITTI           static -0.105528
# 12         DDAD          dynamic -0.157509
# 13         DDAD             full -0.352332
# 14         DDAD           static -0.388401
# 15        KITTI          dynamic  0.228404
# 16        KITTI             full  0.178114
# 17        KITTI           static  0.178815
# 18         DDAD          dynamic -0.095238
# 19         DDAD             full -0.271157
# 20         DDAD           static -0.302285
# 21        KITTI          dynamic  0.114202
# 22        KITTI             full  0.101281
# 23        KITTI           static  0.097950
#        training_method  A1 (DDAD)  A1 (KITTI)
# 0           FedSCDepth  -0.481651   -0.094937
# 1  FedSCDepth(Retrain)  -0.458716   -0.092405
#        training_method  A1 (DDAD)  A1 (KITTI)
# 0           FedSCDepth  -0.352332    0.178114
# 1  FedSCDepth(Retrain)  -0.271157    0.101281

# %%
analysis.plot_metrics_differences(['test_a2'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type   test_a2
# 0          DDAD          dynamic -0.344942
# 1          DDAD             full -0.364668
# 2          DDAD           static -0.384106
# 3         KITTI          dynamic  0.002299
# 4         KITTI             full -0.054765
# 5         KITTI           static -0.069079
# 6          DDAD          dynamic -0.353234
# 7          DDAD             full -0.371151
# 8          DDAD           static -0.389073
# 9         KITTI          dynamic  0.000000
# 10        KITTI             full -0.053669
# 11        KITTI           static -0.066886
# 12         DDAD          dynamic -0.124191
# 13         DDAD             full -0.122525
# 14         DDAD           static -0.133750
# 15        KITTI          dynamic  0.082192
# 16        KITTI             full  0.060354
# 17        KITTI           static  0.060700
# 18         DDAD          dynamic -0.072445
# 19         DDAD             full -0.097772
# 20         DDAD           static -0.107500
# 21        KITTI          dynamic  0.030822
# 22        KITTI             full  0.024974
# 23        KITTI           static  0.023663
#        training_method  A2 (DDAD)  A2 (KITTI)
# 0           FedSCDepth  -0.364668   -0.054765
# 1  FedSCDepth(Retrain)  -0.371151   -0.053669
#        training_method  A2 (DDAD)  A2 (KITTI)
# 0           FedSCDepth  -0.122525    0.060354
# 1  FedSCDepth(Retrain)  -0.097772    0.024974

# %%
analysis.plot_metrics_differences(['test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type   test_a3
# 0          DDAD          dynamic -0.200535
# 1          DDAD             full -0.306152
# 2          DDAD           static -0.327007
# 3         KITTI          dynamic  0.005308
# 4         KITTI             full -0.030335
# 5         KITTI           static -0.037657
# 6          DDAD          dynamic -0.205882
# 7          DDAD             full -0.309013
# 8          DDAD           static -0.329927
# 9         KITTI          dynamic  0.005308
# 10        KITTI             full -0.030335
# 11        KITTI           static -0.036611
# 12         DDAD          dynamic -0.078857
# 13         DDAD             full -0.066069
# 14         DDAD           static -0.073281
# 15        KITTI          dynamic  0.027397
# 16        KITTI             full  0.019289
# 17        KITTI           static  0.021169
# 18         DDAD          dynamic -0.046857
# 19         DDAD             full -0.053751
# 20         DDAD           static -0.060879
# 21        KITTI          dynamic  0.006322
# 22        KITTI             full  0.004061
# 23        KITTI           static  0.005040
#        training_method  A3 (DDAD)  A3 (KITTI)
# 0           FedSCDepth  -0.306152   -0.030335
# 1  FedSCDepth(Retrain)  -0.309013   -0.030335
#        training_method  A3 (DDAD)  A3 (KITTI)
# 0           FedSCDepth  -0.066069    0.019289
# 1  FedSCDepth(Retrain)  -0.053751    0.004061

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log', 'test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_abs_rel  test_sq_rel  test_log10  \
# 0          DDAD          dynamic      0.327635     0.458308    0.404040
# 1          DDAD             full      0.412088     0.425285    0.532751
# 2          DDAD           static      0.431937     0.469137    0.538136
# 3         KITTI          dynamic     -0.066986     0.378168    0.041667
# 4         KITTI             full      0.206667     0.757853    0.291667
# 5         KITTI           static      0.258503     0.803131    0.352113
# 6          DDAD          dynamic      0.339031     0.473980    0.414141
# 7          DDAD             full      0.406593     0.436788    0.528384
# 8          DDAD           static      0.424084     0.478862    0.533898
# 9         KITTI          dynamic     -0.019139     0.411739    0.062500
# 10        KITTI             full      0.206667     0.766087    0.277778
# 11        KITTI           static      0.258503     0.805840    0.338028
# 12         DDAD          dynamic      0.128906     0.346242    0.236641
# 13         DDAD             full      0.365854     0.414364    0.390244
# 14         DDAD           static      0.394422     0.430890    0.420635
# 15        KITTI          dynamic     -0.504673    -0.950042   -0.322222
# 16        KITTI             full     -0.825000    -1.938320   -0.596154
# 17        KITTI           static     -0.944954    -2.454976   -0.702128
# 18         DDAD          dynamic      0.082031     0.223317    0.145038
# 19         DDAD             full      0.288618     0.322757    0.308943
# 20         DDAD           static      0.318725     0.336449    0.333333
# 21        KITTI          dynamic     -0.224299    -0.240974   -0.155556
# 22        KITTI             full     -0.416667    -0.580052   -0.326923
# 23        KITTI           static     -0.458716    -0.748815   -0.361702
#
#     test_rmse  test_rmse_log   test_a1   test_a2   test_a3
# 0    0.234542       0.347197 -0.505051 -0.344942 -0.200535
# 1    0.173622       0.505391 -0.481651 -0.364668 -0.306152
# 2    0.175246       0.509908 -0.492991 -0.384106 -0.327007
# 3    0.548234       0.013201 -0.027108  0.002299  0.005308
# 4    0.729636       0.295455 -0.094937 -0.054765 -0.030335
# 5    0.751604       0.386100 -0.108040 -0.069079 -0.037657
# 6    0.243123       0.354430 -0.527778 -0.353234 -0.205882
# 7    0.184227       0.506739 -0.458716 -0.371151 -0.309013
# 8    0.185563       0.511229 -0.464953 -0.389073 -0.329927
# 9    0.556442       0.026403 -0.051205  0.000000  0.005308
# 10   0.728169       0.291667 -0.092405 -0.053669 -0.030335
# 11   0.747521       0.378378 -0.105528 -0.066886 -0.036611
# 12   0.217087       0.220253 -0.157509 -0.124191 -0.078857
# 13   0.249754       0.342995 -0.352332 -0.122525 -0.066069
# 14   0.257116       0.362768 -0.388401 -0.133750 -0.073281
# 15  -0.309987      -0.193772  0.228404  0.082192  0.027397
# 16  -0.521106      -0.440860  0.178114  0.060354  0.019289
# 17  -0.585199      -0.571429  0.178815  0.060700  0.021169
# 18   0.124379       0.144304 -0.095238 -0.072445 -0.046857
# 19   0.170466       0.268116 -0.271157 -0.097772 -0.053751
# 20   0.176099       0.286396 -0.302285 -0.107500 -0.060879
# 21  -0.060324      -0.069204  0.114202  0.030822  0.006322
# 22  -0.128348      -0.215054  0.101281  0.024974  0.004061
# 23  -0.150297      -0.279503  0.097950  0.023663  0.005040
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  SQ REL (DDAD)  \
# 0           FedSCDepth        0.412088         0.206667       0.425285
# 1  FedSCDepth(Retrain)        0.406593         0.206667       0.436788
#
#    SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  RMSE (KITTI)  \
# 0        0.757853      0.532751       0.291667     0.173622      0.729636
# 1        0.766087      0.528384       0.277778     0.184227      0.728169
#
#    RMSE LOG (DDAD)  RMSE LOG (KITTI)  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  \
# 0         0.505391          0.295455  -0.481651   -0.094937  -0.364668
# 1         0.506739          0.291667  -0.458716   -0.092405  -0.371151
#
#    A2 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0   -0.054765  -0.306152   -0.030335
# 1   -0.053669  -0.309013   -0.030335
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  SQ REL (DDAD)  \
# 0           FedSCDepth        0.365854        -0.825000       0.414364
# 1  FedSCDepth(Retrain)        0.288618        -0.416667       0.322757
#
#    SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  RMSE (KITTI)  \
# 0       -1.938320      0.390244      -0.596154     0.249754     -0.521106
# 1       -0.580052      0.308943      -0.326923     0.170466     -0.128348
#
#    RMSE LOG (DDAD)  RMSE LOG (KITTI)  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  \
# 0         0.342995         -0.440860  -0.352332    0.178114  -0.122525
# 1         0.268116         -0.215054  -0.271157    0.101281  -0.097772
#
#    A2 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0    0.060354  -0.066069    0.019289
# 1    0.024974  -0.053751    0.004061

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_log10', 'test_rmse', 'test_rmse_log'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_abs_rel  test_sq_rel  test_log10  \
# 0          DDAD          dynamic      0.327635     0.458308    0.404040
# 1          DDAD             full      0.412088     0.425285    0.532751
# 2          DDAD           static      0.431937     0.469137    0.538136
# 3         KITTI          dynamic     -0.066986     0.378168    0.041667
# 4         KITTI             full      0.206667     0.757853    0.291667
# 5         KITTI           static      0.258503     0.803131    0.352113
# 6          DDAD          dynamic      0.339031     0.473980    0.414141
# 7          DDAD             full      0.406593     0.436788    0.528384
# 8          DDAD           static      0.424084     0.478862    0.533898
# 9         KITTI          dynamic     -0.019139     0.411739    0.062500
# 10        KITTI             full      0.206667     0.766087    0.277778
# 11        KITTI           static      0.258503     0.805840    0.338028
# 12         DDAD          dynamic      0.128906     0.346242    0.236641
# 13         DDAD             full      0.365854     0.414364    0.390244
# 14         DDAD           static      0.394422     0.430890    0.420635
# 15        KITTI          dynamic     -0.504673    -0.950042   -0.322222
# 16        KITTI             full     -0.825000    -1.938320   -0.596154
# 17        KITTI           static     -0.944954    -2.454976   -0.702128
# 18         DDAD          dynamic      0.082031     0.223317    0.145038
# 19         DDAD             full      0.288618     0.322757    0.308943
# 20         DDAD           static      0.318725     0.336449    0.333333
# 21        KITTI          dynamic     -0.224299    -0.240974   -0.155556
# 22        KITTI             full     -0.416667    -0.580052   -0.326923
# 23        KITTI           static     -0.458716    -0.748815   -0.361702
#
#     test_rmse  test_rmse_log
# 0    0.234542       0.347197
# 1    0.173622       0.505391
# 2    0.175246       0.509908
# 3    0.548234       0.013201
# 4    0.729636       0.295455
# 5    0.751604       0.386100
# 6    0.243123       0.354430
# 7    0.184227       0.506739
# 8    0.185563       0.511229
# 9    0.556442       0.026403
# 10   0.728169       0.291667
# 11   0.747521       0.378378
# 12   0.217087       0.220253
# 13   0.249754       0.342995
# 14   0.257116       0.362768
# 15  -0.309987      -0.193772
# 16  -0.521106      -0.440860
# 17  -0.585199      -0.571429
# 18   0.124379       0.144304
# 19   0.170466       0.268116
# 20   0.176099       0.286396
# 21  -0.060324      -0.069204
# 22  -0.128348      -0.215054
# 23  -0.150297      -0.279503
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  SQ REL (DDAD)  \
# 0           FedSCDepth        0.412088         0.206667       0.425285
# 1  FedSCDepth(Retrain)        0.406593         0.206667       0.436788
#
#    SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  RMSE (KITTI)  \
# 0        0.757853      0.532751       0.291667     0.173622      0.729636
# 1        0.766087      0.528384       0.277778     0.184227      0.728169
#
#    RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0         0.505391          0.295455
# 1         0.506739          0.291667
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  SQ REL (DDAD)  \
# 0           FedSCDepth        0.365854        -0.825000       0.414364
# 1  FedSCDepth(Retrain)        0.288618        -0.416667       0.322757
#
#    SQ REL (KITTI)  LOG10 (DDAD)  LOG10 (KITTI)  RMSE (DDAD)  RMSE (KITTI)  \
# 0       -1.938320      0.390244      -0.596154     0.249754     -0.521106
# 1       -0.580052      0.308943      -0.326923     0.170466     -0.128348
#
#    RMSE LOG (DDAD)  RMSE LOG (KITTI)
# 0         0.342995         -0.440860
# 1         0.268116         -0.215054

# %%
analysis.plot_metrics_differences(['test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type   test_a1   test_a2   test_a3
# 0          DDAD          dynamic -0.505051 -0.344942 -0.200535
# 1          DDAD             full -0.481651 -0.364668 -0.306152
# 2          DDAD           static -0.492991 -0.384106 -0.327007
# 3         KITTI          dynamic -0.027108  0.002299  0.005308
# 4         KITTI             full -0.094937 -0.054765 -0.030335
# 5         KITTI           static -0.108040 -0.069079 -0.037657
# 6          DDAD          dynamic -0.527778 -0.353234 -0.205882
# 7          DDAD             full -0.458716 -0.371151 -0.309013
# 8          DDAD           static -0.464953 -0.389073 -0.329927
# 9         KITTI          dynamic -0.051205  0.000000  0.005308
# 10        KITTI             full -0.092405 -0.053669 -0.030335
# 11        KITTI           static -0.105528 -0.066886 -0.036611
# 12         DDAD          dynamic -0.157509 -0.124191 -0.078857
# 13         DDAD             full -0.352332 -0.122525 -0.066069
# 14         DDAD           static -0.388401 -0.133750 -0.073281
# 15        KITTI          dynamic  0.228404  0.082192  0.027397
# 16        KITTI             full  0.178114  0.060354  0.019289
# 17        KITTI           static  0.178815  0.060700  0.021169
# 18         DDAD          dynamic -0.095238 -0.072445 -0.046857
# 19         DDAD             full -0.271157 -0.097772 -0.053751
# 20         DDAD           static -0.302285 -0.107500 -0.060879
# 21        KITTI          dynamic  0.114202  0.030822  0.006322
# 22        KITTI             full  0.101281  0.024974  0.004061
# 23        KITTI           static  0.097950  0.023663  0.005040
#        training_method  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  A2 (KITTI)  \
# 0           FedSCDepth  -0.481651   -0.094937  -0.364668   -0.054765
# 1  FedSCDepth(Retrain)  -0.458716   -0.092405  -0.371151   -0.053669
#
#    A3 (DDAD)  A3 (KITTI)
# 0  -0.306152   -0.030335
# 1  -0.309013   -0.030335
#        training_method  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  A2 (KITTI)  \
# 0           FedSCDepth  -0.352332    0.178114  -0.122525    0.060354
# 1  FedSCDepth(Retrain)  -0.271157    0.101281  -0.097772    0.024974
#
#    A3 (DDAD)  A3 (KITTI)
# 0  -0.066069    0.019289
# 1  -0.053751    0.004061

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_rmse', 'test_a1', 'test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_abs_rel  test_rmse   test_a1   test_a3
# 0          DDAD          dynamic      0.327635   0.234542 -0.505051 -0.200535
# 1          DDAD             full      0.412088   0.173622 -0.481651 -0.306152
# 2          DDAD           static      0.431937   0.175246 -0.492991 -0.327007
# 3         KITTI          dynamic     -0.066986   0.548234 -0.027108  0.005308
# 4         KITTI             full      0.206667   0.729636 -0.094937 -0.030335
# 5         KITTI           static      0.258503   0.751604 -0.108040 -0.037657
# 6          DDAD          dynamic      0.339031   0.243123 -0.527778 -0.205882
# 7          DDAD             full      0.406593   0.184227 -0.458716 -0.309013
# 8          DDAD           static      0.424084   0.185563 -0.464953 -0.329927
# 9         KITTI          dynamic     -0.019139   0.556442 -0.051205  0.005308
# 10        KITTI             full      0.206667   0.728169 -0.092405 -0.030335
# 11        KITTI           static      0.258503   0.747521 -0.105528 -0.036611
# 12         DDAD          dynamic      0.128906   0.217087 -0.157509 -0.078857
# 13         DDAD             full      0.365854   0.249754 -0.352332 -0.066069
# 14         DDAD           static      0.394422   0.257116 -0.388401 -0.073281
# 15        KITTI          dynamic     -0.504673  -0.309987  0.228404  0.027397
# 16        KITTI             full     -0.825000  -0.521106  0.178114  0.019289
# 17        KITTI           static     -0.944954  -0.585199  0.178815  0.021169
# 18         DDAD          dynamic      0.082031   0.124379 -0.095238 -0.046857
# 19         DDAD             full      0.288618   0.170466 -0.271157 -0.053751
# 20         DDAD           static      0.318725   0.176099 -0.302285 -0.060879
# 21        KITTI          dynamic     -0.224299  -0.060324  0.114202  0.006322
# 22        KITTI             full     -0.416667  -0.128348  0.101281  0.004061
# 23        KITTI           static     -0.458716  -0.150297  0.097950  0.005040
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  RMSE (DDAD)  \
# 0           FedSCDepth        0.412088         0.206667     0.173622
# 1  FedSCDepth(Retrain)        0.406593         0.206667     0.184227
#
#    RMSE (KITTI)  A1 (DDAD)  A1 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0      0.729636  -0.481651   -0.094937  -0.306152   -0.030335
# 1      0.728169  -0.458716   -0.092405  -0.309013   -0.030335
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  RMSE (DDAD)  \
# 0           FedSCDepth        0.365854        -0.825000     0.249754
# 1  FedSCDepth(Retrain)        0.288618        -0.416667     0.170466
#
#    RMSE (KITTI)  A1 (DDAD)  A1 (KITTI)  A3 (DDAD)  A3 (KITTI)
# 0     -0.521106  -0.352332    0.178114  -0.066069    0.019289
# 1     -0.128348  -0.271157    0.101281  -0.053751    0.004061

# %%
analysis.plot_metrics_differences(['test_abs_rel', 'test_sq_rel', 'test_rmse', 'test_rmse_log'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type  test_abs_rel  test_sq_rel  test_rmse  \
# 0          DDAD          dynamic      0.327635     0.458308   0.234542
# 1          DDAD             full      0.412088     0.425285   0.173622
# 2          DDAD           static      0.431937     0.469137   0.175246
# 3         KITTI          dynamic     -0.066986     0.378168   0.548234
# 4         KITTI             full      0.206667     0.757853   0.729636
# 5         KITTI           static      0.258503     0.803131   0.751604
# 6          DDAD          dynamic      0.339031     0.473980   0.243123
# 7          DDAD             full      0.406593     0.436788   0.184227
# 8          DDAD           static      0.424084     0.478862   0.185563
# 9         KITTI          dynamic     -0.019139     0.411739   0.556442
# 10        KITTI             full      0.206667     0.766087   0.728169
# 11        KITTI           static      0.258503     0.805840   0.747521
# 12         DDAD          dynamic      0.128906     0.346242   0.217087
# 13         DDAD             full      0.365854     0.414364   0.249754
# 14         DDAD           static      0.394422     0.430890   0.257116
# 15        KITTI          dynamic     -0.504673    -0.950042  -0.309987
# 16        KITTI             full     -0.825000    -1.938320  -0.521106
# 17        KITTI           static     -0.944954    -2.454976  -0.585199
# 18         DDAD          dynamic      0.082031     0.223317   0.124379
# 19         DDAD             full      0.288618     0.322757   0.170466
# 20         DDAD           static      0.318725     0.336449   0.176099
# 21        KITTI          dynamic     -0.224299    -0.240974  -0.060324
# 22        KITTI             full     -0.416667    -0.580052  -0.128348
# 23        KITTI           static     -0.458716    -0.748815  -0.150297
#
#     test_rmse_log
# 0        0.347197
# 1        0.505391
# 2        0.509908
# 3        0.013201
# 4        0.295455
# 5        0.386100
# 6        0.354430
# 7        0.506739
# 8        0.511229
# 9        0.026403
# 10       0.291667
# 11       0.378378
# 12       0.220253
# 13       0.342995
# 14       0.362768
# 15      -0.193772
# 16      -0.440860
# 17      -0.571429
# 18       0.144304
# 19       0.268116
# 20       0.286396
# 21      -0.069204
# 22      -0.215054
# 23      -0.279503
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  SQ REL (DDAD)  \
# 0           FedSCDepth        0.412088         0.206667       0.425285
# 1  FedSCDepth(Retrain)        0.406593         0.206667       0.436788
#
#    SQ REL (KITTI)  RMSE (DDAD)  RMSE (KITTI)  RMSE LOG (DDAD)  \
# 0        0.757853     0.173622      0.729636         0.505391
# 1        0.766087     0.184227      0.728169         0.506739
#
#    RMSE LOG (KITTI)
# 0          0.295455
# 1          0.291667
#        training_method  ABS REL (DDAD)  ABS REL (KITTI)  SQ REL (DDAD)  \
# 0           FedSCDepth        0.365854        -0.825000       0.414364
# 1  FedSCDepth(Retrain)        0.288618        -0.416667       0.322757
#
#    SQ REL (KITTI)  RMSE (DDAD)  RMSE (KITTI)  RMSE LOG (DDAD)  \
# 0       -1.938320     0.249754     -0.521106         0.342995
# 1       -0.580052     0.170466     -0.128348         0.268116
#
#    RMSE LOG (KITTI)
# 0         -0.440860
# 1         -0.215054

# %%
analysis.plot_metrics_differences(['test_a1', 'test_a2', 'test_a3'], 'full')
# Out:
#    source_train_dataset target_train_dataset      training_method  \
# 0                  DDAD                KITTI           FedSCDepth
# 1                  DDAD                KITTI           FedSCDepth
# 2                  DDAD                KITTI           FedSCDepth
# 3                  DDAD                KITTI           FedSCDepth
# 4                  DDAD                KITTI           FedSCDepth
# 5                  DDAD                KITTI           FedSCDepth
# 6                  DDAD                KITTI  FedSCDepth(Retrain)
# 7                  DDAD                KITTI  FedSCDepth(Retrain)
# 8                  DDAD                KITTI  FedSCDepth(Retrain)
# 9                  DDAD                KITTI  FedSCDepth(Retrain)
# 10                 DDAD                KITTI  FedSCDepth(Retrain)
# 11                 DDAD                KITTI  FedSCDepth(Retrain)
# 12                KITTI                 DDAD           FedSCDepth
# 13                KITTI                 DDAD           FedSCDepth
# 14                KITTI                 DDAD           FedSCDepth
# 15                KITTI                 DDAD           FedSCDepth
# 16                KITTI                 DDAD           FedSCDepth
# 17                KITTI                 DDAD           FedSCDepth
# 18                KITTI                 DDAD  FedSCDepth(Retrain)
# 19                KITTI                 DDAD  FedSCDepth(Retrain)
# 20                KITTI                 DDAD  FedSCDepth(Retrain)
# 21                KITTI                 DDAD  FedSCDepth(Retrain)
# 22                KITTI                 DDAD  FedSCDepth(Retrain)
# 23                KITTI                 DDAD  FedSCDepth(Retrain)
#
#    test_dataset test_region_type   test_a1   test_a2   test_a3
# 0          DDAD          dynamic -0.505051 -0.344942 -0.200535
# 1          DDAD             full -0.481651 -0.364668 -0.306152
# 2          DDAD           static -0.492991 -0.384106 -0.327007
# 3         KITTI          dynamic -0.027108  0.002299  0.005308
# 4         KITTI             full -0.094937 -0.054765 -0.030335
# 5         KITTI           static -0.108040 -0.069079 -0.037657
# 6          DDAD          dynamic -0.527778 -0.353234 -0.205882
# 7          DDAD             full -0.458716 -0.371151 -0.309013
# 8          DDAD           static -0.464953 -0.389073 -0.329927
# 9         KITTI          dynamic -0.051205  0.000000  0.005308
# 10        KITTI             full -0.092405 -0.053669 -0.030335
# 11        KITTI           static -0.105528 -0.066886 -0.036611
# 12         DDAD          dynamic -0.157509 -0.124191 -0.078857
# 13         DDAD             full -0.352332 -0.122525 -0.066069
# 14         DDAD           static -0.388401 -0.133750 -0.073281
# 15        KITTI          dynamic  0.228404  0.082192  0.027397
# 16        KITTI             full  0.178114  0.060354  0.019289
# 17        KITTI           static  0.178815  0.060700  0.021169
# 18         DDAD          dynamic -0.095238 -0.072445 -0.046857
# 19         DDAD             full -0.271157 -0.097772 -0.053751
# 20         DDAD           static -0.302285 -0.107500 -0.060879
# 21        KITTI          dynamic  0.114202  0.030822  0.006322
# 22        KITTI             full  0.101281  0.024974  0.004061
# 23        KITTI           static  0.097950  0.023663  0.005040
#        training_method  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  A2 (KITTI)  \
# 0           FedSCDepth  -0.481651   -0.094937  -0.364668   -0.054765
# 1  FedSCDepth(Retrain)  -0.458716   -0.092405  -0.371151   -0.053669
#
#    A3 (DDAD)  A3 (KITTI)
# 0  -0.306152   -0.030335
# 1  -0.309013   -0.030335
#        training_method  A1 (DDAD)  A1 (KITTI)  A2 (DDAD)  A2 (KITTI)  \
# 0           FedSCDepth  -0.352332    0.178114  -0.122525    0.060354
# 1  FedSCDepth(Retrain)  -0.271157    0.101281  -0.097772    0.024974
#
#    A3 (DDAD)  A3 (KITTI)
# 0  -0.066069    0.019289
# 1  -0.053751    0.004061
